# %%
import os
import requests
import pandas as pd
import csv
import time
import datetime
import dateutil
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta, FR
import json
from pathlib import Path
from difflib import SequenceMatcher
import operator
import re
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
import spacy
from spacy_langdetect import LanguageDetector
from langdetect import detect_langs
nlp = spacy.load('en')
nlp.add_pipe(LanguageDetector(), name='language_detector', last=True)
with open('keys.json', 'r') as fp:
    our_keys = json.load(fp)
key = our_keys["musixmatch_key"]
plotly_key = our_keys["plotly_key"]
plotly.tools.set_credentials_file(username='jagluck', api_key=plotly_key)

# %%
#save songs
def save_songs(songs):
    if songs != {}:
        with open('data/songs.json', 'w') as fp:
            json.dump(songs, fp)
        
def load_songs():
    #load songs
    with open('data/songs.json', 'r') as fp:
        songs = json.load(fp)
        
    return songs
       
#compare similarity of two strings
def similar(a, b):
    sep = "feat"
    arest = a.split(sep, 1)[0]
    brest = b.split(sep, 1)[0]
    return SequenceMatcher(None, arest, brest).ratio()

def get_lang(text):
    doc = nlp(text)
    # document level language detection. Think of it like average language of the document!
    if (doc._.language['score'] > .9):
        langs = detect_langs(text)
        if (langs[0].lang == doc._.language['language']):
            if (langs[0].prob > .9):
                return doc._.language['language']

  
    return 'X'

#get language/lyric information for a single track
def get_track(song, artist):
    songs = load_songs()
    search_url = 'http://api.musixmatch.com/ws/1.1/track.search'
    params = {'q_track' : song, 'page_size' : '30', 'page' : '1', 's_track_rating' : 'desc', 'apikey': key}
    resp = requests.get(search_url, params=params)
    message = json.loads(resp.text)['message']
    while (message["header"]["status_code"] != 200):
        time.sleep(.5)  
        resp = requests.get(search_url, params=params)
        message = json.loads(resp.text)['message']
        
    tracks = json.loads(resp.text)['message']['body']['track_list']

    artist_results = {}

    index = 0
    for track in tracks:
        track_id = track['track']['track_id']
        artist_results[index] = similar(track['track']['artist_name'], artist)
        index = index + 1

    sorted_index = sorted(artist_results.items(), key=operator.itemgetter(1), reverse=True)
    
    if ((len(sorted_index) > 0) and (sorted_index[0][1] > .6)):
        winningIndex = sorted_index[0][0]
        print(tracks[winningIndex]['track'])
        track_id = tracks[winningIndex]['track']['track_id']
        commontrack_id = tracks[winningIndex]['track']['commontrack_id']
        print(track_id)

        search_url = 'http://api.musixmatch.com/ws/1.1/track.lyrics.get'
        params = {'track_id' : track_id, "commontrack_id" : commontrack_id, 'apikey': key}
        resp = requests.get(search_url, params=params)

        body = json.loads(resp.text)['message']['body']
        if ('lyrics' in body):
            lyrics = body['lyrics']
            lyrics_body  = lyrics['lyrics_body']
#             lyrics_language = lyrics['lyrics_language']

            id = (song + " by " + artist)
            song_info = {}
            song_info['song'] = song
            song_info['artist'] = artist
            song_info['lyrics_body'] = lyrics['lyrics_body'].replace('\n', ' ')[:-59]
#             song_info['lyrics_language'] = lyrics['lyrics_language']
            song_info['lyrics_language'] = get_lang(song_info['lyrics_body'])
            songs[id] = song_info
        else:
            print("empty resp")
            id = (song + " by " + artist)
            song_info = {}
            song_info['song'] = song
            song_info['artist'] = artist
            song_info['lyrics_body'] = "no lyrics"
            lg = "X"
            song_info['lyrics_language'] = lg
            songs[id] = song_info
    else:
        id = (song + " by " + artist)
        song_info = {}
        song_info['song'] = song
        song_info['artist'] = artist
        song_info['lyrics_body'] = "no lyrics"
        lg = "X"
        song_info['lyrics_language'] = lg
        songs[id] = song_info
        
    save_songs(songs)
       
#go through every song in a file
def get_songs(df, fileName):
    songs = load_songs()
    languages = []
    lyrics = []
    for songTitle, artist in zip(df['Track Name'], df['Artist']):
        songTitle = str(songTitle)
        id = (songTitle + ' by ' + artist) 
        print(id)
        #if we do not alreay have the songs language and info archived, then query for it
        if id not in songs:
            get_track(songTitle, artist)
        else:
            print("already have")
        songs = load_songs()
        songInfo = songs[id]
        lyrics.append(songInfo['lyrics_body'])
        languages.append(songInfo['lyrics_language'])
        
    #add new info to dataframe
    df['language'] = languages
    df['lyrics'] = lyrics
    
    df.to_csv(fileName)
    
#create urls and download files for a country and the last x weeks
def download_charts(country, weeks):
    
    #find last fridays date
    last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    if (datetime.now().strftime('%Y-%m-%d') == last_friday.strftime('%Y-%m-%d')):
        last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    files = []
    urls = []
    newer_date = last_friday - timedelta(days=7)
    
    #create uls by counting back a friday at a time
    for i in range(weeks):
        older_date = newer_date - timedelta(days=7)
        newer_str = newer_date.strftime('%Y-%m-%d')
        older_str = older_date.strftime('%Y-%m-%d')
        newer_date = older_date
        url = 'https://spotifycharts.com/regional/' + country + '/weekly/' + older_str + '--' + newer_str + '/download'
        file_name = "data/" + country + "/" + country + "_" + older_str + '--' + newer_str + '.csv'
#         print(url)
#         print(file_name)
        urls.append(url)
        files.append(file_name)
        
    #if we do not already have the file download it
    for file, url in zip(files,urls):
        my_file = Path(file)
        if not my_file.is_file():
            resp = requests.get(url)
            
            # if the directory does not exist create it
            directory = os.path.dirname(my_file)
            if not os.path.exists(directory):
                os.makedirs(directory)

            with open(file, 'w') as f:
                writer = csv.writer(f)
                reader = csv.reader(resp.text.splitlines())

                for row in reader:
                    writer.writerow(row)
                
    return files

#take file and add language/lyric info if needed
def add_language(files):

    for file in files:
        
        #load and reformat this file
        df = pd.read_csv(file,skiprows=[0])
        if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
            df = pd.read_csv(file,skiprows=[])
            if 'Unnamed: 0' in list(df):
                df = df.drop('Unnamed: 0', axis=1)


        df.Artist = df.Artist.astype(str)
        
        #use api and add language/lyrics only if you do not already have them
        if ('language' not in list(df)):
            get_songs(df, file) 
            songs = load_songs()
            print(len(songs))
        
def get_data(country, weeks):
       
    #download chart files
    files = download_charts(country, weeks)   
    
    #add language information to files
    add_language(files)

    #analyze language for every week
    country = []
    week = []
    english_percent = []
    spanish_percent = []

    for file in files:
        df = pd.read_csv(file,skiprows=[0])
        if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
            df = pd.read_csv(file,skiprows=[])
            if 'Unnamed: 0' in list(df):
                df = df.drop('Unnamed: 0', axis=1)


        df.Artist = df.Artist.astype(str)
        lang = {}
        for l in df['language']:
            if l in lang:
                lang[l] = lang[l] + 1
            else:
                lang[l] = 1

        eng = 0
        if "en" in lang:
            eng = lang['en']

        esp = 0
        if "es" in lang:
            esp = lang['es']

        total = eng + esp
        english_percent.append(round((eng/total),2))
        spanish_percent.append(round((esp/total),2))
        country.append(file[5:7])
        week.append(file[-14:][0:10])

    data = pd.DataFrame(
            {'country': country,
             'week': week,
             "english_percent": english_percent,
             "spanish_percent": spanish_percent
            })
    
    return data

# %%
text = "I am a man and i have three pets"
print(get_lang(text))
# Out:
# 0.9999973529136688
# [en:0.9999976837818454]
# en

# %%
us = get_data('us', 104)
us.sort_values(by=['week'], ascending=False)
us.head(104)
# Out:
#     country        week  english_percent  spanish_percent
# 0
# 102      es  2017-07-21             0.41             0.59
# 103      es  2017-07-14             0.44             0.56
#
# [104 rows x 4 columns]

# %%
de = get_data('de', 104)
de.sort_values(by=['week'], ascending=False)
de.head(104)
# Out:
# Melodien (feat. Juju) by Capital Bra
# already have
# 500 PS by Bonez MC
# already have
# In My Mind by Dynoro
# already have
# GIGI (ZKITTLEZ) by Gringo
# already have
# In My Feelings by Drake
# already have
# Mercedes by Eno
# already have
# Bella ciao - HUGEL Remix by El Profesor
# already have
# Casanova by Summer Cem
# already have
# Solo (feat. Demi Lovato) by Clean Bandit
# already have
# Rise by Jonas Blue
# already have
# Body (feat. Brando) by Loud Luxury
# already have
# Für Euch alle (feat. Samra & Capital Bra) by Bushido
# already have
# Ballin by Luciano
# already have
# Nevermind by Dennis Lloyd
# already have
# Taste (feat. Offset) by Tyga
# already have
# Girls Like You (feat. Cardi B) by Maroon 5
# already have
# No Brainer by DJ Khaled
# already have
# Habibo by Veysel
# already have
# FEFE (feat. Nicki Minaj & Murda Beatz) by 6ix9ine
# already have
# One Night Stand by Capital Bra
# already have
# STARGAZING by Travis Scott
# already have
# Jackie Chan by Tiësto
# already have
# Toto (feat. RAF Camora) by Noizy
# already have
# 2002 by Anne-Marie
# already have
# Better Now by Post Malone
# already have
# Neymar by Capital Bra
# already have
# Born To Be Yours by Kygo
# already have
# Oh Child by Robin Schulz
# already have
# One Kiss (with Dua Lipa) by Calvin Harris
# already have
# Flouz by Azzi Memo
# already have
# Eastside (with Halsey & Khalid) by benny blanco
# already have
# Santorini (feat. Veysel) by Summer Cem
# already have
# Blah Blah Blah by Armin van Buuren
# already have
# Sonnenbrille by Loredana
# already have
# Penthouse by Eno
# already have
# Je ne parle pas français - Beatgees Remix by Namika
# already have
# Jennie (feat. R. City, Bori) by Felix Jaehn
# already have
# Lucid Dreams by Juice WRLD
# already have
# Safe by Nico Santos
# already have
# I Like It by Cardi B
# already have
# Molotov (feat. RAF Camora) by Summer Cem
# already have
# SICKO MODE by Travis Scott
# already have
# Change Your Mind by ELI
# already have
# Wann dann by Capital Bra
# already have
# Copacabana by Leon Machère
# already have
# Paradies by Ufo361
# already have
# Shotgun by George Ezra
# already have
# Berlin lebt by Capital Bra
# already have
# SAD! by XXXTENTACION
# already have
# Tamam Tamam by Summer Cem
# already have
# Youngblood by 5 Seconds of Summer
# already have
# Fame (feat. RAF Camora) by Kontra K
# already have
# Familiar by Liam Payne
# already have
# God is a woman by Ariana Grande
# already have
# Back To You - From 13 Reasons Why – Season 2 Soundtrack by Selena Gomez
# already have
# Kennzeichen B-TK by Capital Bra
# already have
# KMN Member by KMN Gang
# already have
# Ocean (feat. Khalid) by Martin Garrix
# already have
# SWISH by Tyga
# already have
# VVS by Ufo361
# already have
# We Can Do Better by Matt Simons
# already have
# Only Thing We Know by Alle Farben
# already have
# Zusammen feat. Clueso by Die Fantastischen Vier
# already have
# H.O.L.Y. by Alle Farben
# already have
# Flames by David Guetta
# already have
# High Hopes by Panic! At The Disco
# already have
# Melody (feat. James Blunt) by Lost Frequencies
# already have
# CAROUSEL by Travis Scott
# already have
# Cika Cika by Ardian Bujupi
# already have
# 5 Songs in einer Nacht by Capital Bra
# already have
# Was du Liebe nennst by Bausa
# already have
# La Cintura by Alvaro Soler
# already have
# Alles vorbei by Summer Cem
# already have
# Phänomenal by Pietro Lombardi
# already have
# Wake up by Gringo
# already have
# Chinchilla (feat. KC Rebell & Capital Bra) by Summer Cem
# already have
# Moonlight by XXXTENTACION
# already have
# FRIENDS by Marshmello
# already have
# Nike Pullover by Azet
# already have
# Praise The Lord (Da Shine) (feat. Skepta) by A$AP Rocky
# already have
# Hoch by Kontra K
# already have
# Barking by Ramz
# already have
# Magisch by Olexesh
# already have
# La Cintura (feat. Flo Rida & TINI) - Remix by Alvaro Soler
# already have
# God's Plan by Drake
# already have
# Don’t Matter To Me (with Michael Jackson) by Drake
# already have
# Playinwitme (feat. Kehlani) by KYLE
# already have
# Crew by Summer Cem
# already have
# X by Nicky Jam
# already have
# STOP TRYING TO BE GOD by Travis Scott
# already have
# changes by XXXTENTACION
# already have
# An Wunder by Wincent Weiss
# already have
# YOSEMITE by Travis Scott
# already have
# WAKE UP by Travis Scott
# already have
# BUTTERFLY EFFECT by Travis Scott
# already have
# rockstar (feat. 21 Savage) by Post Malone
# already have
# Wir 2 immer 1 (feat. Olexesh) by Vanessa Mai
# already have
# R.I.P. SCREW by Travis Scott
# already have
# Nice For What by Drake
# already have
# Happy Now by Zedd
# already have
# Fiesta by Edin
# already have
# NO BYSTANDERS by Travis Scott
# already have
# no tears left to cry by Ariana Grande
# already have
# High On Life (feat. Bonn) by Martin Garrix
# already have
# I'm a Mess by Bebe Rexha
# already have
# Üff Üff by Fard
# already have
# Ohne mein Team by Bonez MC
# already have
# Sin Pijama by Becky G
# already have
# Mythos by Bushido
# already have
# Nonstop by Drake
# already have
# Gaddafi by XATAR
# already have
# Answerphone (feat. Yxng Bane) by Banx & Ranx
# already have
# Shape of You by Ed Sheeran
# already have
# Avirex by RIN
# already have
# CAN'T SAY by Travis Scott
# already have
# These Days (feat. Jess Glynne, Macklemore & Dan Caplen) by Rudimental
# already have
# Échame La Culpa by Luis Fonsi
# already have
# Primo by RAF Camora
# already have
# Mitternacht 2 by Kollegah
# already have
# Don't Leave Me Alone (feat. Anne-Marie) by David Guetta
# already have
# NC-17 by Travis Scott
# already have
# Bed (feat. Ariana Grande) by Nicki Minaj
# already have
# Live It Up - Official Song 2018 FIFA World Cup Russia by Nicky Jam
# already have
# Remind Me to Forget by Kygo
# already have
# Zu dir by LEA
# already have
# Be Alright by Dean Lewis
# already have
# 5% TINT by Travis Scott
# already have
# XY by AK Ausserkontrolle
# already have
# Happier by Ed Sheeran
# already have
# WHO? WHAT! by Travis Scott
# already have
# Wakka Flocka Flame by Dardan
# already have
# Havana (feat. Young Thug) by Camila Cabello
# already have
# Knöcheltief by Trettmann
# already have
# SKELETONS by Travis Scott
# already have
# Diarabi - Remix by Kaaris
# already have
# Ring Ring (feat. Mabel & Rich The Kid) by Jax Jones
# already have
# ASTROTHUNDER by Travis Scott
# already have
# Jocelyn Flores by XXXTENTACION
# already have
# Colors - Coca-Cola® Anthem, 2018 FIFA World CupTM by Jason Derulo
# already have
# The Middle by Zedd
# already have
# Like I Do by David Guetta
# already have
# HOUSTONFORNICATION by Travis Scott
# already have
# Dom Perignon by Kay One
# already have
# Legenden by Max Giesinger
# already have
# Dura by Daddy Yankee
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Qa bone by Azet
# already have
# 28° by JAZN
# already have
# Psycho (feat. Ty Dolla $ign) by Post Malone
# already have
# Olé Olé by Capital Bra
# already have
# Eloah by Sun Diego
# already have
# Somebody by The Chainsmokers
# already have
# Oder nicht by Kontra K
# already have
# IDGAF by Dua Lipa
# already have
# ¿ Warum ? by Gzuz
# already have
# Diego by Azad
# already have
# Immer wieder (feat. MoTrip) by Rooz
# already have
# Motorola by Fard
# already have
# Yallah Habibi - DJ Antoine & Mad Mark 2k18 German Mix by DJ Antoine
# already have
# Maserati by RAF Camora
# already have
# Bugatti Veyron by Kurdo
# already have
# Kontrollieren by RAF Camora
# already have
# Mwaka Moon - Remix by Kalash
# already have
# Von Party zu Party by SXTN
# already have
# Mad Love by Sean Paul
# already have
# Zuhause by Fynn Kliemann
# already have
# I'll Be There by Jess Glynne
# already have
# Sick Boy by The Chainsmokers
# already have
# In My Blood by Shawn Mendes
# already have
# Darkside by Alan Walker
# already have
# Palmen aus Plastik by Bonez MC
# already have
# Natural by Imagine Dragons
# already have
# Paradise by George Ezra
# already have
# Te Boté - Remix by Nio Garcia
# already have
# Perfect by Ed Sheeran
# already have
# Heute mit mir by Nimo
# already have
# Über Nacht by Gzuz
# already have
# Millionär by 187 Strassenbande
# already have
# Better Not (feat. Wafia) by Louis The Child
# already have
# Diamant by Majoe
# already have
# Believer by Imagine Dragons
# already have
# Netflix & Chill by Kay One
# already have
# Fuego by Dardan
# already have
# Senorita by Kay One
# already have
# Kein Engel by Snipe
# already have
# Dancer by Flo Rida
# already have
# BILLY by 6ix9ine
# already have
# Weg weg weg (feat. Farid Bang) by Summer Cem
# already have
# Bon Voyage by Miami Yacine
# already have
# Was erlebt by Gzuz
# already have
# In the End by Linkin Park
# already have
# Freaky Friday (feat. Chris Brown) by Lil Dicky
# already have
# COFFEE BEAN by Travis Scott
# already have
# lovely (with Khalid) by Billie Eilish
# already have
# Balla by XATAR
# KLEINKRIMINELL by Jalil
# {'track_id': 155178537, 'track_name': 'KLEINKRIMINELL', 'track_name_translation_list': [], 'track_rating': 11, 'commontrack_id': 85956357, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 29652596, 'album_name': 'Black Panther', 'artist_id': 25794828, 'artist_name': 'Jalil', 'track_share_url': 'https://www.musixmatch.com/lyrics/Jalil-2/KLEINKRIMINELL?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Jalil-2/KLEINKRIMINELL/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-08-17T14:54:38Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 155178537
# Wohin willst du by Gestört aber GeiL
# {'track_id': 132286052, 'track_name': 'Wohin willst du', 'track_name_translation_list': [], 'track_rating': 14, 'commontrack_id': 72715337, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 47, 'album_id': 26512365, 'album_name': '#ZWEI', 'artist_id': 33688483, 'artist_name': 'Gestört aber GeiL feat. LEA', 'track_share_url': 'https://www.musixmatch.com/lyrics/Gest%C3%B6rt-aber-GeiL-feat-Lea/Wohin-willst-du?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Gest%C3%B6rt-aber-GeiL-feat-Lea/Wohin-willst-du/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-08-27T20:47:03Z', 'primary_genres': {'music_genre_list': []}}
# 132286052
# Thunder by Imagine Dragons
# already have
# Unforgettable by French Montana
# already have
# Africa by Toto
# already have
# 5911
# In My Mind by Dynoro
# already have
# In My Feelings by Drake
# already have
# Casanova by Summer Cem
# already have
# Bella ciao - HUGEL Remix by El Profesor
# already have
# Solo (feat. Demi Lovato) by Clean Bandit
# already have
# Mercedes by Eno
# already have
# Rise by Jonas Blue
# already have
# Body by Loud Luxury
# already have
# Für Euch alle (feat. Samra & Capital Bra) by Bushido
# already have
# Taste (feat. Offset) by Tyga
# already have
# Nevermind by Dennis Lloyd
# already have
# Ballin by Luciano
# already have
# Girls Like You (feat. Cardi B) by Maroon 5
# already have
# Habibo by Veysel
# already have
# FEFE (feat. Nicki Minaj & Murda Beatz) by 6ix9ine
# already have
# One Kiss (with Dua Lipa) by Calvin Harris
# already have
# Better Now by Post Malone
# already have
# One Night Stand by Capital Bra
# already have
# Santorini (feat. Veysel) by Summer Cem
# already have
# Jackie Chan by Tiësto
# already have
# Toto (feat. RAF Camora) by Noizy
# already have
# 2002 by Anne-Marie
# already have
# No Brainer by DJ Khaled
# already have
# Molotov (feat. RAF Camora) by Summer Cem
# already have
# Neymar by Capital Bra
# already have
# Je ne parle pas français - Beatgees Remix by Namika
# already have
# Born To Be Yours by Kygo
# already have
# Sonnenbrille by Loredana
# already have
# Lucid Dreams by Juice WRLD
# already have
# I Like It by Cardi B
# already have
# Oh Child by Robin Schulz
# already have
# Jennie (feat. R. City, Bori) by Felix Jaehn
# already have
# Eastside (with Halsey & Khalid) by benny blanco
# already have
# Penthouse by Eno
# already have
# Tamam Tamam by Summer Cem
# already have
# SAD! by XXXTENTACION
# already have
# Change Your Mind by ELI
# already have
# Alles vorbei by Summer Cem
# already have
# Paradies by Ufo361
# already have
# Berlin lebt by Capital Bra
# already have
# Youngblood by 5 Seconds of Summer
# already have
# Blah Blah Blah by Armin van Buuren
# already have
# Safe by Nico Santos
# already have
# La Cintura by Alvaro Soler
# already have
# Wann dann by Capital Bra
# already have
# Fame (feat. RAF Camora) by Kontra K
# already have
# VVS by Ufo361
# already have
# God is a woman by Ariana Grande
# already have
# Back To You - From 13 Reasons Why – Season 2 Soundtrack by Selena Gomez
# already have
# Familiar by Liam Payne
# already have
# Ocean (feat. Khalid) by Martin Garrix
# already have
# KMN Member by KMN Gang
# already have
# Chinchilla (feat. KC Rebell & Capital Bra) by Summer Cem
# already have
# Flames by David Guetta
# already have
# Zusammen feat. Clueso by Die Fantastischen Vier
# already have
# SWISH by Tyga
# already have
# Shotgun by George Ezra
# already have
# H.O.L.Y. by Alle Farben
# already have
# Kennzeichen B-TK by Capital Bra
# already have
# Melody (feat. James Blunt) by Lost Frequencies
# already have
# We Can Do Better by Matt Simons
# already have
# Don’t Matter To Me (with Michael Jackson) by Drake
# already have
# Hoch by Kontra K
# already have
# Moonlight by XXXTENTACION
# already have
# Phänomenal by Pietro Lombardi
# already have
# Crew by Summer Cem
# already have
# FRIENDS by Marshmello
# already have
# Wake up by Gringo
# already have
# Praise The Lord (Da Shine) (feat. Skepta) by A$AP Rocky
# already have
# Mythos by Bushido
# already have
# Copacabana by Leon Machère
# already have
# God's Plan by Drake
# already have
# Was du Liebe nennst by Bausa
# already have
# Barking by Ramz
# already have
# 5 Songs in einer Nacht by Capital Bra
# already have
# Playinwitme (feat. Kehlani) by KYLE
# already have
# changes by XXXTENTACION
# already have
# Weg weg weg (feat. Farid Bang) by Summer Cem
# already have
# An Wunder by Wincent Weiss
# already have
# Wakka Flocka Flame by Dardan
# already have
# X by Nicky Jam
# already have
# Magisch by Olexesh
# already have
# Cika Cika by Ardian Bujupi
# already have
# rockstar (feat. 21 Savage) by Post Malone
# already have
# Avirex by RIN
# already have
# Nice For What by Drake
# already have
# Nonstop by Drake
# already have
# Shape of You by Ed Sheeran
# already have
# Bed (feat. Ariana Grande) by Nicki Minaj
# already have
# no tears left to cry by Ariana Grande
# already have
# La Cintura (feat. Flo Rida & TINI) - Remix by Alvaro Soler
# already have
# Sin Pijama by Becky G
# already have
# Üff Üff by Fard
# already have
# I'm a Mess by Bebe Rexha
# already have
# Anders by Summer Cem
# {'track_id': 154279359, 'track_name': 'Anders', 'track_name_translation_list': [], 'track_rating': 18, 'commontrack_id': 85793288, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 29499183, 'album_name': 'Endstufe (Deluxe Edition)', 'artist_id': 388279, 'artist_name': 'Summer Cem', 'track_share_url': 'https://www.musixmatch.com/lyrics/Summer-Cem/Anders?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Summer-Cem/Anders/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-08-09T12:53:36Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 154279359
# Colors - Coca-Cola® Anthem, 2018 FIFA World CupTM by Jason Derulo
# already have
# Live It Up - Official Song 2018 FIFA World Cup Russia by Nicky Jam
# already have
# Wir 2 immer 1 (feat. Olexesh) by Vanessa Mai
# already have
# High Hopes by Panic! At The Disco
# already have
# XY by AK Ausserkontrolle
# already have
# Mitternacht 2 by Kollegah
# already have
# Ohne mein Team by Bonez MC
# already have
# Only Thing We Know by Alle Farben
# already have
# These Days (feat. Jess Glynne, Macklemore & Dan Caplen) by Rudimental
# already have
# Diarabi - Remix by Kaaris
# already have
# Answerphone (feat. Yxng Bane) by Banx & Ranx
# already have
# Happier by Ed Sheeran
# already have
# Maison Margiela by Summer Cem
# {'track_id': 154279356, 'track_name': 'Maison Margiela', 'track_name_translation_list': [], 'track_rating': 17, 'commontrack_id': 85793287, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 29499183, 'album_name': 'Endstufe (Deluxe Edition)', 'artist_id': 388279, 'artist_name': 'Summer Cem', 'track_share_url': 'https://www.musixmatch.com/lyrics/Summer-Cem/Maison-Margiela?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Summer-Cem/Maison-Margiela/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-08-09T12:50:30Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 154279356
# Fiesta by Edin
# already have
# Échame La Culpa by Luis Fonsi
# already have
# Shukran für nix by Summer Cem
# {'track_id': 154279365, 'track_name': 'Shukran für nix', 'track_name_translation_list': [], 'track_rating': 17, 'commontrack_id': 85793290, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 1, 'album_id': 29499183, 'album_name': 'Endstufe (Deluxe Edition)', 'artist_id': 388279, 'artist_name': 'Summer Cem', 'track_share_url': 'https://www.musixmatch.com/lyrics/Summer-Cem/Shukran-f%C3%BCr-nix?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Summer-Cem/Shukran-f%C3%BCr-nix/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-08-08T10:44:11Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 154279365
# The Middle by Zedd
# already have
# Zu dir by LEA
# already have
# Jocelyn Flores by XXXTENTACION
# already have
# Primo by RAF Camora
# already have
# Happy Now by Zedd
# already have
# Remind Me to Forget by Kygo
# already have
# Knöcheltief by Trettmann
# already have
# Havana (feat. Young Thug) by Camila Cabello
# already have
# Eloah by Sun Diego
# already have
# Don't Leave Me Alone (feat. Anne-Marie) by David Guetta
# already have
# Follow Me by Summer Cem
# Freaky Friday (feat. Chris Brown) by Lil Dicky
# already have
# Psycho (feat. Ty Dolla $ign) by Post Malone
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Bugatti Veyron by Kurdo
# already have
# Yallah Habibi - DJ Antoine & Mad Mark 2k18 German Mix by DJ Antoine
# already have
# Like I Do by David Guetta
# already have
# Hades by Bushido
# {'track_id': 158479591, 'track_name': 'Hades', 'track_name_translation_list': [], 'track_rating': 18, 'commontrack_id': 84556631, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 2, 'album_id': 30161896, 'album_name': 'Mythos', 'artist_id': 36161383, 'artist_name': 'Bushido feat. Samra', 'track_share_url': 'https://www.musixmatch.com/lyrics/Bushido-feat-Samra/Hades?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Bushido-feat-Samra/Hades/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-06-20T08:08:48Z', 'primary_genres': {'music_genre_list': []}}
# 158479591
# Kein Respekt (feat. 18 Karat) by Summer Cem
# Unter Kontrolle by Nash
# {'track_id': 153724429, 'track_name': 'Unter Kontrolle', 'track_name_translation_list': [], 'track_rating': 12, 'commontrack_id': 85532530, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 1, 'album_id': 29412536, 'album_name': 'Unter Kontrolle', 'artist_id': 33446350, 'artist_name': 'Nash', 'track_share_url': 'https://www.musixmatch.com/lyrics/Nash-22/Unter-Kontrolle?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Nash-22/Unter-Kontrolle/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-08-14T07:19:04Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 153724429
# Motorola by Fard
# already have
# Legenden by Max Giesinger
# already have
# Perfect by Ed Sheeran
# already have
# Qa bone by Azet
# already have
# Zuhause by Fynn Kliemann
# already have
# Oder nicht by Kontra K
# already have
# ¿ Warum ? by Gzuz
# already have
# Ring Ring (feat. Mabel & Rich The Kid) by Jax Jones
# already have
# Über Nacht by Gzuz
# already have
# NMM (feat. Elias) by Summer Cem
# Te Boté - Remix by Nio Garcia
# already have
# Dura by Daddy Yankee
# already have
# 28° by JAZN
# already have
# Netflix & Chill by Kay One
# already have
# Immer wieder (feat. MoTrip) by Rooz
# already have
# Mwaka Moon - Remix by Kalash
# already have
# Better Not (feat. Wafia) by Louis The Child
# already have
# Maserati by RAF Camora
# already have
# Somebody by The Chainsmokers
# already have
# 200 Düsen by Summer Cem
# {'track_id': 154279352, 'track_name': '200 Düsen', 'track_name_translation_list': [], 'track_rating': 18, 'commontrack_id': 82263411, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 0, 'album_id': 29499183, 'album_name': 'Endstufe (Deluxe Edition)', 'artist_id': 388279, 'artist_name': 'Summer Cem', 'track_share_url': 'https://www.musixmatch.com/lyrics/Summer-Cem/200-D%C3%BCsen?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Summer-Cem/200-D%C3%BCsen/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-04-03T08:45:57Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 154279352
# Mad Love by Sean Paul
# already have
# Sick Boy by The Chainsmokers
# already have
# Morgen by Fynn Kliemann
# already have
# lovely (with Khalid) by Billie Eilish
# already have
# Fuego by Dardan
# already have
# Ice by Dardan
# In My Blood by Shawn Mendes
# already have
# Kontrollieren by RAF Camora
# already have
# IDGAF by Dua Lipa
# already have
# Paradise by George Ezra
# already have
# Olé Olé by Capital Bra
# already have
# Von Party zu Party by SXTN
# already have
# Meros überall by Sero El Mero
# {'track_id': 153899888, 'track_name': 'Meros überall', 'track_name_translation_list': [], 'track_rating': 15, 'commontrack_id': 85577131, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 2, 'album_id': 29433574, 'album_name': 'Meros überall', 'artist_id': 36378031, 'artist_name': 'Sero El Mero', 'track_share_url': 'https://www.musixmatch.com/lyrics/Sero-el-Mero/Meros-%C3%BCberall?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Sero-el-Mero/Meros-%C3%BCberall/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-07-30T14:17:36Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 153899888
# Bad Boys (feat. Farid Bang) by Summer Cem
# Heute mit mir by Nimo
# already have
# Senorita by Kay One
# already have
# Millionär by 187 Strassenbande
# already have
# Balla by XATAR
# already have
# Palmen aus Plastik by Bonez MC
# already have
# Natural by Imagine Dragons
# already have
# Be Alright by Dean Lewis
# already have
# Was erlebt by Gzuz
# already have
# Sólo Contigo by Topic
# {'track_id': 152027698, 'track_name': 'Sólo Contigo', 'track_name_translation_list': [], 'track_rating': 22, 'commontrack_id': 84710879, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 4, 'album_id': 29181315, 'album_name': 'Sólo Contigo', 'artist_id': 36191739, 'artist_name': 'Topic feat. Juan Magán & Lena', 'track_share_url': 'https://www.musixmatch.com/lyrics/Topic-feat-Juan-Mag%C3%A1n-Lena/S%C3%B3lo-Contigo?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Topic-feat-Juan-Mag%C3%A1n-Lena/S%C3%B3lo-Contigo/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-07-04T10:27:59Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 17, 'music_genre_parent_id': 34, 'music_genre_name': 'Dance', 'music_genre_name_extended': 'Dance', 'music_genre_vanity': 'Dance'}}]}}
# 152027698
# es
# {'language': 'es', 'score': 0.9999967693973447}
# Believer by Imagine Dragons
# already have
# Kein Engel by Snipe
# already have
# Breathe by Jax Jones
# already have
# Bon Voyage by Miami Yacine
# already have
# Je ne parle pas français by Namika
# {'track_id': 147977116, 'track_name': 'Je ne parle pas français', 'track_name_translation_list': [], 'track_rating': 65, 'commontrack_id': 82291361, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 98, 'album_id': 28532565, 'album_name': 'Que Walou', 'artist_id': 28724015, 'artist_name': 'Namika', 'track_share_url': 'https://www.musixmatch.com/lyrics/Namika/Je-ne-parle-pas-fran%C3%A7ais?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Namika/Je-ne-parle-pas-fran%C3%A7ais/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2019-04-15T14:07:57Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 147977116
# Look At Me! by XXXTENTACION
# already have
# Audio by Sia
# already have
# Lambo Diablo GT (feat. Nimo) by Capo
# already have
# One Day (feat. Ryan Tedder) by Logic
# already have
# Dancer by Flo Rida
# already have
# X - Remix by Nicky Jam
# already have
# In the End by Linkin Park
# already have
# Überlebt by Azet
# {'track_id': 147883588, 'track_name': 'Überlebt', 'track_name_translation_list': [], 'track_rating': 14, 'commontrack_id': 82191602, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 13, 'album_id': 28514287, 'album_name': 'Fast Life', 'artist_id': 31029116, 'artist_name': 'Azet', 'track_share_url': 'https://www.musixmatch.com/lyrics/Azet/%C3%9Cberlebt?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Azet/%C3%9Cberlebt/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-04-03T07:21:53Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 147883588
# One Night by RIN
# Unforgettable by French Montana
# already have
# Wohin willst du by Gestört aber GeiL
# already have
# Rooftop by Nico Santos
# already have
# Palmen aus Plastik 2 - Snippet by Bonez MC
# Darkside by Alan Walker
# already have
# Thunder by Imagine Dragons
# already have
# River (feat. Ed Sheeran) by Eminem
# already have
# Leiser by LEA
# already have
# Mama Laudaaa by Almklausi
# already have
# Let You Down by NF
# already have
# Side Effects (feat. Emily Warren) by The Chainsmokers
# already have
# Let´s Do It by Summer Cem
# 5929
# In My Mind by Dynoro
# already have
# In My Feelings by Drake
# already have
# Mercedes by Eno
# already have
# Für Euch alle (feat. Samra & Capital Bra) by Bushido
# already have
# Bella ciao - HUGEL Remix by El Profesor
# already have
# Solo (feat. Demi Lovato) by Clean Bandit
# already have
# Casanova by Summer Cem
# already have
# Rise by Jonas Blue
# already have
# Body by Loud Luxury
# already have
# Ballin by Luciano
# already have
# Nevermind by Dennis Lloyd
# already have
# Taste (feat. Offset) by Tyga
# already have
# Habibo by Veysel
# already have
# Girls Like You (feat. Cardi B) by Maroon 5
# already have
# One Kiss (with Dua Lipa) by Calvin Harris
# already have
# VVS by Ufo361
# already have
# One Night Stand by Capital Bra
# already have
# Better Now by Post Malone
# already have
# Neymar by Capital Bra
# already have
# Toto (feat. RAF Camora) by Noizy
# already have
# Je ne parle pas français - Beatgees Remix by Namika
# already have
# Sonnenbrille by Loredana
# already have
# La Cintura by Alvaro Soler
# already have
# Jackie Chan by Tiësto
# already have
# Jennie (feat. R. City, Bori) by Felix Jaehn
# already have
# Mythos by Bushido
# already have
# Santorini (feat. Veysel) by Summer Cem
# already have
# Born To Be Yours by Kygo
# already have
# Lucid Dreams by Juice WRLD
# already have
# Penthouse by Eno
# already have
# 2002 by Anne-Marie
# already have
# I Like It by Cardi B
# already have
# Paradies by Ufo361
# already have
# SAD! by XXXTENTACION
# already have
# Berlin lebt by Capital Bra
# already have
# Wann dann by Capital Bra
# already have
# KMN Member by KMN Gang
# already have
# God is a woman by Ariana Grande
# already have
# Change Your Mind by ELI
# already have
# Youngblood by 5 Seconds of Summer
# already have
# Fame (feat. RAF Camora) by Kontra K
# already have
# Hoch by Kontra K
# already have
# Tamam Tamam by Summer Cem
# already have
# FEFE (feat. Nicki Minaj & Murda Beatz) by 6ix9ine
# already have
# Back To You - From 13 Reasons Why – Season 2 Soundtrack by Selena Gomez
# already have
# Ocean (feat. Khalid) by Martin Garrix
# already have
# Don’t Matter To Me (with Michael Jackson) by Drake
# already have
# Oh Child by Robin Schulz
# already have
# Familiar by Liam Payne
# already have
# Zusammen feat. Clueso by Die Fantastischen Vier
# already have
# Wake up by Gringo
# already have
# Flames by David Guetta
# already have
# Kennzeichen B-TK by Capital Bra
# already have
# Eastside (with Halsey & Khalid) by benny blanco
# already have
# Safe by Nico Santos
# already have
# Melody (feat. James Blunt) by Lost Frequencies
# already have
# Alles vorbei by Summer Cem
# already have
# H.O.L.Y. by Alle Farben
# already have
# Blah Blah Blah by Armin van Buuren
# already have
# Phänomenal by Pietro Lombardi
# already have
# Moonlight by XXXTENTACION
# already have
# changes by XXXTENTACION
# already have
# God's Plan by Drake
# already have
# 5 Songs in einer Nacht by Capital Bra
# already have
# We Can Do Better by Matt Simons
# already have
# FRIENDS by Marshmello
# already have
# XY by AK Ausserkontrolle
# already have
# X by Nicky Jam
# already have
# Barking by Ramz
# already have
# Was du Liebe nennst by Bausa
# already have
# Playinwitme (feat. Kehlani) by KYLE
# already have
# Unter Kontrolle by Nash
# already have
# Praise The Lord (Da Shine) (feat. Skepta) by A$AP Rocky
# already have
# Chinchilla (feat. KC Rebell & Capital Bra) by Summer Cem
# already have
# An Wunder by Wincent Weiss
# already have
# Cika Cika by Ardian Bujupi
# already have
# Live It Up - Official Song 2018 FIFA World Cup Russia by Nicky Jam
# already have
# Nice For What by Drake
# already have
# Magisch by Olexesh
# already have
# Nonstop by Drake
# already have
# Colors - Coca-Cola® Anthem, 2018 FIFA World CupTM by Jason Derulo
# already have
# Avirex by RIN
# already have
# no tears left to cry by Ariana Grande
# already have
# Bed (feat. Ariana Grande) by Nicki Minaj
# already have
# Crew by Summer Cem
# already have
# rockstar (feat. 21 Savage) by Post Malone
# already have
# Mitternacht 2 by Kollegah
# already have
# Shape of You by Ed Sheeran
# already have
# Yallah Habibi - DJ Antoine & Mad Mark 2k18 German Mix by DJ Antoine
# already have
# Shotgun by George Ezra
# already have
# Wir 2 immer 1 (feat. Olexesh) by Vanessa Mai
# already have
# Hades by Bushido
# already have
# These Days (feat. Jess Glynne, Macklemore & Dan Caplen) by Rudimental
# already have
# The Middle by Zedd
# already have
# Jocelyn Flores by XXXTENTACION
# already have
# Ohne mein Team by Bonez MC
# already have
# Sin Pijama by Becky G
# already have
# Answerphone (feat. Yxng Bane) by Banx & Ranx
# already have
# Échame La Culpa by Luis Fonsi
# already have
# Remind Me to Forget by Kygo
# already have
# Motorola by Fard
# already have
# Freaky Friday (feat. Chris Brown) by Lil Dicky
# already have
# Happier by Ed Sheeran
# already have
# Primo by RAF Camora
# already have
# Eloah by Sun Diego
# already have
# Ice by Dardan
# already have
# Bugatti Veyron by Kurdo
# already have
# Havana (feat. Young Thug) by Camila Cabello
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# ALLES LIT by Jalil
# {'track_id': 155178554, 'track_name': 'ALLES LIT (Instrumental)', 'track_name_translation_list': [], 'track_rating': 10, 'commontrack_id': 86315521, 'instrumental': 1, 'explicit': 0, 'has_lyrics': 0, 'has_subtitles': 0, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 29652596, 'album_name': 'Black Panther', 'artist_id': 25794828, 'artist_name': 'Jalil', 'track_share_url': 'https://www.musixmatch.com/lyrics/Jalil-2/ALLES-LIT-Instrumental?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Jalil-2/ALLES-LIT-Instrumental/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-08-11T19:52:38Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 155178554
# Like I Do by David Guetta
# already have
# Psycho (feat. Ty Dolla $ign) by Post Malone
# already have
# Fiesta by Edin
# already have
# Knöcheltief by Trettmann
# already have
# Guilty 400 by PA Sports
# {'track_id': 153724678, 'track_name': 'Guilty 400', 'track_name_translation_list': [], 'track_rating': 13, 'commontrack_id': 85532746, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 0, 'has_richsync': 0, 'num_favourite': 1, 'album_id': 29412602, 'album_name': 'Guilty 400', 'artist_id': 13276622, 'artist_name': 'P.A. Sports', 'track_share_url': 'https://www.musixmatch.com/lyrics/PA-Sports/Guilty-400?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/PA-Sports/Guilty-400/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-07-24T10:01:38Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 153724678
# Natural by Imagine Dragons
# already have
# Netflix & Chill by Kay One
# already have
# Happy Now by Zedd
# already have
# Balla by XATAR
# already have
# High Hopes by Panic! At The Disco
# already have
# Über Nacht by Gzuz
# already have
# lovely (with Khalid) by Billie Eilish
# already have
# Te Boté - Remix by Nio Garcia
# already have
# Zu dir by LEA
# already have
# Oder nicht by Kontra K
# already have
# ¿ Warum ? by Gzuz
# already have
# Summertime Magic by Childish Gambino
# already have
# Mwaka Moon - Remix by Kalash
# already have
# Fuego by Dardan
# already have
# Qa bone by Azet
# already have
# Perfect by Ed Sheeran
# already have
# F.D.S by Genetikk
# {'track_id': 155470523, 'track_name': 'F.D.S', 'track_name_translation_list': [], 'track_rating': 16, 'commontrack_id': 85532150, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 1, 'album_id': 29708022, 'album_name': 'D.N.A.2', 'artist_id': 24405176, 'artist_name': 'Genetikk', 'track_share_url': 'https://www.musixmatch.com/lyrics/Genetikk/F-D-S?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Genetikk/F-D-S/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-07-23T14:11:04Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 155470523
# Only Thing We Know by Alle Farben
# already have
# Immer wieder (feat. MoTrip) by Rooz
# already have
# In My Blood by Shawn Mendes
# already have
# Mad Love by Sean Paul
# already have
# Dura by Daddy Yankee
# already have
# 28° by JAZN
# already have
# Better Not (feat. Wafia) by Louis The Child
# already have
# Sick Boy by The Chainsmokers
# already have
# Je ne parle pas français by Namika
# already have
# Somebody by The Chainsmokers
# already have
# Paradise by George Ezra
# already have
# One Night by RIN
# already have
# Legenden by Max Giesinger
# already have
# Olé Olé by Capital Bra
# already have
# IDGAF by Dua Lipa
# already have
# Believer by Imagine Dragons
# already have
# Von Party zu Party by SXTN
# already have
# Heute mit mir by Nimo
# already have
# Kontrollieren by RAF Camora
# already have
# Was erlebt by Gzuz
# already have
# Maserati by RAF Camora
# already have
# APESHIT by The Carters
# already have
# Audio by Sia
# already have
# Look At Me! by XXXTENTACION
# already have
# Senorita by Kay One
# already have
# Leave a Light On by Tom Walker
# already have
# Kein Engel by Snipe
# already have
# Überlebt by Azet
# already have
# Millionär by 187 Strassenbande
# already have
# Bon Voyage by Miami Yacine
# already have
# Piccos by Dardan
# {'track_id': 150876549, 'track_name': 'Piccos', 'track_name_translation_list': [], 'track_rating': 17, 'commontrack_id': 83812210, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 1, 'album_id': 28990588, 'album_name': 'Piccos', 'artist_id': 34342090, 'artist_name': 'Dardan feat. Nimo', 'track_share_url': 'https://www.musixmatch.com/lyrics/Dardan-feat-Nimo/Piccos?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Dardan-feat-Nimo/Piccos/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-05-29T12:10:07Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 150876549
# Breathe by Jax Jones
# already have
# Rooftop by Nico Santos
# already have
# Sólo Contigo by Topic
# already have
# X - Remix by Nicky Jam
# already have
# Let You Down by NF
# already have
# In the End by Linkin Park
# already have
# Darby by Capital Bra
# {'track_id': 147808338, 'track_name': 'Darby (Instrumental)', 'track_name_translation_list': [], 'track_rating': 21, 'commontrack_id': 85218181, 'instrumental': 1, 'explicit': 0, 'has_lyrics': 0, 'has_subtitles': 0, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 28501416, 'album_name': 'Berlin lebt', 'artist_id': 32123762, 'artist_name': 'Capital Bra', 'track_share_url': 'https://www.musixmatch.com/lyrics/Capital-Bra/Darby-Instrumental?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Capital-Bra/Darby-Instrumental/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-07-10T08:10:02Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 147808338
# empty resp
# Wohin willst du by Gestört aber GeiL
# already have
# Thunder by Imagine Dragons
# already have
# Unforgettable by Robin Schulz
# {'track_id': 146622781, 'track_name': 'Unforgettable (Kryder Remix)', 'track_name_translation_list': [], 'track_rating': 44, 'commontrack_id': 81446534, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 0, 'has_richsync': 0, 'num_favourite': 2, 'album_id': 28302066, 'album_name': 'Unforgettable (The Remixes)', 'artist_id': 34426921, 'artist_name': 'Robin Schulz feat. Marc Scibilia', 'track_share_url': 'https://www.musixmatch.com/lyrics/Robin-Schulz-feat-Marc-Scibilia/Unforgettable-Kryder-Remix?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Robin-Schulz-feat-Marc-Scibilia/Unforgettable-Kryder-Remix/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-06-18T12:25:41Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 17, 'music_genre_parent_id': 34, 'music_genre_name': 'Dance', 'music_genre_name_extended': 'Dance', 'music_genre_vanity': 'Dance'}}]}}
# 146622781
# en
# {'language': 'en', 'score': 0.999996416059134}
# Without You (feat. Sandro Cavazza) by Avicii
# already have
# River (feat. Ed Sheeran) by Eminem
# already have
# Palmen aus Plastik by Bonez MC
# already have
# Unforgettable by French Montana
# already have
# Morgen by Fynn Kliemann
# already have
# Leiser by LEA
# already have
# Look Alive (feat. Drake) by BlocBoy JB
# already have
# 1, 2, 3 (feat. Jason Derulo & De La Ghetto) by Sofia Reyes
# already have
# Wolke 7 by Gzuz
# {'track_id': 147931175, 'track_name': 'Wolke 7', 'track_name_translation_list': [], 'track_rating': 15, 'commontrack_id': 82262274, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 5, 'album_id': 28522738, 'album_name': 'Wolke 7', 'artist_id': 25421670, 'artist_name': 'Gzuz', 'track_share_url': 'https://www.musixmatch.com/lyrics/Gzuz/Wolke-7?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Gzuz/Wolke-7/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-05-28T14:30:33Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 147931175
# Wie Zuhause by Alligatoah
# already have
# Zuhause by Fynn Kliemann
# already have
# Lambo Diablo GT (feat. Nimo) by Capo
# already have
# Hookah Kartell by Sun Diego
# {'track_id': 152027419, 'track_name': 'Hookah Kartell', 'track_name_translation_list': [], 'track_rating': 10, 'commontrack_id': 84710684, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 2, 'album_id': 29181266, 'album_name': 'Hookah Kartell', 'artist_id': 24895029, 'artist_name': 'Sun Diego', 'track_share_url': 'https://www.musixmatch.com/lyrics/Sun-Diego-3/Hookah-Kartell?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Sun-Diego-3/Hookah-Kartell/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-06-27T10:17:02Z', 'primary_genres': {'music_genre_list': []}}
# 152027419
# Mama Laudaaa by Almklausi
# already have
# Roli by Luciano
# already have
# Africa by Toto
# already have
# Mafiosa (feat. Caroliina) by Lartiste
# Ring Ring (feat. Mabel & Rich The Kid) by Jax Jones
# already have
# Drück Drück by Gzuz
# {'track_id': 147886849, 'track_name': 'Drück Drück', 'track_name_translation_list': [], 'track_rating': 15, 'commontrack_id': 82229187, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 9, 'album_id': 28515234, 'album_name': 'Drück Drück', 'artist_id': 28798079, 'artist_name': 'Gzuz feat. LX', 'track_share_url': 'https://www.musixmatch.com/lyrics/Gzuz-feat-LX/Dr%C3%BCck-Dr%C3%BCck?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Gzuz-feat-LX/Dr%C3%BCck-Dr%C3%BCck/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-04-03T08:27:00Z', 'primary_genres': {'music_genre_list': []}}
# 147886849
# Lose Yourself - From "8 Mile" Soundtrack by Eminem
# already have
# New Rules by Dua Lipa
# already have
# Tip Toe (feat. French Montana) by Jason Derulo
# already have
# C'est la vie by Delil
# Saufen morgens, mittags, abends by Ingo ohne Flamingo
# {'track_id': 162428617, 'track_name': 'Saufen morgens, mittags, abends', 'track_name_translation_list': [], 'track_rating': 14, 'commontrack_id': 71512259, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 11, 'album_id': 30876496, 'album_name': 'Saufen morgens, mittags, abends - Die Party', 'artist_id': 33462611, 'artist_name': 'Ingo ohne Flamingo', 'track_share_url': 'https://www.musixmatch.com/lyrics/Ingo-ohne-Flamingo/Saufen-morgens-mittags-abends?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Ingo-ohne-Flamingo/Saufen-morgens-mittags-abends/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2019-05-16T08:36:49Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 50000066, 'music_genre_parent_id': 34, 'music_genre_name': 'German Pop', 'music_genre_name_extended': 'German Pop', 'music_genre_vanity': 'German-Pop'}}]}}
# 162428617
# Dancer by Flo Rida
# already have
# Wonderwall - Remastered by Oasis
# already have
# Giselle Bündchen by Capital Bra
# {'track_id': 152027473, 'track_name': 'Giselle Bündchen', 'track_name_translation_list': [], 'track_rating': 21, 'commontrack_id': 84315387, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 29181280, 'album_name': 'Berlin lebt', 'artist_id': 32123762, 'artist_name': 'Capital Bra', 'track_share_url': 'https://www.musixmatch.com/lyrics/Capital-Bra/Giselle-B%C3%BCndchen?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Capital-Bra/Giselle-B%C3%BCndchen/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-06-26T12:13:28Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 152027473
# 5942
# In My Mind by Dynoro
# already have
# Für Euch alle (feat. Samra & Capital Bra) by Bushido
# already have
# In My Feelings by Drake
# already have
# Bella ciao - HUGEL Remix by El Profesor
# already have
# Solo (feat. Demi Lovato) by Clean Bandit
# already have
# Casanova by Summer Cem
# already have
# Ballin by Luciano
# already have
# Rise by Jonas Blue
# already have
# Habibo by Veysel
# already have
# Nevermind by Dennis Lloyd
# already have
# Taste (feat. Offset) by Tyga
# already have
# Body by Loud Luxury
# already have
# Paradies by Ufo361
# already have
# One Night Stand by Capital Bra
# already have
# One Kiss (with Dua Lipa) by Calvin Harris
# already have
# Neymar by Capital Bra
# already have
# Better Now by Post Malone
# already have
# ...
# 130524305
# empty resp
# My Love (feat. Major Lazer, WizKid, Dua Lipa) by Wale
# already have
# Maximum by KC Rebell
# {'track_id': 131017877, 'track_name': 'Maximum', 'track_name_translation_list': [], 'track_rating': 18, 'commontrack_id': 71575322, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 26300989, 'album_name': 'Maximum (Deluxe Edition)', 'artist_id': 27795667, 'artist_name': 'KC Rebell feat. Summer Cem', 'track_share_url': 'https://www.musixmatch.com/lyrics/KC-Rebell-feat-Summer-Cem/Maximum?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/KC-Rebell-feat-Summer-Cem/Maximum/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-07-11T19:31:56Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1073, 'music_genre_parent_id': 18, 'music_genre_name': 'Hip-Hop', 'music_genre_name_extended': 'Hip Hop/Rap / Hip-Hop', 'music_genre_vanity': 'Hip-Hop-Rap-Hip-Hop'}}]}}
# 131017877
# Mister Dardy by Dardan
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# Bis hier und noch weiter by Adel Tawil
# {'track_id': 128779588, 'track_name': 'Bis hier und noch weiter', 'track_name_translation_list': [], 'track_rating': 18, 'commontrack_id': 70660528, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 58, 'album_id': 25971552, 'album_name': 'So schön anders (Deluxe Version)', 'artist_id': 33303912, 'artist_name': 'Adel Tawil feat. KC Rebell & Summer Cem', 'track_share_url': 'https://www.musixmatch.com/lyrics/Adel-Tawil-feat-KC-Rebell-Summer-Cem/Bis-hier-und-noch-weiter?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Adel-Tawil-feat-KC-Rebell-Summer-Cem/Bis-hier-und-noch-weiter/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-03-20T13:21:20Z', 'primary_genres': {'music_genre_list': []}}
# 128779588
# goosebumps by Travis Scott
# already have
# Fotzen im Club by SXTN
# already have
# Feuerwerk by Wincent Weiss
# already have
# Plem Plem (feat. Raf Camora & Bonez MC) by Kontra K
# already have
# Wie alles begann by Capital Bra
# already have
# Diamanten by Kontra K
# already have
# The Ocean (feat. Shy Martin) by Mike Perry
# already have
# iPhone 17 (feat. Moé) by KC Rebell
# {'track_id': 122804940, 'track_name': 'iPhone 17 (feat. Moé)', 'track_name_translation_list': [], 'track_rating': 18, 'commontrack_id': 67951807, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 8, 'album_id': 25133336, 'album_name': 'Abstand', 'artist_id': 32812687, 'artist_name': 'KC Rebell feat. Moe', 'track_share_url': 'https://www.musixmatch.com/lyrics/KC-Rebell-feat-Mo%C3%A9-3/iPhone-17-feat-Mo%C3%A9?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/KC-Rebell-feat-Mo%C3%A9-3/iPhone-17-feat-Mo%C3%A9/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-11-25T13:22:10Z', 'primary_genres': {'music_genre_list': []}}
# 122804940
# Bad Ideas by Alle Farben
# already have
# Bonfire by Felix Jaehn
# {'track_id': 124735495, 'track_name': 'Bonfire', 'track_name_translation_list': [], 'track_rating': 20, 'commontrack_id': 62616271, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 797, 'album_id': 25392190, 'album_name': 'Wild Summer 2017 (Mixed By Bombs Away & Tenzin)', 'artist_id': 31981539, 'artist_name': 'Felix Jaehn feat. Alma', 'track_share_url': 'https://www.musixmatch.com/lyrics/Felix-Jaehn-feat-ALMA/Bonfire?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Felix-Jaehn-feat-ALMA/Bonfire/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-07-15T13:51:17Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 17, 'music_genre_parent_id': 34, 'music_genre_name': 'Dance', 'music_genre_name_extended': 'Dance', 'music_genre_vanity': 'Dance'}}, {'music_genre': {'music_genre_id': 14, 'music_genre_parent_id': 34, 'music_genre_name': 'Pop', 'music_genre_name_extended': 'Pop', 'music_genre_vanity': 'Pop'}}]}}
# 124735495
# en
# {'language': 'en', 'score': 0.9999954921994603}
# Tabasco by KC Rebell
# {'track_id': 131017885, 'track_name': 'Tabasco', 'track_name_translation_list': [], 'track_rating': 18, 'commontrack_id': 72565596, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 26300989, 'album_name': 'Maximum (Deluxe Edition)', 'artist_id': 27795667, 'artist_name': 'KC Rebell feat. Summer Cem', 'track_share_url': 'https://www.musixmatch.com/lyrics/KC-Rebell-feat-Summer-Cem/Maximum-Dasaks?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/KC-Rebell-feat-Summer-Cem/Maximum-Dasaks/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-05-30T14:47:55Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1073, 'music_genre_parent_id': 18, 'music_genre_name': 'Hip-Hop', 'music_genre_name_extended': 'Hip Hop/Rap / Hip-Hop', 'music_genre_vanity': 'Hip-Hop-Rap-Hip-Hop'}}]}}
# 131017885
# Swish Swish by Katy Perry
# already have
# Run Up (feat. PARTYNEXTDOOR & Nicki Minaj) by Major Lazer
# {'track_id': 159592302, 'track_name': 'Run Up', 'track_name_translation_list': [], 'track_rating': 42, 'commontrack_id': 69396824, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 4257, 'album_id': 30361012, 'album_name': 'Major Lazer Essentials', 'artist_id': 33059272, 'artist_name': 'Major Lazer feat. PARTYNEXTDOOR & Nicki Minaj', 'track_share_url': 'https://www.musixmatch.com/lyrics/Major-Lazer-feat-PARTYNEXTDOOR-Nicki-Minaj/Run-Up-2?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Major-Lazer-feat-PARTYNEXTDOOR-Nicki-Minaj/Run-Up-2/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-01-27T11:06:50Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 14, 'music_genre_parent_id': 34, 'music_genre_name': 'Pop', 'music_genre_name_extended': 'Pop', 'music_genre_vanity': 'Pop'}}]}}
# 159592302
# en
# {'language': 'en', 'score': 0.9999949154834388}
# Lose Yourself - From "8 Mile" Soundtrack by Eminem
# already have
# Treat You Better by Shawn Mendes
# already have
# Boxerschnitt by Mert
# already have
# Show You Love by Kato
# already have
# Sampler 4 Snippet by 187 Strassenbande
# {'track_id': 131471052, 'track_name': 'Sampler 4 Snippet', 'track_name_translation_list': [], 'track_rating': 11, 'commontrack_id': 73353919, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 26382516, 'album_name': 'Sampler 4 Snippet', 'artist_id': 26530703, 'artist_name': '187 Strassenbande', 'track_share_url': 'https://www.musixmatch.com/lyrics/187-Strassenbande/Sampler-4-Snippet?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/187-Strassenbande/Sampler-4-Snippet/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-11-14T09:34:27Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 131471052
# Way Down We Go by KALEO
# already have
# Skandale by Bonez MC
# Old Friends - Jonas Blue Remix by Jasmine Thompson
# {'track_id': 128790954, 'track_name': 'Old Friends (Jonas Blue Remix)', 'track_name_translation_list': [], 'track_rating': 23, 'commontrack_id': 71581868, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 76, 'album_id': 25972892, 'album_name': 'Wonderland', 'artist_id': 33491700, 'artist_name': 'Jasmine Thompson', 'track_share_url': 'https://www.musixmatch.com/lyrics/Jasmine-Thompson/Old-Friends-Jonas-Blue-Remix?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Jasmine-Thompson/Old-Friends-Jonas-Blue-Remix/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-05-25T11:01:06Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 14, 'music_genre_parent_id': 34, 'music_genre_name': 'Pop', 'music_genre_name_extended': 'Pop', 'music_genre_vanity': 'Pop'}}]}}
# 128790954
# en
# {'language': 'en', 'score': 0.999997820197505}
# Say You Won't Let Go by James Arthur
# already have
# Lost In You by Lena
# Standort (feat. Tommy) by Capo
# Alone by Alan Walker
# already have
# Ahnma by Beginner
# {'track_id': 114310112, 'track_name': 'Ahnma', 'track_name_translation_list': [], 'track_rating': 16, 'commontrack_id': 62067735, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 182, 'album_id': 23921411, 'album_name': 'Advanced Chemistry', 'artist_id': 31899006, 'artist_name': 'Beginner feat. Gzuz & Gentleman', 'track_share_url': 'https://www.musixmatch.com/lyrics/Beginner-feat-Gzuz-Gentleman/Ahnma-2?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Beginner-feat-Gzuz-Gentleman/Ahnma-2/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-04-28T10:58:08Z', 'primary_genres': {'music_genre_list': []}}
# 114310112
# 'Till I Collapse by Eminem
# already have
# Grande by Nash
# Party On The West Coast (feat. Snoop Dogg) by Matoma
# 93       de  2017-09-22             0.97             0.03
# 94       de  2017-09-15             0.96             0.04
# 95       de  2017-09-08             0.96             0.04
# 96       de  2017-09-01             0.96             0.04
# 97       de  2017-08-25             0.96             0.04
# 98       de  2017-08-18             0.96             0.04
# 99       de  2017-08-11             0.96             0.04
# 100      de  2017-08-04             0.96             0.04
# 101      de  2017-07-28             0.96             0.04
# 102      de  2017-07-21             0.94             0.06
# 103      de  2017-07-14             0.95             0.05
#
# [104 rows x 4 columns]

# %%
glbl = get_data('global', 104)
glbl.sort_values(by=['week'], ascending=False)
glbl.head(104)

# %%
import pandas as pd

def get_all_data(countries, go_back):
    #find last fridays date
    last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    if (datetime.now().strftime('%Y-%m-%d') == last_friday.strftime('%Y-%m-%d')):
        last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    all_pds = []
    files = []
    urls = []
    country = []
    week = []
    newer_date = last_friday - timedelta(days=7)

    #create uls by counting back a friday at a time
    for i in range(go_back):
        dfs = []
        first = True
        older_date = newer_date - timedelta(days=7)
        newer_str = newer_date.strftime('%Y-%m-%d')
        older_str = older_date.strftime('%Y-%m-%d')
        newer_date = older_date
        for c in countries:
            file_name = "data/" + c + "/" + c + "_" + older_str + '--' + newer_str + '.csv'
            df = pd.read_csv(file_name,skiprows=[0])
            if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
                df = pd.read_csv(file_name,skiprows=[])
                if 'Unnamed: 0' in list(df):
                    df = df.drop('Unnamed: 0', axis=1)


            df.Artist = df.Artist.astype(str)
            dfs.append(df)
            if first:
                first = False
                country.append("all")
                week.append(file_name[-14:][0:10])
        whole=pd.concat(dfs)   
        all_pds.append(whole)  

    #analyze language for every week
    english_percent = []
    spanish_percent = []

    for df in all_pds:
        if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
            if 'Unnamed: 0' in list(df):
                df = df.drop('Unnamed: 0', axis=1)

        lang = {}
        for l in df['language']:
            if l in lang:
                lang[l] = lang[l] + 1
            else:
                lang[l] = 1

        eng = 0
        if "en" in lang:
            eng = lang['en']

        esp = 0
        if "es" in lang:
            esp = lang['es']

        total = eng + esp
        english_percent.append(round((eng/total),2))
        spanish_percent.append(round((esp/total),2))

    data = pd.DataFrame(
            {'country': country,
             'week': week,
             "english_percent": english_percent,
             "spanish_percent": spanish_percent
            })
    
    return data

# %%
all_countries = get_all_data(["mx","gt","ar","do", "co", "es"],104)
all_countries.head(104)
all_countries.to_csv("data/all_countries.csv")

# %%
# Create a trace
trace = go.Scatter(
    x = us['week'],
    y = us['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys US weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# /usr/local/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>

# %%
# Create a trace
trace = go.Scatter(
    x = de['week'],
    y = de['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Germanys weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# /usr/local/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>

# %%
# Create a trace
trace = go.Scatter(
    x = do['week'],
    y = do['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Dominican Republic weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>

# %%
# Create a trace
trace = go.Scatter(
    x = co['week'],
    y = co['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Colombia weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>

# %%
# Create a trace
trace = go.Scatter(
    x = mx['week'],
    y = mx['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Mexico weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>

# %%
# Create a trace
trace = go.Scatter(
    x = ar['week'],
    y = ar['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Argentina weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>

# %%
# Create a trace
trace = go.Scatter(
    x = gt['week'],
    y = gt['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Guatemala weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>

# %%
# Create a trace
trace = go.Scatter(
    x = es['week'],
    y = es['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spains weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>

# %%
# Create a trace
trace = go.Scatter(
    x = glbl['week'],
    y = glbl['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Global weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>

# %%
print(len(all_countries))

# Create a trace
trace = go.Scatter(
    x = all_countries['week'],
    y = all_countries['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,all_countries['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2)
                  )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spotifys Combined Spanish Speaking Countries weekly top 200 Chart',
              xaxis = dict(title = ''),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
# Out:
# 104
# /usr/local/lib/python3.7/site-packages/plotly/graph_objs/_deprecations.py:426: DeprecationWarning:
#
# plotly.graph_objs.Marker is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Marker
#   - plotly.graph_objs.histogram.selected.Marker
#   - etc.
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jagluck/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jagluck/0.embed" height="525px" width="100%"></iframe>
