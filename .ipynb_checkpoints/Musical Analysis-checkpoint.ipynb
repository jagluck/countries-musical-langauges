# %%
import os
import requests
import pandas as pd
import csv
import time
import datetime
import dateutil
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta, FR
import json
from pathlib import Path
from difflib import SequenceMatcher
import operator
import re

import plotly 
import plotly.plotly as py
import plotly.graph_objs as go

from numpy import arange,array,ones
from scipy import stats
import spacy
from spacy_langdetect import LanguageDetector
from langdetect import detect_langs
nlp = spacy.load('en')
nlp.add_pipe(LanguageDetector(), name='language_detector', last=True)
with open('keys.json', 'r') as fp:
    our_keys = json.load(fp)
key = our_keys["musixmatch_key"]
plotly_key = our_keys["plotly_key"]
plotly.tools.set_credentials_file(username = 'jagluck',
                                  api_key = plotly_key)

# %%
#save songs
def save_songs(songs):
    if songs != {}:
        with open('data/songs.json', 'w') as fp:
            json.dump(songs, fp)
        
def load_songs():
    #load songs
    with open('data/songs.json', 'r') as fp:
        songs = json.load(fp)
        
    return songs
       
#compare similarity of two strings
def similar(a, b):
    sep = "feat"
    arest = a.split(sep, 1)[0]
    brest = b.split(sep, 1)[0]
    return SequenceMatcher(None, arest, brest).ratio()

def get_lang(text):
    doc = nlp(text)
    # document level language detection. Think of it like average language of the document!
    if (doc._.language['score'] > .9):
        langs = detect_langs(text)
        if (langs[0].lang == doc._.language['language']):
            if (langs[0].prob > .9):
                return doc._.language['language']

  
    return 'X'

#get language/lyric information for a single track
def get_track(song, artist):
    songs = load_songs()
    search_url = 'http://api.musixmatch.com/ws/1.1/track.search'
    params = {'q_track' : song, 'page_size' : '30', 'page' : '1', 's_track_rating' : 'desc', 'apikey': key}
    resp = requests.get(search_url, params=params)
    message = json.loads(resp.text)['message']
    while (message["header"]["status_code"] != 200):
        time.sleep(.5)  
        resp = requests.get(search_url, params=params)
        message = json.loads(resp.text)['message']
        
    tracks = json.loads(resp.text)['message']['body']['track_list']

    artist_results = {}

    index = 0
    for track in tracks:
        track_id = track['track']['track_id']
        artist_results[index] = similar(track['track']['artist_name'], artist)
        index = index + 1

    sorted_index = sorted(artist_results.items(), key=operator.itemgetter(1), reverse=True)
    
    if ((len(sorted_index) > 0) and (sorted_index[0][1] > .6)):
        winningIndex = sorted_index[0][0]
        print(tracks[winningIndex]['track'])
        track_id = tracks[winningIndex]['track']['track_id']
        commontrack_id = tracks[winningIndex]['track']['commontrack_id']
        print(track_id)

        search_url = 'http://api.musixmatch.com/ws/1.1/track.lyrics.get'
        params = {'track_id' : track_id, "commontrack_id" : commontrack_id, 'apikey': key}
        resp = requests.get(search_url, params=params)

        body = json.loads(resp.text)['message']['body']
        if ('lyrics' in body):
            lyrics = body['lyrics']
            lyrics_body  = lyrics['lyrics_body']
#             lyrics_language = lyrics['lyrics_language']

            id = (song + " by " + artist)
            song_info = {}
            song_info['song'] = song
            song_info['artist'] = artist
            song_info['lyrics_body'] = lyrics['lyrics_body'].replace('\n', ' ')[:-59]
#             song_info['lyrics_language'] = lyrics['lyrics_language']
            song_info['lyrics_language'] = get_lang(song_info['lyrics_body'])
            songs[id] = song_info
        else:
            print("empty resp")
            id = (song + " by " + artist)
            song_info = {}
            song_info['song'] = song
            song_info['artist'] = artist
            song_info['lyrics_body'] = "no lyrics"
            lg = "X"
            song_info['lyrics_language'] = lg
            songs[id] = song_info
    else:
        id = (song + " by " + artist)
        song_info = {}
        song_info['song'] = song
        song_info['artist'] = artist
        song_info['lyrics_body'] = "no lyrics"
        lg = "X"
        song_info['lyrics_language'] = lg
        songs[id] = song_info
        
    save_songs(songs)
       
#go through every song in a file
def get_songs(df, fileName):
    songs = load_songs()
    languages = []
    lyrics = []
    for songTitle, artist in zip(df['Track Name'], df['Artist']):
        songTitle = str(songTitle)
        id = (songTitle + ' by ' + artist) 
        print(id)
        #if we do not alreay have the songs language and info archived, then query for it
        if id not in songs:
            get_track(songTitle, artist)
        else:
            print("already have")
        songs = load_songs()
        songInfo = songs[id]
        lyrics.append(songInfo['lyrics_body'])
        languages.append(songInfo['lyrics_language'])
        
    #add new info to dataframe
    df['language'] = languages
    df['lyrics'] = lyrics
    
    df.to_csv(fileName)
    
#create urls and download files for a country
def download_charts(country):
    
    #find last thursday date
    last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    if (datetime.now().strftime('%Y-%m-%d') == last_thursday.strftime('%Y-%m-%d')):
        last_thursday = datetime.now() + relativedelta(weekday=TH(-1))

    files = []
    urls = []
    newer_date = last_thursday - timedelta(days=7)
    older_date = newer_date - timedelta(days=7)
    oldest_date = datetime(2017, 1, 1) 
    #create uls by counting back a friday at a time
    while (older_date > oldest_date): 
        newer_str = newer_date.strftime('%Y-%m-%d')
        older_str = older_date.strftime('%Y-%m-%d')
        newer_date = older_date
        older_date = newer_date - timedelta(days=7)
        url = 'https://spotifycharts.com/regional/' + country + '/weekly/' + older_str + '--' + newer_str + '/download'
        file_name = "data/" + country + "/" + country + "_" + older_str + '--' + newer_str + '.csv'
#         print(url)
#         print(file_name)
        urls.append(url)
        files.append(file_name)
        
    #if we do not already have the file download it
    for file, url in zip(files,urls):
        my_file = Path(file)
        if not my_file.is_file():
            resp = requests.get(url)
            
            # if the directory does not exist create it
            directory = os.path.dirname(my_file)
            if not os.path.exists(directory):
                os.makedirs(directory)

            with open(file, 'w') as f:
                writer = csv.writer(f)
                reader = csv.reader(resp.text.splitlines())

                for row in reader:
                    writer.writerow(row)
                
    return files

#take file and add language/lyric info if needed
def add_language(files):

    for file in files:
        
        #load and reformat this file
        num_lines = sum(1 for line in open(file))
        df = pd.read_csv(file,skiprows=[0])
        if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
            df = pd.read_csv(file,skiprows=[])
            if 'Unnamed: 0' in list(df):
                df = df.drop('Unnamed: 0', axis=1)


        df.Artist = df.Artist.astype(str)

        #use api and add language/lyrics only if you do not already have them
        if ('language' not in list(df)):
            get_songs(df, file) 
            songs = load_songs()
            print(len(songs))
  
            
        
def get_data(country):
       
    #download chart files
    files = download_charts(country)   
    
    #add language information to files
    add_language(files)

    #analyze language for every week
    country = []
    week = []
    english_percent = []
    german_percent = []
    spanish_percent = []

    for file in files:
        df = pd.read_csv(file,skiprows=[0])
        if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
            df = pd.read_csv(file,skiprows=[])
            if 'Unnamed: 0' in list(df):
                df = df.drop('Unnamed: 0', axis=1)


        df.Artist = df.Artist.astype(str)
        lang = {}
        total = 0
        for l in df['language']:
            if l is not "X":
                total = total + 1
            if l in lang:
                lang[l] = lang[l] + 1
            else:
                lang[l] = 1
        eng = 0
        if "en" in lang:
            eng = lang['en']
        esp = 0
        if "es" in lang:
            esp = lang['es']
        ger = 0
        if "de" in lang:
            ger = lang['de']
        english_percent.append(round((eng/total),2))
        spanish_percent.append(round((esp/total),2))
        german_percent.append(round((ger/total),2))
        country.append(file[5:7])
        week.append(file[-26:][0:10])

    data = pd.DataFrame(
            {'country': country,
             'week': week,
             "english_percent": english_percent,
             "spanish_percent": spanish_percent,
             "german_percent": german_percent
            })
    
    return data

# %%
us = get_data('us')
us.sort_values(by=['week'], ascending=False)
# Out:
#     country        week  english_percent  spanish_percent  german_percent
# 0        us  2019-07-05             0.95             0.05             0.0
# 1        us  2019-06-28             0.91             0.09             0.0
# 2        us  2019-06-21             0.96             0.04             0.0
# 3        us  2019-06-14             0.96             0.04             0.0
# 4        us  2019-06-07             0.96             0.04             0.0
# ..      ...         ...              ...              ...             ...
# 126      us  2017-02-03             0.99             0.01             0.0
# 127      us  2017-01-27             0.99             0.01             0.0
# 128      us  2017-01-20             0.99             0.01             0.0
# 129      us  2017-01-13             0.99             0.01             0.0
# 130      us  2017-01-06             0.99             0.01             0.0
#
# [131 rows x 5 columns]

# %%
do = get_data('do')
do.sort_values(by=['week'], ascending=False)
# Out:
#     country        week  english_percent  spanish_percent  german_percent
# 0        do  2019-07-05             0.10             0.89             0.0
# 1        do  2019-06-28             0.11             0.89             0.0
# 2        do  2019-06-21             0.12             0.88             0.0
# 3        do  2019-06-14             0.10             0.90             0.0
# 4        do  2019-06-07             0.10             0.90             0.0
# ..      ...         ...              ...              ...             ...
# 126      do  2017-02-03             0.43             0.56             0.0
# 127      do  2017-01-27             0.45             0.55             0.0
# 128      do  2017-01-20             0.47             0.53             0.0
# 129      do  2017-01-13             0.48             0.52             0.0
# 130      do  2017-01-06             0.48             0.52             0.0
#
# [131 rows x 5 columns]

# %%
mx = get_data('mx')
mx.sort_values(by=['week'], ascending=False)
# Out:
# Una Lady Como Tú by Manuel Turizo
# already have
# Felices los 4 by Maluma
# already have
# Me Rehúso by Danny Ocean
# already have
# Mi Gente by J Balvin
# already have
# Escápate Conmigo by Wisin
# already have
# Ahora Dice by Chris Jeday
# already have
# Hey DJ by CNCO
# already have
# Bonita by J Balvin
# already have
# Shape of You by Ed Sheeran
# already have
# Tu Foto by Ozuna
# already have
# Despacito - Remix by Luis Fonsi
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Me Enamoré by Shakira
# already have
# Sigo Extrañándote by J Balvin
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# El Amante by Nicky Jam
# already have
# Feels by Calvin Harris
# already have
# Attention by Charlie Puth
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# Báilame by Nacho
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Tuesday by Burak Yeter
# already have
# Thunder by Imagine Dragons
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# No digas nada by Mario Bautista
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# Sign of the Times by Harry Styles
# already have
# That's What I Like by Bruno Mars
# already have
# Loca (feat. Cali y El Dandee) by Maite Perroni
# already have
# Amárrame by Mon Laferte
# already have
# Something Just Like This by The Chainsmokers
# already have
# Alguien Robo by Sebastian Yatra
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# Besándote by Piso 21
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# Adiós Amor by Christian Nodal
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# There for You by Martin Garrix
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# Traicionera by Sebastian Yatra
# already have
# Bad Liar by Selena Gomez
# already have
# Swish Swish by Katy Perry
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Strip That Down by Liam Payne
# already have
# Para Qué Lastimarme by Gerardo Ortiz
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# Déjame te explico by Reykon
# already have
# Probablemente by Christian Nodal
# already have
# Borro Cassette by Maluma
# already have
# Wild Thoughts (feat. Rihanna & Bryson Tiller) by DJ Khaled
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# Safari by J Balvin
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Believer by Imagine Dragons
# already have
# Vacaciones by Wisin
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Soy Peor by Bad Bunny
# already have
# First Time by Kygo
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Slide by Calvin Harris
# already have
# I Feel It Coming by The Weeknd
# already have
# No Vacancy (with Sebastián Yatra) by OneRepublic
# already have
# La Bicicleta by Carlos Vives
# already have
# Soy Peor Remix (feat. J Balvin, Ozuna & Arcangel) by Bad Bunny
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# Congratulations by Post Malone
# already have
# Brillas by León Larregui
# already have
# Tu Falta De Querer by Mon Laferte
# already have
# Cómo Te Atreves by Morat
# already have
# Imitadora by Romeo Santos
# already have
# Deja vu by Prince Royce
# already have
# Tienes Que Entender by Alejandro Fernandez
# already have
# Passionfruit by Drake
# already have
# Ni Tú Ni Yo (feat. Gente de Zona) by Jennifer Lopez
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# Culpable Tu by Alta Consigna
# already have
# Mama by Jonas Blue
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Let Me Love You by DJ Snake
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Cuatro Babys by Maluma
# already have
# Malibu by Miley Cyrus
# already have
# Locos by León Larregui
# already have
# El Paciente by Alfredo Olivas
# already have
# Closer by The Chainsmokers
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# El Amante - Remix by Nicky Jam
# already have
# Te Regalo by Carla Morrison
# already have
# Buscando Huellas (feat. J Balvin & Sean Paul) by Major Lazer
# already have
# Sin Contrato by Maluma
# already have
# Lumbra by Cali Y El Dandee
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# Tengo Que Colgar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Te Regalo by Ulices Chaidez
# already have
# One Dance by Drake
# already have
# Ahora Me Llama by Karol G
# already have
# Loco Enamorado by Abraham Mateo
# already have
# Siempre Te Voy A Querer by Calibre 50
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Tú Sí Sabes Quererme (feat. Los Macorinos) by Natalia Lafourcade
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Starboy by The Weeknd
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# Por Enamorarme by Los Plebes del Rancho de Ariel Camacho
# already have
# Faded by Alan Walker
# already have
# Ahora Te Puedes Marchar by Luis Miguel
# already have
# Me Gustas by Kevin Roldan
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# El chisme by Reykon
# already have
# Side To Side by Ariana Grande
# already have
# Bebe (feat. Anuel AA) by Ozuna
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Desde Esa Noche by Thalía
# already have
# Photograph by Ed Sheeran
# already have
# Unforgettable by French Montana
# already have
# Thinking out Loud by Ed Sheeran
# already have
# Leve by Cartel De Santa
# already have
# Me Mata by Bad Bunny
# already have
# El Perdedor by Maluma
# already have
# 24K Magic by Bruno Mars
# already have
# Shape of You (feat. Zion & Lennox) - Latin Remix by Ed Sheeran
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# Stressed Out by Twenty One Pilots
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Signs by Drake
# already have
# Esta Noche Se Me Olvida by Julión Álvarez y su Norteño Banda
# already have
# Qué Me Has Hecho by Chayanne
# already have
# Quiero Que Vuelvas by Alejandro Fernandez
# already have
# La Gozadera by Gente De Zona
# already have
# The Scientist by Coldplay
# already have
# Middle by DJ Snake
# already have
# No Te Hagas by Jory Boy
# already have
# Amor Con Hielo by Morat
# already have
# Don't Wanna Know by Maroon 5
# already have
# Destino o Casualidad by Melendi
# already have
# Perfect by Ed Sheeran
# already have
# El Perdón by Nicky Jam
# already have
# Get Low (with Liam Payne) by Zedd
# already have
# Bon appétit by Katy Perry
# already have
# Que Se Canse de Llamar by Los Plebes del Rancho de Ariel Camacho
# already have
# La Dosis Perfecta by Panteon Rococo
# already have
# Hasta la Raíz by Natalia Lafourcade
# already have
# Culón Culito by Cartel De Santa
# already have
# Me Ama Me Odia by Ozuna
# already have
# Shaky Shaky by Daddy Yankee
# already have
# Hear Me Now by Alok
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# Caraluna by Bacilos
# already have
# La flaca by Jarabe De Palo
# already have
# Mala Mujer by C. Tangana
# already have
# Slow Hands by Niall Horan
# already have
# Me Vas a Extrañar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Afuera Está Lloviendo by Julión Álvarez y su Norteño Banda
# already have
# Paris by The Chainsmokers
# already have
# In the Name of Love by Martin Garrix
# already have
# Ride by Twenty One Pilots
# already have
# Crying in the Club by Camila Cabello
# already have
# Te Deseo Lo Mejor by Alta Consigna
# already have
# Me Va A Pesar by La Arrolladora Banda El Limón De Rene Camacho
# already have
# DUELE EL CORAZON by Enrique Iglesias
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# My Way by Calvin Harris
# already have
# Llegaste tú (feat. Reykon) by Sofia Reyes
# already have
# Casi Humanos by Dvicio
# already have
# Bebé - Remix by Brytiago
# already have
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# Dueles by Jesse & Joy
# already have
# Es Tuyo Mi Amor by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Persiana Americana by Soda Stereo
# already have
# Me Dediqué a Perderte by Alejandro Fernandez
# already have
# Que Lo Nuestro Se Quede Nuestro by Carlos Rivera
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# Soñé by Zoé
# already have
# Afuera by Caifanes
# already have
# Labios Rotos by Zoé
# already have
# Be Mine by Ofenbach
# already have
# Bobo by J Balvin
# already have
# Rollin by Calvin Harris
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Eres by Café Tacvba
# already have
# This Is What You Came For by Calvin Harris
# already have
# Mi Buen Amor by Mon Laferte
# already have
# Ya Me Enteré by Reik
# already have
# Me Acostumbre (feat. Bad Bunny) by Arcangel
# already have
# Cheap Thrills by Sia
# already have
# Just Hold On by Steve Aoki
# already have
# Wonderwall - Remastered by Oasis
# already have
# Lo Digo (feat. Gente de Zona) by Carlos Rivera
# already have
# 6900
# Felices los 4 by Maluma
# already have
# Me Rehúso by Danny Ocean
# already have
# Una Lady Como Tú by Manuel Turizo
# already have
# Escápate Conmigo by Wisin
# already have
# Mi Gente by J Balvin
# already have
# Ahora Dice by Chris Jeday
# already have
# Hey DJ by CNCO
# already have
# Bonita by J Balvin
# already have
# Shape of You by Ed Sheeran
# already have
# Despacito - Remix by Luis Fonsi
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Tu Foto by Ozuna
# already have
# Sigo Extrañándote by J Balvin
# already have
# Me Enamoré by Shakira
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# El Amante by Nicky Jam
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# Feels by Calvin Harris
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# Attention by Charlie Puth
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Tuesday by Burak Yeter
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Thunder by Imagine Dragons
# already have
# Sign of the Times by Harry Styles
# already have
# Amárrame by Mon Laferte
# already have
# That's What I Like by Bruno Mars
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# Báilame by Nacho
# already have
# No digas nada by Mario Bautista
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# Something Just Like This by The Chainsmokers
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# Alguien Robo by Sebastian Yatra
# already have
# Loca (feat. Cali y El Dandee) by Maite Perroni
# already have
# Adiós Amor by Christian Nodal
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# Besándote by Piso 21
# already have
# Bad Liar by Selena Gomez
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# Traicionera by Sebastian Yatra
# already have
# There for You by Martin Garrix
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Swish Swish by Katy Perry
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Strip That Down by Liam Payne
# already have
# Para Qué Lastimarme by Gerardo Ortiz
# already have
# Borro Cassette by Maluma
# already have
# Believer by Imagine Dragons
# already have
# Déjame te explico by Reykon
# already have
# Safari by J Balvin
# already have
# Wild Thoughts (feat. Rihanna & Bryson Tiller) by DJ Khaled
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# Slide by Calvin Harris
# already have
# Probablemente by Christian Nodal
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Vacaciones by Wisin
# already have
# First Time by Kygo
# already have
# Soy Peor by Bad Bunny
# already have
# Soy Peor Remix (feat. J Balvin, Ozuna & Arcangel) by Bad Bunny
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# I Feel It Coming by The Weeknd
# already have
# Mama by Jonas Blue
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Malibu by Miley Cyrus
# already have
# La Bicicleta by Carlos Vives
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# No Vacancy (with Sebastián Yatra) by OneRepublic
# already have
# Cómo Te Atreves by Morat
# already have
# Tu Falta De Querer by Mon Laferte
# already have
# Passionfruit by Drake
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# Brillas by León Larregui
# already have
# Congratulations by Post Malone
# already have
# Culpable Tu by Alta Consigna
# already have
# Deja vu by Prince Royce
# already have
# Tienes Que Entender by Alejandro Fernandez
# already have
# Let Me Love You by DJ Snake
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Cuatro Babys by Maluma
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# El Paciente by Alfredo Olivas
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Closer by The Chainsmokers
# already have
# Locos by León Larregui
# already have
# El Amante - Remix by Nicky Jam
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# Te Regalo by Carla Morrison
# already have
# Tengo Que Colgar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Buscando Huellas (feat. J Balvin & Sean Paul) by Major Lazer
# already have
# One Dance by Drake
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# Lumbra by Cali Y El Dandee
# already have
# Sin Contrato by Maluma
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Siempre Te Voy A Querer by Calibre 50
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Te Regalo by Ulices Chaidez
# already have
# Starboy by The Weeknd
# already have
# Tú Sí Sabes Quererme (feat. Los Macorinos) by Natalia Lafourcade
# already have
# Me Gustas by Kevin Roldan
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# Esta Noche Se Me Olvida by Julión Álvarez y su Norteño Banda
# already have
# Faded by Alan Walker
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Signs by Drake
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Por Enamorarme by Los Plebes del Rancho de Ariel Camacho
# already have
# Afuera Está Lloviendo by Julión Álvarez y su Norteño Banda
# already have
# Bon appétit by Katy Perry
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Desde Esa Noche by Thalía
# already have
# Leve by Cartel De Santa
# already have
# Ahora Te Puedes Marchar by Luis Miguel
# already have
# 24K Magic by Bruno Mars
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Photograph by Ed Sheeran
# already have
# Thinking out Loud by Ed Sheeran
# already have
# El chisme by Reykon
# already have
# El Perdedor by Maluma
# already have
# Shape of You (feat. Zion & Lennox) - Latin Remix by Ed Sheeran
# already have
# Side To Side by Ariana Grande
# already have
# Me Mata by Bad Bunny
# already have
# Ahora Me Llama by Karol G
# already have
# Stressed Out by Twenty One Pilots
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# La Gozadera by Gente De Zona
# already have
# Loco Enamorado by Abraham Mateo
# already have
# Perfect by Ed Sheeran
# already have
# Amor Con Hielo by Morat
# already have
# Quiero Que Vuelvas by Alejandro Fernandez
# already have
# Unforgettable by French Montana
# already have
# Middle by DJ Snake
# already have
# Don't Wanna Know by Maroon 5
# already have
# Rollin by Calvin Harris
# already have
# The Scientist by Coldplay
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# Que Se Canse de Llamar by Los Plebes del Rancho de Ariel Camacho
# already have
# Shaky Shaky by Daddy Yankee
# already have
# El Perdón by Nicky Jam
# already have
# No Te Hagas by Jory Boy
# already have
# Hasta la Raíz by Natalia Lafourcade
# already have
# Hear Me Now by Alok
# already have
# Culón Culito by Cartel De Santa
# already have
# La Dosis Perfecta by Panteon Rococo
# already have
# Te Deseo Lo Mejor by Alta Consigna
# already have
# My Way by Calvin Harris
# already have
# Caraluna by Bacilos
# already have
# La flaca by Jarabe De Palo
# already have
# Me Vas a Extrañar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# In the Name of Love by Martin Garrix
# already have
# Imitadora by Romeo Santos
# already have
# Es Tuyo Mi Amor by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Me Va A Pesar by La Arrolladora Banda El Limón De Rene Camacho
# already have
# Paris by The Chainsmokers
# already have
# DUELE EL CORAZON by Enrique Iglesias
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# Me Ama Me Odia by Ozuna
# already have
# Ride by Twenty One Pilots
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Crying in the Club by Camila Cabello
# already have
# Slow Hands by Niall Horan
# already have
# Cold by Maroon 5
# already have
# Dueles by Jesse & Joy
# already have
# Persiana Americana by Soda Stereo
# already have
# Casi Humanos by Dvicio
# already have
# Me Dediqué a Perderte by Alejandro Fernandez
# already have
# Mala Mujer by C. Tangana
# already have
# Llegaste tú (feat. Reykon) by Sofia Reyes
# already have
# Bebé - Remix by Brytiago
# already have
# Bobo by J Balvin
# already have
# Just Hold On by Steve Aoki
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# This Is What You Came For by Calvin Harris
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# Soñé by Zoé
# already have
# Afuera by Caifanes
# already have
# Hula Hoop by Daddy Yankee
# already have
# Cheap Thrills by Sia
# already have
# Que Lo Nuestro Se Quede Nuestro by Carlos Rivera
# already have
# Be Mine by Ofenbach
# already have
# Qué Me Has Hecho by Chayanne
# already have
# Labios Rotos by Zoé
# already have
# Eres by Café Tacvba
# already have
# Wonderwall - Remastered by Oasis
# already have
# Love Yourself by Justin Bieber
# already have
# Pumped Up Kicks by Foster The People
# already have
# Ya Me Enteré by Reik
# already have
# Devuélveme a mi chica by Hombres G
# already have
# Me Acostumbre (feat. Bad Bunny) by Arcangel
# already have
# Treat You Better by Shawn Mendes
# already have
# 6900
# Felices los 4 by Maluma
# already have
# Me Rehúso by Danny Ocean
# already have
# Una Lady Como Tú by Manuel Turizo
# already have
# Escápate Conmigo by Wisin
# already have
# Ahora Dice by Chris Jeday
# already have
# Hey DJ by CNCO
# already have
# Shape of You by Ed Sheeran
# already have
# Despacito - Remix by Luis Fonsi
# already have
# Bonita by J Balvin
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# El Amante by Nicky Jam
# already have
# Tu Foto by Ozuna
# already have
# Sigo Extrañándote by J Balvin
# already have
# Me Enamoré by Shakira
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Attention by Charlie Puth
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Tuesday by Burak Yeter
# already have
# Sign of the Times by Harry Styles
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# That's What I Like by Bruno Mars
# already have
# Amárrame by Mon Laferte
# already have
# Thunder by Imagine Dragons
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Something Just Like This by The Chainsmokers
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# Alguien Robo by Sebastian Yatra
# already have
# Adiós Amor by Christian Nodal
# already have
# Báilame by Nacho
# already have
# No digas nada by Mario Bautista
# already have
# Besándote by Piso 21
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# Bad Liar by Selena Gomez
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# Traicionera by Sebastian Yatra
# already have
# There for You by Martin Garrix
# already have
# Swish Swish by Katy Perry
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# Strip That Down by Liam Payne
# already have
# Loca (feat. Cali y El Dandee) by Maite Perroni
# already have
# Believer by Imagine Dragons
# already have
# Para Qué Lastimarme by Gerardo Ortiz
# already have
# Borro Cassette by Maluma
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Feels by Calvin Harris
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# Malibu by Miley Cyrus
# already have
# Déjame te explico by Reykon
# already have
# Safari by J Balvin
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Vacaciones by Wisin
# already have
# First Time by Kygo
# already have
# Soy Peor by Bad Bunny
# already have
# I Feel It Coming by The Weeknd
# already have
# Probablemente by Christian Nodal
# already have
# Slide by Calvin Harris
# already have
# La Bicicleta by Carlos Vives
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Cómo Te Atreves by Morat
# already have
# Mama by Jonas Blue
# already have
# Passionfruit by Drake
# already have
# No Vacancy (with Sebastián Yatra) by OneRepublic
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# Tu Falta De Querer by Mon Laferte
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Wild Thoughts (feat. Rihanna & Bryson Tiller) by DJ Khaled
# already have
# Brillas by León Larregui
# already have
# Congratulations by Post Malone
# already have
# Deja vu by Prince Royce
# already have
# Culpable Tu by Alta Consigna
# already have
# Let Me Love You by DJ Snake
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Cuatro Babys by Maluma
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# Closer by The Chainsmokers
# already have
# Soy Peor Remix (feat. J Balvin, Ozuna & Arcangel) by Bad Bunny
# already have
# El Paciente by Alfredo Olivas
# already have
# Locos by León Larregui
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# One Dance by Drake
# already have
# Sin Contrato by Maluma
# already have
# Tengo Que Colgar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# Tú Sí Sabes Quererme (feat. Los Macorinos) by Natalia Lafourcade
# already have
# Tienes Que Entender by Alejandro Fernandez
# already have
# Bon appétit by Katy Perry
# already have
# Lumbra by Cali Y El Dandee
# already have
# Siempre Te Voy A Querer by Calibre 50
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Starboy by The Weeknd
# already have
# Shaky Shaky by Daddy Yankee
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Te Regalo by Ulices Chaidez
# already have
# Esta Noche Se Me Olvida by Julión Álvarez y su Norteño Banda
# already have
# Afuera Está Lloviendo by Julión Álvarez y su Norteño Banda
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# I Don’t Know Why by Imagine Dragons
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Faded by Alan Walker
# already have
# Shape of You (feat. Zion & Lennox) - Latin Remix by Ed Sheeran
# already have
# Buscando Huellas (feat. J Balvin & Sean Paul) by Major Lazer
# already have
# Me Gustas by Kevin Roldan
# already have
# Desde Esa Noche by Thalía
# already have
# Thinking out Loud by Ed Sheeran
# already have
# Leve by Cartel De Santa
# already have
# Quiero Que Vuelvas by Alejandro Fernandez
# already have
# El Perdedor by Maluma
# already have
# 24K Magic by Bruno Mars
# already have
# Te Regalo by Carla Morrison
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Photograph by Ed Sheeran
# already have
# Por Enamorarme by Los Plebes del Rancho de Ariel Camacho
# already have
# Ahora Te Puedes Marchar by Luis Miguel
# already have
# La Gozadera by Gente De Zona
# already have
# Whatever It Takes by Imagine Dragons
# already have
# Side To Side by Ariana Grande
# already have
# El chisme by Reykon
# already have
# Perfect by Ed Sheeran
# already have
# Don't Wanna Know by Maroon 5
# already have
# Stressed Out by Twenty One Pilots
# already have
# Amor Con Hielo by Morat
# already have
# Me Mata by Bad Bunny
# already have
# Middle by DJ Snake
# already have
# Que Se Canse de Llamar by Los Plebes del Rancho de Ariel Camacho
# already have
# El Perdón by Nicky Jam
# already have
# Cold by Maroon 5
# already have
# Culón Culito by Cartel De Santa
# already have
# My Way by Calvin Harris
# already have
# The Scientist by Coldplay
# already have
# Hasta la Raíz by Natalia Lafourcade
# already have
# Hear Me Now by Alok
# already have
# DUELE EL CORAZON by Enrique Iglesias
# already have
# Unforgettable by French Montana
# already have
# Caraluna by Bacilos
# already have
# La Dosis Perfecta by Panteon Rococo
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Te Deseo Lo Mejor by Alta Consigna
# already have
# Imitadora by Romeo Santos
# already have
# Crying in the Club by Camila Cabello
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# Paris by The Chainsmokers
# already have
# Me Va A Pesar by La Arrolladora Banda El Limón De Rene Camacho
# already have
# Me Vas a Extrañar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# La flaca by Jarabe De Palo
# already have
# Me Ama Me Odia by Ozuna
# already have
# In the Name of Love by Martin Garrix
# already have
# No Te Hagas by Jory Boy
# already have
# Es Tuyo Mi Amor by Banda Sinaloense MS de Sergio Lizárraga
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# Ride by Twenty One Pilots
# already have
# Slow Hands by Niall Horan
# already have
# Llegaste tú (feat. Reykon) by Sofia Reyes
# already have
# Casi Humanos by Dvicio
# already have
# Dueles by Jesse & Joy
# already have
# Walking The Wire by Imagine Dragons
# already have
# Hula Hoop by Daddy Yankee
# already have
# Quién Te Entiende by Crecer German
# already have
# Just Hold On by Steve Aoki
# already have
# Persiana Americana by Soda Stereo
# already have
# Ahora Me Llama by Karol G
# already have
# Mala Mujer by C. Tangana
# already have
# This Is What You Came For by Calvin Harris
# already have
# Durmiendo en el Lugar Equivocado by La Adictiva Banda San José de Mesillas
# {'track_id': 118830398, 'track_name': 'Durmiendo en el Lugar Equivocado', 'track_name_translation_list': [], 'track_rating': 32, 'commontrack_id': 64165980, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 284, 'album_id': 24533215, 'album_name': 'Durmiendo en el Lugar Equivocado', 'artist_id': 24453638, 'artist_name': 'La Adictiva Banda San José de Mesillas', 'track_share_url': 'https://www.musixmatch.com/lyrics/La-Adictiva-Banda-San-Jos%C3%A9-de-Mesillas/Durmiendo-en-el-Lugar-Equivocado?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/La-Adictiva-Banda-San-Jos%C3%A9-de-Mesillas/Durmiendo-en-el-Lugar-Equivocado/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-11-17T12:36:09Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1123, 'music_genre_parent_id': 12, 'music_genre_name': 'Regional Mexicano', 'music_genre_name_extended': 'Latin / Regional Mexicano', 'music_genre_vanity': 'Latin-Regional-Mexicano'}}, {'music_genre': {'music_genre_id': 12, 'music_genre_parent_id': 34, 'music_genre_name': 'Latin', 'music_genre_name_extended': 'Latin', 'music_genre_vanity': 'Latin'}}]}}
# 118830398
# Don't Let Me Down by The Chainsmokers
# already have
# Qué Me Has Hecho by Chayanne
# already have
# Me Dediqué a Perderte by Alejandro Fernandez
# already have
# Cheap Thrills by Sia
# already have
# Issues by Julia Michaels
# already have
# Afuera by Caifanes
# already have
# Treat You Better by Shawn Mendes
# already have
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# Soñé by Zoé
# already have
# Pumped Up Kicks by Foster The People
# already have
# Labios Rotos by Zoé
# already have
# Loco Enamorado by Abraham Mateo
# already have
# Love Yourself by Justin Bieber
# already have
# Eres by Café Tacvba
# already have
# Devuélveme a mi chica by Hombres G
# already have
# Bobo by J Balvin
# already have
# Ya Me Enteré by Reik
# already have
# Bebé - Remix by Brytiago
# already have
# Be Mine by Ofenbach
# already have
# Si Te Vienen a Contar by Cartel De Santa
# already have
# 6901
# Felices los 4 by Maluma
# already have
# Me Rehúso by Danny Ocean
# already have
# Escápate Conmigo by Wisin
# already have
# Una Lady Como Tú by Manuel Turizo
# already have
# Ahora Dice by Chris Jeday
# already have
# Hey DJ by CNCO
# already have
# Shape of You by Ed Sheeran
# already have
# Despacito - Remix by Luis Fonsi
# already have
# El Amante by Nicky Jam
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# Sigo Extrañándote by J Balvin
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Tu Foto by Ozuna
# already have
# Me Enamoré by Shakira
# already have
# Bonita by J Balvin
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# Sign of the Times by Harry Styles
# already have
# Attention by Charlie Puth
# already have
# Tuesday by Burak Yeter
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Amárrame by Mon Laferte
# already have
# That's What I Like by Bruno Mars
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# Something Just Like This by The Chainsmokers
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# Adiós Amor by Christian Nodal
# already have
# Alguien Robo by Sebastian Yatra
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# Bad Liar by Selena Gomez
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# No digas nada by Mario Bautista
# already have
# Besándote by Piso 21
# already have
# There for You by Martin Garrix
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# Strip That Down by Liam Payne
# already have
# Báilame by Nacho
# already have
# Traicionera by Sebastian Yatra
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Thunder by Imagine Dragons
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Swish Swish by Katy Perry
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# I Feel It Coming by The Weeknd
# already have
# Malibu by Miley Cyrus
# already have
# Borro Cassette by Maluma
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# Para Qué Lastimarme by Gerardo Ortiz
# already have
# Loca (feat. Cali y El Dandee) by Maite Perroni
# already have
# Safari by J Balvin
# already have
# Slide (feat. Frank Ocean & Migos) by Calvin Harris
# already have
# Bon appétit by Katy Perry
# already have
# First Time by Kygo
# already have
# Vacaciones by Wisin
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# Believer by Imagine Dragons
# already have
# La Bicicleta by Carlos Vives
# already have
# Passionfruit by Drake
# already have
# No Vacancy (with Sebastián Yatra) by OneRepublic
# already have
# Probablemente by Christian Nodal
# already have
# Cómo Te Atreves by Morat
# already have
# Tu Falta De Querer by Mon Laferte
# already have
# Soy Peor by Bad Bunny
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# Déjame te explico by Reykon
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Congratulations by Post Malone
# already have
# Deja vu by Prince Royce
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Brillas by León Larregui
# already have
# Cuatro Babys by Maluma
# already have
# Culpable Tu by Alta Consigna
# already have
# Let Me Love You by DJ Snake
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Feels (feat. Pharrell Williams, Katy Perry & Big Sean) by Calvin Harris
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# My Way by Calvin Harris
# already have
# Closer by The Chainsmokers
# already have
# El Paciente by Alfredo Olivas
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Locos by León Larregui
# already have
# Tú Sí Sabes Quererme (feat. Los Macorinos) by Natalia Lafourcade
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Sin Contrato by Maluma
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# Lumbra by Cali Y El Dandee
# already have
# One Dance by Drake
# already have
# Tengo Que Colgar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Siempre Te Voy A Querer by Calibre 50
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# Starboy by The Weeknd
# already have
# Shaky Shaky by Daddy Yankee
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Te Regalo by Ulices Chaidez
# already have
# Shape of You (feat. Zion & Lennox) - Latin Remix by Ed Sheeran
# already have
# Mama by Jonas Blue
# already have
# Afuera Está Lloviendo by Julión Álvarez y su Norteño Banda
# already have
# DUELE EL CORAZON by Enrique Iglesias
# already have
# Desde Esa Noche by Thalía
# already have
# Esta Noche Se Me Olvida by Julión Álvarez y su Norteño Banda
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Quiero Que Vuelvas by Alejandro Fernandez
# already have
# Faded by Alan Walker
# already have
# Leve by Cartel De Santa
# already have
# 24K Magic by Bruno Mars
# already have
# El Perdedor by Maluma
# already have
# Thinking out Loud by Ed Sheeran
# already have
# La Gozadera by Gente De Zona
# already have
# Perfect by Ed Sheeran
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Side To Side by Ariana Grande
# already have
# Photograph by Ed Sheeran
# already have
# Por Enamorarme by Los Plebes del Rancho de Ariel Camacho
# already have
# Don't Wanna Know by Maroon 5
# already have
# Ahora Te Puedes Marchar by Luis Miguel
# already have
# El chisme by Reykon
# already have
# Que Se Canse de Llamar by Los Plebes del Rancho de Ariel Camacho
# already have
# Cold by Maroon 5
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Culón Culito by Cartel De Santa
# already have
# Amor Con Hielo by Morat
# already have
# Stressed Out by Twenty One Pilots
# already have
# Middle by DJ Snake
# already have
# Crying in the Club by Camila Cabello
# already have
# El Perdón by Nicky Jam
# already have
# Buscando Huellas (feat. J Balvin & Sean Paul) by Major Lazer
# already have
# Hear Me Now by Alok
# already have
# Paris by The Chainsmokers
# already have
# Hasta la Raíz by Natalia Lafourcade
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# La Dosis Perfecta by Panteon Rococo
# already have
# Te Deseo Lo Mejor by Alta Consigna
# already have
# The Scientist by Coldplay
# already have
# In the Name of Love by Martin Garrix
# already have
# Es Tuyo Mi Amor by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Me Va A Pesar by La Arrolladora Banda El Limón De Rene Camacho
# already have
# Issues by Julia Michaels
# already have
# Caraluna by Bacilos
# already have
# Unforgettable by French Montana
# already have
# Me Vas a Extrañar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Llegaste tú (feat. Reykon) by Sofia Reyes
# already have
# Me Mata by Bad Bunny
# already have
# Slow Hands by Niall Horan
# already have
# Me Ama Me Odia by Ozuna
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# La flaca by Jarabe De Palo
# already have
# Ride by Twenty One Pilots
# already have
# Casi Humanos by Dvicio
# already have
# Hula Hoop by Daddy Yankee
# already have
# Just Hold On by Steve Aoki
# already have
# Quién Te Entiende by Crecer German
# already have
# Dueles by Jesse & Joy
# already have
# Mala Mujer by C. Tangana
# already have
# This Is What You Came For by Calvin Harris
# already have
# Galway Girl by Ed Sheeran
# already have
# Cheap Thrills by Sia
# already have
# Princesa (feat. CNCO) by Río Roma
# already have
# Durmiendo en el Lugar Equivocado by La Adictiva Banda San José de Mesillas
# already have
# Me Dediqué a Perderte by Alejandro Fernandez
# already have
# No Te Hagas by Jory Boy
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# Pumped Up Kicks by Foster The People
# already have
# Bobo by J Balvin
# already have
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# Be Mine by Ofenbach
# already have
# Eres by Café Tacvba
# already have
# Love Yourself by Justin Bieber
# already have
# Si Te Vienen a Contar by Cartel De Santa
# already have
# Soñé by Zoé
# already have
# Devuélveme a mi chica by Hombres G
# already have
# Treat You Better by Shawn Mendes
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# Afuera by Caifanes
# already have
# Qué Me Has Hecho by Chayanne
# already have
# Ya Me Enteré by Reik
# already have
# Labios Rotos by Zoé
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Me Soltaste by Jesse & Joy
# already have
# Amor Completo by Mon Laferte
# already have
# Perfect Strangers by Jonas Blue
# already have
# Bebé - Remix by Brytiago
# already have
# Que Lo Nuestro Se Quede Nuestro by Carlos Rivera
# already have
# Cake By The Ocean by DNCE
# already have
# Perro Fiel (feat. Nicky Jam) by Shakira
# already have
# Traicionera - Remix by Sebastian Yatra
# already have
# Sería Un Error by Regulo Caro
# already have
# Cobarde by Yuridia
# {'track_id': 84136597, 'track_name': 'Cobarde', 'track_name_translation_list': [], 'track_rating': 30, 'commontrack_id': 47245811, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 912, 'album_id': 20874203, 'album_name': '6', 'artist_id': 24421346, 'artist_name': 'Yuridia', 'track_share_url': 'https://www.musixmatch.com/lyrics/Yuridia/Cobarde?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Yuridia/Cobarde/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-03-02T06:56:09Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1117, 'music_genre_parent_id': 12, 'music_genre_name': 'Pop in Spanish', 'music_genre_name_extended': 'Latin / Pop in Spanish', 'music_genre_vanity': 'Latin-Pop-in-Spanish'}}]}}
# 84136597
# Te Regalo by Carla Morrison
# already have
# 6902
# Felices los 4 by Maluma
# already have
# Me Rehúso by Danny Ocean
# already have
# Escápate Conmigo by Wisin
# already have
# Ahora Dice by Chris Jeday
# already have
# Shape of You by Ed Sheeran
# already have
# Hey DJ by CNCO
# already have
# Despacito - Remix by Luis Fonsi
# already have
# Una Lady Como Tú by Manuel Turizo
# already have
# El Amante by Nicky Jam
# already have
# Sigo Extrañándote by J Balvin
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Me Enamoré by Shakira
# already have
# Tu Foto by Ozuna
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# Sign of the Times by Harry Styles
# already have
# Bonita by J Balvin
# already have
# Tuesday by Burak Yeter
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Attention by Charlie Puth
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# That's What I Like by Bruno Mars
# already have
# Amárrame by Mon Laferte
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# Something Just Like This by The Chainsmokers
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# I'm the One by DJ Khaled
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Adiós Amor by Christian Nodal
# already have
# Alguien Robo by Sebastian Yatra
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# No digas nada by Mario Bautista
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# Thunder by Imagine Dragons
# already have
# Traicionera by Sebastian Yatra
# already have
# There for You by Martin Garrix
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Báilame by Nacho
# already have
# Besándote by Piso 21
# already have
# Bon appétit by Katy Perry
# already have
# I Feel It Coming by The Weeknd
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# Bad Liar by Selena Gomez
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# Strip That Down by Liam Payne
# already have
# Borro Cassette by Maluma
# already have
# Malibu by Miley Cyrus
# already have
# Passionfruit by Drake
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# Swish Swish by Katy Perry
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# Safari by J Balvin
# already have
# First Time by Kygo
# already have
# Para Qué Lastimarme by Gerardo Ortiz
# already have
# Slide (feat. Frank Ocean & Migos) by Calvin Harris
# already have
# Vacaciones by Wisin
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# La Bicicleta by Carlos Vives
# already have
# Believer by Imagine Dragons
# already have
# Congratulations by Post Malone
# already have
# Tú Sí Sabes Quererme (feat. Los Macorinos) by Natalia Lafourcade
# already have
# Tu Falta De Querer by Mon Laferte
# already have
# Cómo Te Atreves by Morat
# already have
# No Vacancy (with Sebastián Yatra) by OneRepublic
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# My Way by Calvin Harris
# already have
# Culpable Tu by Alta Consigna
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Loca (feat. Cali y El Dandee) by Maite Perroni
# already have
# Soy Peor by Bad Bunny
# already have
# Cuatro Babys by Maluma
# already have
# Deja vu by Prince Royce
# already have
# Brillas by León Larregui
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Let Me Love You by DJ Snake
# already have
# Closer by The Chainsmokers
# already have
# Probablemente by Christian Nodal
# already have
# HUMBLE. by Kendrick Lamar
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Locos by León Larregui
# already have
# Sin Contrato by Maluma
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# El Paciente by Alfredo Olivas
# already have
# One Dance by Drake
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# Lumbra by Cali Y El Dandee
# already have
# Starboy by The Weeknd
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# Shaky Shaky by Daddy Yankee
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Tengo Que Colgar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Siempre Te Voy A Querer by Calibre 50
# already have
# Afuera Está Lloviendo by Julión Álvarez y su Norteño Banda
# already have
# Déjame te explico by Reykon
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Perfect by Ed Sheeran
# already have
# Desde Esa Noche by Thalía
# already have
# 24K Magic by Bruno Mars
# already have
# Photograph by Ed Sheeran
# already have
# DUELE EL CORAZON by Enrique Iglesias
# already have
# Te Regalo by Ulices Chaidez
# already have
# Shape of You (feat. Zion & Lennox) - Latin Remix by Ed Sheeran
# already have
# Thinking out Loud by Ed Sheeran
# already have
# Leve by Cartel De Santa
# already have
# Faded by Alan Walker
# already have
# El Perdedor by Maluma
# already have
# Side To Side by Ariana Grande
# already have
# Quiero Que Vuelvas by Alejandro Fernandez
# already have
# Esta Noche Se Me Olvida by Julión Álvarez y su Norteño Banda
# already have
# Don't Wanna Know by Maroon 5
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Cold by Maroon 5
# already have
# Que Se Canse de Llamar by Los Plebes del Rancho de Ariel Camacho
# already have
# La Gozadera by Gente De Zona
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Amor Con Hielo by Morat
# already have
# Crying in the Club by Camila Cabello
# already have
# Culón Culito by Cartel De Santa
# already have
# Paris by The Chainsmokers
# already have
# Ahora Te Puedes Marchar by Luis Miguel
# already have
# Middle by DJ Snake
# already have
# Stressed Out by Twenty One Pilots
# already have
# Hear Me Now by Alok
# already have
# El chisme by Reykon
# already have
# El Perdón by Nicky Jam
# already have
# Galway Girl by Ed Sheeran
# already have
# Hasta la Raíz by Natalia Lafourcade
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Por Enamorarme by Los Plebes del Rancho de Ariel Camacho
# already have
# In the Name of Love by Martin Garrix
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# The Scientist by Coldplay
# already have
# Issues by Julia Michaels
# already have
# La Dosis Perfecta by Panteon Rococo
# already have
# Te Deseo Lo Mejor by Alta Consigna
# already have
# Slow Hands by Niall Horan
# already have
# Llegaste tú (feat. Reykon) by Sofia Reyes
# already have
# Buscando Huellas (feat. J Balvin & Sean Paul) by Major Lazer
# already have
# Casi Humanos by Dvicio
# already have
# Dueles by Jesse & Joy
# already have
# Hula Hoop by Daddy Yankee
# already have
# Unforgettable by French Montana
# already have
# Just Hold On by Steve Aoki
# already have
# Es Tuyo Mi Amor by Banda Sinaloense MS de Sergio Lizárraga
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# Me Vas a Extrañar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# ...
# already have
# Bailar y Volar by Cartel De Santa
# {'track_id': 118791114, 'track_name': 'Bailar y Volar', 'track_name_translation_list': [], 'track_rating': 33, 'commontrack_id': 65709402, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 166, 'album_id': 24527381, 'album_name': 'Viejo Marihuano', 'artist_id': 28857884, 'artist_name': 'Cartel De Santa feat. Millonario', 'track_share_url': 'https://www.musixmatch.com/lyrics/Cartel-De-Santa-feat-Millonario-2/Bailar-y-Volar?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Cartel-De-Santa-feat-Millonario-2/Bailar-y-Volar/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-11-22T05:05:01Z', 'primary_genres': {'music_genre_list': []}}
# 118791114
# Aunque Ahora Estés Con El by Ricardo Montaner
# already have
# Creo en Ti by Reik
# already have
# 6946
# Chantaje (feat. Maluma) by Shakira
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Safari by J Balvin
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# Traicionera by Sebastian Yatra
# already have
# Closer by The Chainsmokers
# already have
# Starboy by The Weeknd
# already have
# Let Me Love You by DJ Snake
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Shape of You by Ed Sheeran
# already have
# La Bicicleta by Carlos Vives
# already have
# Don't Wanna Know by Maroon 5
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# I Feel It Coming by The Weeknd
# already have
# 24K Magic by Bruno Mars
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Shaky Shaky by Daddy Yankee
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Cuatro Babys by Maluma
# already have
# Side To Side by Ariana Grande
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# My Way by Calvin Harris
# already have
# Leve by Cartel De Santa
# already have
# In the Name of Love by Martin Garrix
# already have
# Quiero Que Vuelvas by Alejandro Fernandez
# already have
# Cold Water (feat. Justin Bieber & MØ) by Major Lazer
# already have
# Vacaciones by Wisin
# already have
# Just Hold On by Steve Aoki
# already have
# Hear Me Now by Alok
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# Adiós Amor by Christian Nodal
# already have
# Heathens by Twenty One Pilots
# already have
# Borro Cassette by Maluma
# already have
# One Dance by Drake
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Castle on the Hill by Ed Sheeran
# already have
# By Your Side by Jonas Blue
# already have
# This Is What You Came For by Calvin Harris
# already have
# Fake Love by Drake
# already have
# Llegaste tú (feat. Reykon) by Sofia Reyes
# already have
# Say You Won't Let Go by James Arthur
# already have
# Fuego by Juanes
# already have
# Dueles by Jesse & Joy
# already have
# Qué Gano Olvidándote by Reik
# already have
# Black Beatles by Rae Sremmurd
# already have
# Mercy by Shawn Mendes
# already have
# Desde Esa Noche by Thalía
# already have
# The Greatest by Sia
# already have
# Brillas by León Larregui
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# DUELE EL CORAZON by Enrique Iglesias
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# Bobo by J Balvin
# already have
# Middle by DJ Snake
# already have
# Locos by León Larregui
# already have
# Tengo Que Colgar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Cheap Thrills by Sia
# already have
# Photograph by Ed Sheeran
# already have
# Ride by Twenty One Pilots
# already have
# Stressed Out by Twenty One Pilots
# already have
# Me Quema by Paulina Rubio
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# El Perdedor by Maluma
# already have
# Thinking out Loud by Ed Sheeran
# already have
# Treat You Better by Shawn Mendes
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# Cocoon by Milky Chance
# already have
# The Mack by Nevada
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# CAN'T STOP THE FEELING! (Original Song from DreamWorks Animation's "TROLLS") by Justin Timberlake
# already have
# Ya Me Enteré by Reik
# already have
# Me Vas a Extrañar by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Culpable Tu by Alta Consigna
# already have
# Siempre Te Voy A Querer by Calibre 50
# already have
# Tu Falta De Querer by Mon Laferte
# already have
# Faded by Alan Walker
# already have
# Sin Contrato by Maluma
# already have
# Setting Fires by The Chainsmokers
# already have
# Te Metiste by Ariel Camacho y Los Plebes Del Rancho
# already have
# Cómo Te Atreves by Morat
# already have
# Perfect Strangers by Jonas Blue
# already have
# Deja Que Te Bese by Alejandro Sanz
# already have
# This Girl (Kungs Vs. Cookin' On 3 Burners) - Kungs Vs. Cookin' On 3 Burners by Kungs
# already have
# Love Yourself by Justin Bieber
# already have
# Afuera Está Lloviendo by Julión Álvarez y su Norteño Banda
# already have
# Shed a Light by Robin Schulz
# already have
# ¿Por Que Me Enamoré? by Ulices Chaidez
# already have
# La Gozadera by Gente De Zona
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# All We Know by The Chainsmokers
# already have
# Cake By The Ocean by DNCE
# already have
# Light It Up (feat. Nyla & Fuse ODG) - Remix by Major Lazer
# already have
# Solo Con Verte by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Hasta la Raíz by Natalia Lafourcade
# already have
# Mucha Marihuana by Cartel De Santa
# already have
# Regresa Hermosa by Gerardo Ortiz
# already have
# Que Lo Nuestro Se Quede Nuestro by Carlos Rivera
# already have
# Sorry by Justin Bieber
# already have
# El chisme by Reykon
# already have
# Cool Girl by Tove Lo
# {'track_id': 114201152, 'track_name': 'Cool Girl', 'track_name_translation_list': [{'track_name_translation': {'language': 'JA', 'translation': 'Cool Girl'}}], 'track_rating': 41, 'commontrack_id': 62796167, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 4307, 'album_id': 23910348, 'album_name': 'Lady Wood', 'artist_id': 24612190, 'artist_name': 'Tove Lo', 'track_share_url': 'https://www.musixmatch.com/lyrics/Tove-Lo/Cool-Girl?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Tove-Lo/Cool-Girl/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-08-17T20:43:54Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 20, 'music_genre_parent_id': 34, 'music_genre_name': 'Alternative', 'music_genre_name_extended': 'Alternative', 'music_genre_vanity': 'Alternative'}}, {'music_genre': {'music_genre_id': 14, 'music_genre_parent_id': 34, 'music_genre_name': 'Pop', 'music_genre_name_extended': 'Pop', 'music_genre_vanity': 'Pop'}}]}}
# 114201152
# Alone by Alan Walker
# already have
# Traicionera - Remix by Sebastian Yatra
# already have
# No Lo Hice Bien by Los Plebes del Rancho de Ariel Camacho
# already have
# Lean On (feat. MØ & DJ Snake) by Major Lazer
# already have
# Te Deseo Lo Mejor by Alta Consigna
# already have
# Caminar de Tu Mano by Río Roma
# already have
# Te Dirán by La Adictiva Banda San José de Mesillas
# already have
# Ruleta Rusa by Kevin Roldan
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# Work from Home (feat. Ty Dolla $ign) by Fifth Harmony
# already have
# Pumped Up Kicks by Foster The People
# already have
# Amor Del Bueno by Calibre 50
# already have
# Si Te Vienen a Contar by Cartel De Santa
# already have
# Quién Te Entiende by Crecer German
# already have
# Ginza by J Balvin
# already have
# El Perdón by Nicky Jam
# already have
# De Pies A Cabeza by Maná
# already have
# El Perdedor - The Remix by Maluma
# already have
# Culón Culito by Cartel De Santa
# already have
# Encantadora - Remix by Yandel
# already have
# Adventure of a Lifetime by Coldplay
# already have
# Encantadora by Yandel
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Picky by Joey Montana
# already have
# Panda by Desiigner
# already have
# Sé Que Te Vas by Ha*Ash
# already have
# Hymn for the Weekend - Seeb Remix by Coldplay
# already have
# Que Raro by Feid
# already have
# Work by Rihanna
# already have
# Volvió el Sensei by Cartel De Santa
# already have
# Call On Me - Ryan Riback Extended Remix by Starley
# already have
# Sex by Cheat Codes
# already have
# The Scientist by Coldplay
# already have
# Me Va A Pesar by La Arrolladora Banda El Limón De Rene Camacho
# already have
# Desde Cuándo by Cartel De Santa
# already have
# Sugar by Maroon 5
# already have
# Starving by Hailee Steinfeld
# already have
# Baila Conmigo by Juan Magán
# already have
# Manicomio by Cosculluela
# already have
# Cobarde by Yuridia
# already have
# Soñé by Zoé
# already have
# No Quiere Enamorarse (Remix) [feat. Daddy Yankee] by Ozuna
# already have
# Me Ama Me Odia by Ozuna
# already have
# Come First by Terror Jr
# {'track_id': 115428650, 'track_name': 'Come First', 'track_name_translation_list': [], 'track_rating': 19, 'commontrack_id': 62868244, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 527, 'album_id': 24039001, 'album_name': 'Bop City', 'artist_id': 31651498, 'artist_name': 'Terror Jr', 'track_share_url': 'https://www.musixmatch.com/lyrics/Terror-Jr/Come-First?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Terror-Jr/Come-First/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-08-11T22:02:26Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 14, 'music_genre_parent_id': 34, 'music_genre_name': 'Pop', 'music_genre_name_extended': 'Pop', 'music_genre_vanity': 'Pop'}}]}}
# 115428650
# Fast Car by Jonas Blue
# already have
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# Te Vas by Ozuna
# already have
# Ahora Te Puedes Marchar by Luis Miguel
# already have
# Me Está Gustando by Banda Los Recoditos
# already have
# Hotline Bling by Drake
# already have
# Into You by Ariana Grande
# already have
# Can't Feel My Face by The Weeknd
# already have
# Si me dices que sí (feat. Nicky Jam) by Cosculluela
# already have
# No Money by Galantis
# already have
# Bailame Despacio by Xantos
# already have
# En Ésta No by Sin Bandera
# already have
# Let Me Hold You (Turn Me On) by Dante Klein
# already have
# Luna by Zoé
# already have
# La Dosis Perfecta by Panteon Rococo
# already have
# Mi Razón De Ser by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Bad Things (with Camila Cabello) by Machine Gun Kelly
# already have
# Labios Rotos by Zoé
# already have
# Hasta Que Se Seque el Malecón - Remix by Jacob Forever
# already have
# Háblame De Ti by Banda Sinaloense MS de Sergio Lizárraga
# already have
# Bailando - Spanish Version by Enrique Iglesias
# already have
# A Thousand Years by Christina Perri
# already have
# Qué Caro Estoy Pagando by Los Plebes del Rancho de Ariel Camacho
# already have
# Los Mensajes del Whatsapp by Cartel De Santa
# already have
# Send My Love (To Your New Lover) by Adele
# already have
# Would I Lie to You - Radio Edit by David Guetta
# already have
# Million Reasons by Lady Gaga
# already have
# What Do You Mean? by Justin Bieber
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Hymn for the Weekend by Coldplay
# already have
# Prometiste - MTV Unplugged [En Vivo] by Pepe Aguilar
# already have
# 7 Years by Lukas Graham
# already have
# All of Me by John Legend
# already have
# Sucker For Pain (with Wiz Khalifa, Imagine Dragons, Logic & Ty Dolla $ign feat. X Ambassadors) by Lil Wayne
# already have
# Hello by Adele
# already have
# Sugar (feat. Francesco Yates) by Robin Schulz
# already have
# Pongámonos De Acuerdo by Julión Álvarez y su Norteño Banda
# already have
# I'm Not The Only One by Sam Smith
# already have
# Me Dediqué a Perderte by Alejandro Fernandez
# already have
# Aunque Ahora Estés Con El by Ricardo Montaner
# already have
# Amor Completo by Mon Laferte
# already have
# Bailar y Volar by Cartel De Santa
# already have
# How Far I'll Go - From "Moana" by Alessia Cara
# already have
# Rockin’ by The Weeknd
# already have
# Too Good by Drake
# already have
# Firestone (feat. Conrad Sewell) by Kygo
# {'track_id': 78078046, 'track_name': 'Firestone', 'track_name_translation_list': [], 'track_rating': 77, 'commontrack_id': 45083668, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 13405, 'album_id': 20204593, 'album_name': 'Firestone', 'artist_id': 31998883, 'artist_name': 'Kygo feat. Conrad Sewell', 'track_share_url': 'https://www.musixmatch.com/lyrics/Kygo-feat-Conrad-Sewell-4/Firestone?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Kygo-feat-Conrad-Sewell-4/Firestone/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2019-04-03T09:30:55Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 7, 'music_genre_parent_id': 34, 'music_genre_name': 'Electronic', 'music_genre_name_extended': 'Electronic', 'music_genre_vanity': 'Electronic'}}, {'music_genre': {'music_genre_id': 17, 'music_genre_parent_id': 34, 'music_genre_name': 'Dance', 'music_genre_name_extended': 'Dance', 'music_genre_vanity': 'Dance'}}, {'music_genre': {'music_genre_id': 1048, 'music_genre_parent_id': 17, 'music_genre_name': 'House', 'music_genre_name_extended': 'Dance / House', 'music_genre_vanity': 'Dance-House'}}]}}
# 78078046
# El Paciente by Alfredo Olivas
# already have
# 6 AM (Remix) by Enzo Ortiz
# already have
# Clika Nostra by Cartel De Santa
# {'track_id': 118791116, 'track_name': 'Clika Nostra', 'track_name_translation_list': [], 'track_rating': 34, 'commontrack_id': 65709405, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 178, 'album_id': 24527381, 'album_name': 'Viejo Marihuano', 'artist_id': 32497691, 'artist_name': 'Cartel De Santa feat. Santa Estilo', 'track_share_url': 'https://www.musixmatch.com/lyrics/Cartel-De-Santa-feat-Santa-Estilo/Clika-Nostra?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Cartel-De-Santa-feat-Santa-Estilo/Clika-Nostra/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-11-18T16:57:21Z', 'primary_genres': {'music_genre_list': []}}
# 118791116
# Perdón, Perdón - HA-ASH Primera Fila - Hecho Realidad [En Vivo] by Ha*Ash
# already have
# All Night by The Vamps
# already have
# Chandelier by Sia
# already have
# 6950
#     country        week  english_percent  spanish_percent  german_percent
# 0        mx  2019-07-05             0.17             0.83             0.0
# 1        mx  2019-06-28             0.18             0.82             0.0
# 2        mx  2019-06-21             0.21             0.79             0.0
# 3        mx  2019-06-14             0.20             0.80             0.0
# 4        mx  2019-06-07             0.22             0.78             0.0
# ..      ...         ...              ...              ...             ...
# 126      mx  2017-02-03             0.40             0.60             0.0
# 127      mx  2017-01-27             0.41             0.59             0.0
# 128      mx  2017-01-20             0.43             0.57             0.0
# 129      mx  2017-01-13             0.45             0.55             0.0
# 130      mx  2017-01-06             0.46             0.54             0.0
#
# [131 rows x 5 columns]

# %%
cr = get_data('cr')
cr.sort_values(by=['week'], ascending=False)
# Out:
# Me Rehúso by Danny Ocean
# already have
# Mi Gente by J Balvin
# already have
# Felices los 4 by Maluma
# already have
# Ahora Dice by Chris Jeday
# already have
# Shape of You by Ed Sheeran
# already have
# Escápate Conmigo by Wisin
# already have
# Hey DJ by CNCO
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# Báilame by Nacho
# already have
# Sigo Extrañándote by J Balvin
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Tu Foto by Ozuna
# already have
# Despacito - Remix by Luis Fonsi
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# El Amante by Nicky Jam
# already have
# Something Just Like This by The Chainsmokers
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Me Enamoré by Shakira
# already have
# Wild Thoughts (feat. Rihanna & Bryson Tiller) by DJ Khaled
# already have
# Bonita by J Balvin
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# Feels by Calvin Harris
# already have
# Soy Peor by Bad Bunny
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# That's What I Like by Bruno Mars
# already have
# Perfect by Ed Sheeran
# already have
# Attention by Charlie Puth
# already have
# Una Lady Como Tú by Manuel Turizo
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Lumbra by Cali Y El Dandee
# already have
# Safari by J Balvin
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# Believer by Imagine Dragons
# already have
# Side To Side by Ariana Grande
# already have
# Vacaciones by Wisin
# already have
# Sign of the Times by Harry Styles
# already have
# Alguien Robo by Sebastian Yatra
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Deja vu by Prince Royce
# already have
# Traicionera by Sebastian Yatra
# already have
# Let Me Love You by DJ Snake
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Closer by The Chainsmokers
# already have
# Thinking out Loud by Ed Sheeran
# already have
# One Dance by Drake
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# Photograph by Ed Sheeran
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Besándote by Piso 21
# already have
# Unforgettable by French Montana
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# Malibu by Miley Cyrus
# already have
# There for You by Martin Garrix
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Thunder by Imagine Dragons
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Soy Peor Remix (feat. J Balvin, Ozuna & Arcangel) by Bad Bunny
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Bad Liar by Selena Gomez
# already have
# Slide by Calvin Harris
# already have
# Into You by Ariana Grande
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# Crying in the Club by Camila Cabello
# already have
# No Lie by Sean Paul
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Borro Cassette by Maluma
# already have
# Strip That Down by Liam Payne
# already have
# Fever by Vybz Kartel
# already have
# Passionfruit by Drake
# already have
# I Feel It Coming by The Weeknd
# already have
# Déjame te explico by Reykon
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# La Bicicleta by Carlos Vives
# already have
# Treat You Better by Shawn Mendes
# already have
# Ride by Twenty One Pilots
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# Ahora Me Llama by Karol G
# already have
# Cuatro Babys by Maluma
# already have
# One Last Time by Ariana Grande
# already have
# Galway Girl by Ed Sheeran
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# In the Name of Love by Martin Garrix
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# Swish Swish by Katy Perry
# already have
# Mama by Jonas Blue
# already have
# Tu No Vive Asi (feat. Mambo Kingz & DJ Luian) by Arcangel
# already have
# Faded by Alan Walker
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# Congratulations by Post Malone
# already have
# Qué Me Has Hecho by Chayanne
# already have
# The Scientist by Coldplay
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Signs by Drake
# already have
# Dangerous Woman by Ariana Grande
# already have
# Drop It by Eshconinco
# already have
# Everyday by Ariana Grande
# already have
# Me Mata by Bad Bunny
# already have
# Me Acostumbre (feat. Bad Bunny) by Arcangel
# already have
# 24K Magic by Bruno Mars
# already have
# Bruk It Dung by Eshconinco
# already have
# Bon appétit by Katy Perry
# already have
# Me Ama Me Odia by Ozuna
# already have
# All of Me by John Legend
# already have
# Mask Off by Future
# already have
# Stressed Out by Twenty One Pilots
# already have
# 0 Sentimientos (Remix) [feat. Noriel, Darkiel, Lyan, Messiah & Baby Rasta] by Jon Z
# already have
# Cold Water (feat. Justin Bieber & MØ) by Major Lazer
# already have
# Imitadora by Romeo Santos
# already have
# Don't Wanna Know by Maroon 5
# already have
# Say You Won't Let Go by James Arthur
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Love Yourself by Justin Bieber
# already have
# Bailame Despacio by Xantos
# already have
# Starboy by The Weeknd
# already have
# Dive by Ed Sheeran
# already have
# Happier by Ed Sheeran
# already have
# La Última Vez by Anuel AA
# already have
# Destino o Casualidad by Melendi
# already have
# First Time by Kygo
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Gyal You A Party Animal by Charly Black
# already have
# Cold by Maroon 5
# already have
# Loca (feat. Cali y El Dandee) by Maite Perroni
# already have
# Paris by The Chainsmokers
# already have
# Cheap Thrills by Sia
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Castle on the Hill by Ed Sheeran
# already have
# Bruk Off Yuh Back by Konshens
# already have
# No Te Hagas by Jory Boy
# already have
# Caile (feat. Zion & De La Ghetto) by Revol
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Tan Fácil by CNCO
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# La Gozadera by Gente De Zona
# already have
# Let Her Go by Passenger
# already have
# Privado by Rvssian
# already have
# My Way by Calvin Harris
# already have
# Quisiera by CNCO
# already have
# Por Fin Te Encontré by Cali Y El Dandee
# already have
# Counting Stars by OneRepublic
# already have
# Mercy by Shawn Mendes
# already have
# 7 Years by Lukas Graham
# already have
# Princesa (feat. CNCO) by Río Roma
# already have
# A Thousand Years by Christina Perri
# already have
# Cake By The Ocean by DNCE
# already have
# Ni Tú Ni Yo (feat. Gente de Zona) by Jennifer Lopez
# already have
# Sugar by Maroon 5
# already have
# This Is What You Came For by Calvin Harris
# already have
# El Amante - Remix by Nicky Jam
# already have
# Heathens by Twenty One Pilots
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Sorry Not Sorry by Demi Lovato
# already have
# Sorry by Justin Bieber
# already have
# Ilegal by Cultura Profética
# already have
# Sweet Child O' Mine by Guns N' Roses
# already have
# Praying by Kesha
# already have
# Slow Hands by Niall Horan
# already have
# DNA. by Kendrick Lamar
# already have
# Lean On (feat. MØ & DJ Snake) by Major Lazer
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# Be Alright by Ariana Grande
# {'track_id': 112196602, 'track_name': 'Be Alright', 'track_name_translation_list': [], 'track_rating': 50, 'commontrack_id': 57866564, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 10011, 'album_id': 23646750, 'album_name': 'Dangerous Woman', 'artist_id': 13958599, 'artist_name': 'Ariana Grande', 'track_share_url': 'https://www.musixmatch.com/lyrics/Ariana-Grande/Be-Alright?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Ariana-Grande/Be-Alright/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-03-22T14:15:27Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1048, 'music_genre_parent_id': 17, 'music_genre_name': 'House', 'music_genre_name_extended': 'Dance / House', 'music_genre_vanity': 'Dance-House'}}]}}
# 112196602
# Million Reasons by Lady Gaga
# already have
# Ya Me Enteré by Reik
# already have
# Work by Rihanna
# already have
# Flor Pálida by Marc Anthony
# already have
# Stitches by Shawn Mendes
# already have
# Shaky Shaky by Daddy Yankee
# already have
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# Kung Fu by Dasoul
# already have
# When I Was Your Man by Bruno Mars
# already have
# Caraluna by Bacilos
# already have
# Cheap Thrills by Sia
# already have
# Al Filo de Tu Amor by Carlos Vives
# already have
# Bebe (feat. Anuel AA) by Ozuna
# already have
# Feel Something by Fátima Pinto
# Rollin by Calvin Harris
# already have
# Diabla - Official Remix by Farruko
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# Perfect Strangers by Jonas Blue
# already have
# En La Intimidad by Ozuna
# already have
# Héroe Favorito by Romeo Santos
# already have
# Stay With Me by Sam Smith
# already have
# Caminar de Tu Mano by Río Roma
# already have
# A Ella by Karol G
# already have
# Hello by Adele
# already have
# Pa Ti by Bad Bunny
# already have
# Un Polvo by Maluma
# already have
# 6952
# Me Rehúso by Danny Ocean
# already have
# Felices los 4 by Maluma
# already have
# Shape of You by Ed Sheeran
# already have
# Ahora Dice by Chris Jeday
# already have
# Escápate Conmigo by Wisin
# already have
# Mi Gente by J Balvin
# already have
# Hey DJ by CNCO
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# Sigo Extrañándote by J Balvin
# already have
# Báilame by Nacho
# already have
# Despacito - Remix by Luis Fonsi
# already have
# El Amante by Nicky Jam
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# Something Just Like This by The Chainsmokers
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# Tu Foto by Ozuna
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# That's What I Like by Bruno Mars
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# Soy Peor by Bad Bunny
# already have
# Wild Thoughts (feat. Rihanna & Bryson Tiller) by DJ Khaled
# already have
# Perfect by Ed Sheeran
# already have
# Me Enamoré by Shakira
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Lumbra by Cali Y El Dandee
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# Attention by Charlie Puth
# already have
# Believer by Imagine Dragons
# already have
# Safari by J Balvin
# already have
# Feels by Calvin Harris
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Sign of the Times by Harry Styles
# already have
# Bonita by J Balvin
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Thinking out Loud by Ed Sheeran
# already have
# Let Me Love You by DJ Snake
# already have
# Alguien Robo by Sebastian Yatra
# already have
# Vacaciones by Wisin
# already have
# Traicionera by Sebastian Yatra
# already have
# One Dance by Drake
# already have
# Deja vu by Prince Royce
# already have
# Closer by The Chainsmokers
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Malibu by Miley Cyrus
# already have
# Photograph by Ed Sheeran
# already have
# Una Lady Como Tú by Manuel Turizo
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# There for You by Martin Garrix
# already have
# Besándote by Piso 21
# already have
# Thunder by Imagine Dragons
# already have
# Unforgettable by French Montana
# already have
# Soy Peor Remix (feat. J Balvin, Ozuna & Arcangel) by Bad Bunny
# already have
# Side To Side by Ariana Grande
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Slide by Calvin Harris
# already have
# Passionfruit by Drake
# already have
# Bad Liar by Selena Gomez
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# No Lie by Sean Paul
# already have
# Fever by Vybz Kartel
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# I Feel It Coming by The Weeknd
# already have
# Strip That Down by Liam Payne
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Borro Cassette by Maluma
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# Swish Swish by Katy Perry
# already have
# Treat You Better by Shawn Mendes
# already have
# Crying in the Club by Camila Cabello
# already have
# Ride by Twenty One Pilots
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# Galway Girl by Ed Sheeran
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Cuatro Babys by Maluma
# already have
# La Bicicleta by Carlos Vives
# already have
# Bon appétit by Katy Perry
# already have
# Faded by Alan Walker
# already have
# In the Name of Love by Martin Garrix
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# Bruk It Dung by Eshconinco
# already have
# Tu No Vive Asi (feat. Mambo Kingz & DJ Luian) by Arcangel
# already have
# Signs by Drake
# already have
# Drop It by Eshconinco
# already have
# Mama by Jonas Blue
# already have
# The Scientist by Coldplay
# already have
# Déjame te explico by Reykon
# already have
# Mask Off by Future
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Congratulations by Post Malone
# already have
# Stressed Out by Twenty One Pilots
# already have
# 0 Sentimientos (Remix) [feat. Noriel, Darkiel, Lyan, Messiah & Baby Rasta] by Jon Z
# already have
# 24K Magic by Bruno Mars
# already have
# Cold Water (feat. Justin Bieber & MØ) by Major Lazer
# already have
# Cold by Maroon 5
# already have
# First Time by Kygo
# already have
# Me Acostumbre (feat. Bad Bunny) by Arcangel
# already have
# Me Mata by Bad Bunny
# already have
# Happier by Ed Sheeran
# already have
# Don't Wanna Know by Maroon 5
# already have
# Castle on the Hill by Ed Sheeran
# already have
# Starboy by The Weeknd
# already have
# Into You by Ariana Grande
# already have
# Me Ama Me Odia by Ozuna
# already have
# Love Yourself by Justin Bieber
# already have
# Dive by Ed Sheeran
# already have
# All of Me by John Legend
# already have
# Gyal You A Party Animal by Charly Black
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Bailame Despacio by Xantos
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# Paris by The Chainsmokers
# already have
# Say You Won't Let Go by James Arthur
# already have
# La Última Vez by Anuel AA
# already have
# Bruk Off Yuh Back by Konshens
# already have
# Ahora Me Llama by Karol G
# already have
# Cheap Thrills by Sia
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Qué Me Has Hecho by Chayanne
# already have
# Caile (feat. Zion & De La Ghetto) by Revol
# already have
# La Gozadera by Gente De Zona
# already have
# My Way by Calvin Harris
# already have
# Let Her Go by Passenger
# already have
# No Te Hagas by Jory Boy
# already have
# 7 Years by Lukas Graham
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Por Fin Te Encontré by Cali Y El Dandee
# already have
# Destino o Casualidad by Melendi
# already have
# Heathens by Twenty One Pilots
# already have
# Cake By The Ocean by DNCE
# already have
# Loca (feat. Cali y El Dandee) by Maite Perroni
# already have
# Privado by Rvssian
# already have
# Counting Stars by OneRepublic
# already have
# Mercy by Shawn Mendes
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Sorry by Justin Bieber
# already have
# Sugar by Maroon 5
# already have
# One Last Time by Ariana Grande
# already have
# Shaky Shaky by Daddy Yankee
# already have
# This Is What You Came For by Calvin Harris
# already have
# Rollin by Calvin Harris
# already have
# Sweet Child O' Mine by Guns N' Roses
# already have
# Ilegal by Cultura Profética
# already have
# DNA. by Kendrick Lamar
# already have
# Voy a Brillar by Alex Badilla
# {'track_id': 131196508, 'track_name': 'Voy a Brillar', 'track_name_translation_list': [], 'track_rating': 9, 'commontrack_id': 73185810, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 2, 'album_id': 26336390, 'album_name': 'Voy a Brillar', 'artist_id': 33784810, 'artist_name': 'Alex Badilla', 'track_share_url': 'https://www.musixmatch.com/lyrics/Alex-Badilla/Voy-a-Brillar?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Alex-Badilla/Voy-a-Brillar/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-06-19T21:30:49Z', 'primary_genres': {'music_genre_list': []}}
# 131196508
# Princesa (feat. CNCO) by Río Roma
# already have
# Feel Something by Fátima Pinto
# already have
# A Thousand Years by Christina Perri
# already have
# Tan Fácil by CNCO
# already have
# Lean On (feat. MØ & DJ Snake) by Major Lazer
# already have
# Million Reasons by Lady Gaga
# already have
# Work by Rihanna
# already have
# Slow Hands by Niall Horan
# already have
# El Amante - Remix by Nicky Jam
# already have
# Stitches by Shawn Mendes
# already have
# Everyday by Ariana Grande
# already have
# Cheap Thrills by Sia
# already have
# Ya Me Enteré by Reik
# already have
# Héroe Favorito by Romeo Santos
# already have
# Al Filo de Tu Amor by Carlos Vives
# already have
# Perfect Strangers by Jonas Blue
# already have
# Caraluna by Bacilos
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# When I Was Your Man by Bruno Mars
# already have
# Love Yuh Everything by Alkaline
# {'track_id': 83260662, 'track_name': 'Love Yuh Everything', 'track_name_translation_list': [], 'track_rating': 22, 'commontrack_id': 46288597, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 232, 'album_id': 20788368, 'album_name': 'Love Yuh Everything', 'artist_id': 24596367, 'artist_name': 'Alkaline', 'track_share_url': 'https://www.musixmatch.com/lyrics/Alkaline-2/Love-Yuh-Everything?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Alkaline-2/Love-Yuh-Everything/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2015-09-02T12:07:25Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1866, 'music_genre_parent_id': 8053, 'music_genre_name': 'Modern Dancehall', 'music_genre_name_extended': 'Reggae / Modern Dancehall', 'music_genre_vanity': 'Reggae-Modern-Dancehall'}}]}}
# 83260662
# Gyal You A Party Animal - Remix by Charly Black
# already have
# Bicycle Ride by Vybz Kartel
# {'track_id': 88523502, 'track_name': 'Bicycle Ride', 'track_name_translation_list': [], 'track_rating': 24, 'commontrack_id': 47291035, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 274, 'album_id': 21161848, 'album_name': 'Bicycle Ride - Single', 'artist_id': 56948, 'artist_name': 'Vybz Kartel', 'track_share_url': 'https://www.musixmatch.com/lyrics/Vybz-Kartel/Bicycle-Ride?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Vybz-Kartel/Bicycle-Ride/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-01-31T15:40:57Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1866, 'music_genre_parent_id': 8053, 'music_genre_name': 'Modern Dancehall', 'music_genre_name_extended': 'Reggae / Modern Dancehall', 'music_genre_vanity': 'Reggae-Modern-Dancehall'}}, {'music_genre': {'music_genre_id': 24, 'music_genre_parent_id': 34, 'music_genre_name': 'Reggae', 'music_genre_name_extended': 'Reggae', 'music_genre_vanity': 'Reggae'}}]}}
# 88523502
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# Imitadora by Romeo Santos
# already have
# Quisiera by CNCO
# already have
# En La Intimidad by Ozuna
# already have
# Flor Pálida by Marc Anthony
# already have
# Caminar de Tu Mano by Río Roma
# already have
# Middle by DJ Snake
# already have
# Stay With Me by Sam Smith
# already have
# Dangerous Woman by Ariana Grande
# already have
# Hello by Adele
# already have
# Now Or Never by Halsey
# already have
# Pumped Up Kicks by Foster The People
# already have
# Un Polvo by Maluma
# already have
# Diabla - Official Remix by Farruko
# already have
# Shape of You (feat. Zion & Lennox) - Latin Remix by Ed Sheeran
# already have
# Buscando Huellas (feat. J Balvin & Sean Paul) by Major Lazer
# already have
# 6955
# Me Rehúso by Danny Ocean
# already have
# Felices los 4 by Maluma
# already have
# Shape of You by Ed Sheeran
# already have
# Ahora Dice by Chris Jeday
# already have
# Escápate Conmigo by Wisin
# already have
# Hey DJ by CNCO
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# El Amante by Nicky Jam
# already have
# Sigo Extrañándote by J Balvin
# already have
# Despacito - Remix by Luis Fonsi
# already have
# Báilame by Nacho
# already have
# Something Just Like This by The Chainsmokers
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# Perfect by Ed Sheeran
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# That's What I Like by Bruno Mars
# already have
# Believer by Imagine Dragons
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Tu Foto by Ozuna
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# Soy Peor by Bad Bunny
# already have
# Wild Thoughts (feat. Rihanna & Bryson Tiller) by DJ Khaled
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Me Enamoré by Shakira
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# Lumbra by Cali Y El Dandee
# already have
# Sign of the Times by Harry Styles
# already have
# Thinking out Loud by Ed Sheeran
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Attention by Charlie Puth
# already have
# Safari by J Balvin
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Photograph by Ed Sheeran
# already have
# Malibu by Miley Cyrus
# already have
# Let Me Love You by DJ Snake
# already have
# Vacaciones by Wisin
# already have
# Closer by The Chainsmokers
# already have
# Traicionera by Sebastian Yatra
# already have
# Deja vu by Prince Royce
# already have
# One Dance by Drake
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Alguien Robo by Sebastian Yatra
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Thunder by Imagine Dragons
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# There for You by Martin Garrix
# already have
# Bonita by J Balvin
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# Una Lady Como Tú by Manuel Turizo
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# Bad Liar by Selena Gomez
# already have
# Besándote by Piso 21
# already have
# Unforgettable by French Montana
# already have
# Feels by Calvin Harris
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Swish Swish by Katy Perry
# already have
# Passionfruit by Drake
# already have
# Voy a Brillar by Alex Badilla
# already have
# I Feel It Coming by The Weeknd
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Side To Side by Ariana Grande
# already have
# No Lie by Sean Paul
# already have
# Strip That Down by Liam Payne
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# Fever by Vybz Kartel
# already have
# Borro Cassette by Maluma
# already have
# Galway Girl by Ed Sheeran
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# Ride by Twenty One Pilots
# already have
# Bon appétit by Katy Perry
# already have
# Treat You Better by Shawn Mendes
# already have
# Crying in the Club by Camila Cabello
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# La Bicicleta by Carlos Vives
# already have
# Cuatro Babys by Maluma
# already have
# Faded by Alan Walker
# already have
# Soy Peor Remix (feat. J Balvin, Ozuna & Arcangel) by Bad Bunny
# already have
# In the Name of Love by Martin Garrix
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# Dive by Ed Sheeran
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# Drop It by Eshconinco
# already have
# Bruk It Dung by Eshconinco
# already have
# Mask Off by Future
# already have
# Cold by Maroon 5
# already have
# Congratulations by Post Malone
# already have
# Happier by Ed Sheeran
# already have
# The Scientist by Coldplay
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# 24K Magic by Bruno Mars
# already have
# Starboy by The Weeknd
# already have
# Cold Water (feat. Justin Bieber & MØ) by Major Lazer
# already have
# 0 Sentimientos (Remix) [feat. Noriel, Darkiel, Lyan, Messiah & Baby Rasta] by Jon Z
# already have
# Castle on the Hill by Ed Sheeran
# already have
# Tu No Vive Asi (feat. Mambo Kingz & DJ Luian) by Arcangel
# already have
# Stressed Out by Twenty One Pilots
# already have
# First Time by Kygo
# already have
# Don't Wanna Know by Maroon 5
# already have
# Mama by Jonas Blue
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# Love Yourself by Justin Bieber
# already have
# Me Ama Me Odia by Ozuna
# already have
# All of Me by John Legend
# already have
# Me Mata by Bad Bunny
# already have
# Whatever It Takes by Imagine Dragons
# already have
# Déjame te explico by Reykon
# already have
# Paris by The Chainsmokers
# already have
# Say You Won't Let Go by James Arthur
# already have
# Me Acostumbre (feat. Bad Bunny) by Arcangel
# already have
# Slide by Calvin Harris
# already have
# Gyal You A Party Animal by Charly Black
# already have
# Bailame Despacio by Xantos
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Cheap Thrills by Sia
# already have
# La Última Vez by Anuel AA
# already have
# Shaky Shaky by Daddy Yankee
# already have
# Bruk Off Yuh Back by Konshens
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Into You by Ariana Grande
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Caile (feat. Zion & De La Ghetto) by Revol
# already have
# La Gozadera by Gente De Zona
# already have
# My Way by Calvin Harris
# already have
# Qué Me Has Hecho by Chayanne
# already have
# Cake By The Ocean by DNCE
# already have
# Por Fin Te Encontré by Cali Y El Dandee
# already have
# 7 Years by Lukas Graham
# already have
# Let Her Go by Passenger
# already have
# Mercy by Shawn Mendes
# already have
# No Te Hagas by Jory Boy
# already have
# Privado by Rvssian
# already have
# Million Reasons by Lady Gaga
# already have
# Counting Stars by OneRepublic
# already have
# Heathens by Twenty One Pilots
# already have
# Slow Hands by Niall Horan
# already have
# Sorry by Justin Bieber
# already have
# This Is What You Came For by Calvin Harris
# already have
# Sweet Child O' Mine by Guns N' Roses
# already have
# Princesa (feat. CNCO) by Río Roma
# already have
# Sugar by Maroon 5
# already have
# Héroe Favorito by Romeo Santos
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Ahora Me Llama by Karol G
# already have
# Lean On (feat. MØ & DJ Snake) by Major Lazer
# already have
# Cheap Thrills by Sia
# already have
# Ilegal by Cultura Profética
# already have
# Work by Rihanna
# already have
# Stitches by Shawn Mendes
# already have
# Now Or Never by Halsey
# already have
# Al Filo de Tu Amor by Carlos Vives
# already have
# Ya Me Enteré by Reik
# already have
# A Thousand Years by Christina Perri
# already have
# Signs by Drake
# already have
# Perfect Strangers by Jonas Blue
# already have
# Loca (feat. Cali y El Dandee) by Maite Perroni
# already have
# DNA. by Kendrick Lamar
# already have
# Caminar de Tu Mano by Río Roma
# already have
# Caraluna by Bacilos
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# Tan Fácil by CNCO
# already have
# When I Was Your Man by Bruno Mars
# already have
# Middle by DJ Snake
# already have
# 911 by Feid
# already have
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# Love Yuh Everything by Alkaline
# already have
# Bicycle Ride by Vybz Kartel
# already have
# Hello by Adele
# already have
# Stay With Me by Sam Smith
# already have
# Demons by Imagine Dragons
# already have
# Pumped Up Kicks by Foster The People
# already have
# Radioactive by Imagine Dragons
# {'track_id': 18742083, 'track_name': 'Radioactive', 'track_name_translation_list': [], 'track_rating': 85, 'commontrack_id': 10626641, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 46207, 'album_id': 14272186, 'album_name': 'Night Visions', 'artist_id': 13895270, 'artist_name': 'Imagine Dragons', 'track_share_url': 'https://www.musixmatch.com/lyrics/Imagine-Dragons/Radioactive?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Imagine-Dragons/Radioactive/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2019-05-28T03:01:42Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 20, 'music_genre_parent_id': 34, 'music_genre_name': 'Alternative', 'music_genre_name_extended': 'Alternative', 'music_genre_vanity': 'Alternative'}}]}}
# 18742083
# En La Intimidad by Ozuna
# already have
# Shape of You (feat. Zion & Lennox) - Latin Remix by Ed Sheeran
# already have
# Walking The Wire by Imagine Dragons
# already have
# I Don’t Know Why by Imagine Dragons
# already have
# One Last Time by Ariana Grande
# already have
# Flor Pálida by Marc Anthony
# already have
# Deja Que Te Bese by Alejandro Sanz
# already have
# Issues by Julia Michaels
# already have
# Un Polvo by Maluma
# already have
# Yellow by Coldplay
# already have
# When You Dance (feat. Kalado) by Eshconinco
# {'track_id': 118200202, 'track_name': 'When You Dance', 'track_name_translation_list': [], 'track_rating': 15, 'commontrack_id': 62727285, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 0, 'album_id': 24421195, 'album_name': 'When You Dance', 'artist_id': 32001210, 'artist_name': 'Eshconinco feat. Kalado', 'track_share_url': 'https://www.musixmatch.com/lyrics/Eshconinco-feat-Kalado/When-You-Dance-feat-Kalado?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Eshconinco-feat-Kalado/When-You-Dance-feat-Kalado/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-02-02T21:12:36Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1866, 'music_genre_parent_id': 8053, 'music_genre_name': 'Modern Dancehall', 'music_genre_name_extended': 'Reggae / Modern Dancehall', 'music_genre_vanity': 'Reggae-Modern-Dancehall'}}]}}
# 118200202
# DUELE EL CORAZON by Enrique Iglesias
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# 6957
# Me Rehúso by Danny Ocean
# already have
# Felices los 4 by Maluma
# already have
# Shape of You by Ed Sheeran
# already have
# Ahora Dice by Chris Jeday
# already have
# Escápate Conmigo by Wisin
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# Hey DJ by CNCO
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# El Amante by Nicky Jam
# already have
# Despacito - Remix by Luis Fonsi
# already have
# Sigo Extrañándote by J Balvin
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# Something Just Like This by The Chainsmokers
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# Perfect by Ed Sheeran
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Báilame by Nacho
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# That's What I Like by Bruno Mars
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# Thinking out Loud by Ed Sheeran
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# Sign of the Times by Harry Styles
# already have
# Tu Foto by Ozuna
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Lumbra by Cali Y El Dandee
# already have
# Soy Peor by Bad Bunny
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Me Enamoré by Shakira
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Photograph by Ed Sheeran
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# Malibu by Miley Cyrus
# already have
# Safari by J Balvin
# already have
# Attention by Charlie Puth
# already have
# Let Me Love You by DJ Snake
# already have
# Deja vu by Prince Royce
# already have
# Closer by The Chainsmokers
# already have
# One Dance by Drake
# already have
# Traicionera by Sebastian Yatra
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Vacaciones by Wisin
# already have
# Swish Swish by Katy Perry
# already have
# Voy a Brillar by Alex Badilla
# already have
# Alguien Robo by Sebastian Yatra
# already have
# Galway Girl by Ed Sheeran
# already have
# Bad Liar by Selena Gomez
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Believer by Imagine Dragons
# already have
# There for You by Martin Garrix
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# Wild Thoughts (feat. Rihanna & Bryson Tiller) by DJ Khaled
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# Passionfruit by Drake
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Bonita by J Balvin
# already have
# Unforgettable by French Montana
# already have
# Besándote by Piso 21
# already have
# I Feel It Coming by The Weeknd
# already have
# Side To Side by Ariana Grande
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Strip That Down by Liam Payne
# already have
# Bon appétit by Katy Perry
# already have
# Dive by Ed Sheeran
# already have
# No Lie by Sean Paul
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Fever by Vybz Kartel
# already have
# Happier by Ed Sheeran
# already have
# Una Lady Como Tú by Manuel Turizo
# already have
# Thunder by Imagine Dragons
# already have
# Ride by Twenty One Pilots
# already have
# Borro Cassette by Maluma
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# Cuatro Babys by Maluma
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# Treat You Better by Shawn Mendes
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# La Bicicleta by Carlos Vives
# already have
# Castle on the Hill by Ed Sheeran
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# In the Name of Love by Martin Garrix
# already have
# Crying in the Club by Camila Cabello
# already have
# Mask Off by Future
# already have
# Faded by Alan Walker
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# Cold by Maroon 5
# already have
# Starboy by The Weeknd
# already have
# 24K Magic by Bruno Mars
# already have
# Feels (feat. Pharrell Williams, Katy Perry & Big Sean) by Calvin Harris
# already have
# Drop It by Eshconinco
# already have
# Cold Water (feat. Justin Bieber & MØ) by Major Lazer
# already have
# First Time by Kygo
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Congratulations by Post Malone
# already have
# The Scientist by Coldplay
# already have
# Bruk It Dung by Eshconinco
# already have
# Stressed Out by Twenty One Pilots
# already have
# 0 Sentimientos (Remix) [feat. Noriel, Darkiel, Lyan, Messiah & Baby Rasta] by Jon Z
# already have
# Don't Wanna Know by Maroon 5
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Love Yourself by Justin Bieber
# already have
# Tu No Vive Asi (feat. Mambo Kingz & DJ Luian) by Arcangel
# already have
# Paris by The Chainsmokers
# already have
# All of Me by John Legend
# already have
# Say You Won't Let Go by James Arthur
# already have
# Slide (feat. Frank Ocean & Migos) by Calvin Harris
# already have
# Me Ama Me Odia by Ozuna
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# Gyal You A Party Animal by Charly Black
# already have
# Mama by Jonas Blue
# already have
# Cheap Thrills by Sia
# already have
# La Última Vez by Anuel AA
# already have
# Bailame Despacio by Xantos
# already have
# Shaky Shaky by Daddy Yankee
# already have
# Me Acostumbre (feat. Bad Bunny) by Arcangel
# already have
# Me Mata by Bad Bunny
# already have
# My Way by Calvin Harris
# already have
# Bruk Off Yuh Back by Konshens
# already have
# Into You by Ariana Grande
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Cake By The Ocean by DNCE
# already have
# Let Her Go by Passenger
# already have
# La Gozadera by Gente De Zona
# already have
# Million Reasons by Lady Gaga
# already have
# 7 Years by Lukas Graham
# already have
# Heathens by Twenty One Pilots
# already have
# Mercy by Shawn Mendes
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Sorry by Justin Bieber
# already have
# Counting Stars by OneRepublic
# already have
# Por Fin Te Encontré by Cali Y El Dandee
# already have
# Déjame te explico by Reykon
# already have
# Caile (feat. Zion & De La Ghetto) by Revol
# already have
# Slow Hands by Niall Horan
# already have
# Princesa (feat. CNCO) by Río Roma
# already have
# Qué Me Has Hecho by Chayanne
# already have
# This Is What You Came For by Calvin Harris
# already have
# DUELE EL CORAZON by Enrique Iglesias
# already have
# Sugar by Maroon 5
# already have
# Sweet Child O' Mine by Guns N' Roses
# already have
# Stitches by Shawn Mendes
# already have
# Héroe Favorito by Romeo Santos
# already have
# Caminar de Tu Mano by Río Roma
# already have
# Work by Rihanna
# already have
# Cheap Thrills by Sia
# already have
# Lean On (feat. MØ & DJ Snake) by Major Lazer
# already have
# Al Filo de Tu Amor by Carlos Vives
# already have
# Ya Me Enteré by Reik
# already have
# Issues by Julia Michaels
# already have
# Privado by Rvssian
# already have
# Ilegal by Cultura Profética
# already have
# DNA. by Kendrick Lamar
# already have
# Now Or Never by Halsey
# already have
# A Thousand Years by Christina Perri
# already have
# No Te Hagas by Jory Boy
# already have
# When I Was Your Man by Bruno Mars
# already have
# Stay With Me by Sam Smith
# already have
# Perfect Strangers by Jonas Blue
# already have
# Middle by DJ Snake
# already have
# Pumped Up Kicks by Foster The People
# already have
# Shape of You (feat. Zion & Lennox) - Latin Remix by Ed Sheeran
# already have
# Caraluna by Bacilos
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# One Last Time by Ariana Grande
# already have
# Hello by Adele
# already have
# Tan Fácil by CNCO
# already have
# En La Intimidad by Ozuna
# already have
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# Yellow by Coldplay
# already have
# Wonderwall - Remastered by Oasis
# already have
# Bajito by JEN
# CAN'T STOP THE FEELING! (Original Song from DreamWorks Animation's "TROLLS") by Justin Timberlake
# already have
# Deja Que Te Bese by Alejandro Sanz
# already have
# Pa Que Me Invitan - Spanglish Version by JEN
# Demons by Imagine Dragons
# already have
# Love Yuh Everything by Alkaline
# already have
# Flor Pálida by Marc Anthony
# already have
# 911 by Feid
# already have
# Chandelier by Sia
# already have
# Bicycle Ride by Vybz Kartel
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# When You Dance (feat. Kalado) by Eshconinco
# already have
# Starving by Hailee Steinfeld
# already have
# I'm Yours by Jason Mraz
# already have
# Just Hold On by Steve Aoki
# already have
# 1-800-273-8255 by Logic
# already have
# 6959
# Shape of You by Ed Sheeran
# already have
# Me Rehúso by Danny Ocean
# already have
# Felices los 4 by Maluma
# already have
# Ahora Dice by Chris Jeday
# already have
# Escápate Conmigo by Wisin
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# Hey DJ by CNCO
# already have
# El Amante by Nicky Jam
# already have
# Despacito - Remix by Luis Fonsi
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# Perfect by Ed Sheeran
# already have
# Sigo Extrañándote by J Balvin
# already have
# I'm the One by DJ Khaled
# already have
# SUBEME LA RADIO by Enrique Iglesias
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# Something Just Like This by The Chainsmokers
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# La Rompe Corazones by Daddy Yankee
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# That's What I Like by Bruno Mars
# already have
# Thinking out Loud by Ed Sheeran
# already have
# Photograph by Ed Sheeran
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# Báilame by Nacho
# already have
# Hey Ma (with Pitbull & J Balvin feat. Camila Cabello) - Spanish Version by Pitbull
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Sign of the Times by Harry Styles
# already have
# Lumbra by Cali Y El Dandee
# already have
# Si Tu Novio Te Deja Sola by J Balvin
# already have
# Me Enamoré by Shakira
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Soy Peor by Bad Bunny
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Malibu by Miley Cyrus
# already have
# Safari by J Balvin
# already have
# Galway Girl by Ed Sheeran
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# Closer by The Chainsmokers
# already have
# Deja vu by Prince Royce
# already have
# Let Me Love You by DJ Snake
# already have
# Tu Foto by Ozuna
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# One Dance by Drake
# already have
# Traicionera by Sebastian Yatra
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Happier by Ed Sheeran
# already have
# Dive by Ed Sheeran
# already have
# Attention by Charlie Puth
# already have
# Swish Swish by Katy Perry
# already have
# Castle on the Hill by Ed Sheeran
# already have
# Vacaciones by Wisin
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Alguien Robo by Sebastian Yatra
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# There for You by Martin Garrix
# already have
# Bon appétit by Katy Perry
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Si Tú La Ves (feat. Wisin) by Nicky Jam
# already have
# Believer by Imagine Dragons
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Strip That Down by Liam Payne
# already have
# Side To Side by Ariana Grande
# already have
# I Feel It Coming by The Weeknd
# already have
# Passionfruit by Drake
# already have
# Unforgettable by French Montana
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# Besándote by Piso 21
# already have
# Cuatro Babys by Maluma
# already have
# Fever by Vybz Kartel
# already have
# Treat You Better by Shawn Mendes
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Mask Off by Future
# already have
# Borro Cassette by Maluma
# already have
# Sé Que Te Duele by Alejandro Fernandez
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# Thunder by Imagine Dragons
# already have
# Ride by Twenty One Pilots
# already have
# La Bicicleta by Carlos Vives
# already have
# In the Name of Love by Martin Garrix
# already have
# Bad Liar by Selena Gomez
# already have
# No Lie by Sean Paul
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# Bonita by J Balvin
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# Faded by Alan Walker
# already have
# Una Lady Como Tú by Manuel Turizo
# already have
# Cold by Maroon 5
# already have
# First Time by Kygo
# already have
# Chained To The Rhythm by Katy Perry
# already have
# Crying in the Club by Camila Cabello
# already have
# Cold Water (feat. Justin Bieber & MØ) by Major Lazer
# already have
# Drop It by Eshconinco
# already have
# Starboy by The Weeknd
# already have
# Stressed Out by Twenty One Pilots
# already have
# 24K Magic by Bruno Mars
# already have
# Congratulations by Post Malone
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Love Yourself by Justin Bieber
# already have
# Bruk It Dung by Eshconinco
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Paris by The Chainsmokers
# already have
# ...
# already have
# Traicionera - Remix by Sebastian Yatra
# already have
# I Would Like by Zara Larsson
# already have
# Bailando - Spanish Version by Enrique Iglesias
# already have
# Sin Contrato by Maluma
# already have
# Water Under the Bridge by Adele
# already have
# Rude by MAGIC!
# already have
# Ginza by J Balvin
# already have
# Creo en Ti by Reik
# already have
# La Carretera by Prince Royce
# already have
# Take Me To Church by Hozier
# already have
# Sigo Extrañándote by J Balvin
# already have
# I'm Yours by Jason Mraz
# already have
# Can't Feel My Face by The Weeknd
# already have
# Someone Like You by Adele
# already have
# Amor y dolor by Carlos Baute
# already have
# Vivir Mi Vida by Marc Anthony
# already have
# Llegaste Tú by Luis Fonsi
# already have
# Wonderwall - Remastered by Oasis
# already have
# Encantadora by Yandel
# already have
# Guapa by MAYKEL
# By Your Side by Jonas Blue
# already have
# When I Was Your Man by Bruno Mars
# already have
# Don't Leave by Snakehips
# already have
# I'm Not The Only One by Sam Smith
# already have
# 6 AM (Remix) by Enzo Ortiz
# already have
# Fuiste Tú by Ricardo Arjona
# already have
# Perfect Illusion by Lady Gaga
# {'track_id': 115127174, 'track_name': 'Perfect Illusion', 'track_name_translation_list': [], 'track_rating': 45, 'commontrack_id': 62923034, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 5991, 'album_id': 24006984, 'album_name': 'Joanne', 'artist_id': 378462, 'artist_name': 'Lady Gaga', 'track_share_url': 'https://www.musixmatch.com/lyrics/Lady-Gaga/Perfect-Illusion?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Lady-Gaga/Perfect-Illusion/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2016-11-10T15:01:07Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1137, 'music_genre_parent_id': 15, 'music_genre_name': 'Disco', 'music_genre_name_extended': 'R&B/Soul / Disco', 'music_genre_vanity': 'R-B-Soul-Disco'}}, {'music_genre': {'music_genre_id': 17, 'music_genre_parent_id': 34, 'music_genre_name': 'Dance', 'music_genre_name_extended': 'Dance', 'music_genre_vanity': 'Dance'}}]}}
# 115127174
# Propuesta Indecente by Romeo Santos
# already have
# 6980
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# Shape of You by Ed Sheeran
# already have
# Reggaetón Lento (Bailemos) by CNCO
# already have
# Otra vez (feat. J Balvin) by Zion & Lennox
# already have
# Chantaje (feat. Maluma) by Shakira
# already have
# El Amante by Nicky Jam
# already have
# Safari by J Balvin
# already have
# Let Me Love You by DJ Snake
# already have
# Closer by The Chainsmokers
# already have
# Chillax (feat. Ky-Mani Marley) by Farruko
# already have
# Rockabye (feat. Sean Paul & Anne-Marie) by Clean Bandit
# already have
# One Dance by Drake
# already have
# Me Rehúso by Danny Ocean
# already have
# Vente Pa' Ca by Ricky Martin
# already have
# Traicionera by Sebastian Yatra
# already have
# Don't Wanna Know by Maroon 5
# already have
# Starboy by The Weeknd
# already have
# Ay Mi Dios (feat. Pitbull, Yandel & Chacal) by IAmChino
# already have
# Paris by The Chainsmokers
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# 24K Magic by Bruno Mars
# already have
# Castle on the Hill by Ed Sheeran
# already have
# In the Name of Love by Martin Garrix
# already have
# Cold Water (feat. Justin Bieber & MØ) by Major Lazer
# already have
# Vacaciones by Wisin
# already have
# La Bicicleta by Carlos Vives
# already have
# Cuatro Babys by Maluma
# already have
# Side To Side by Ariana Grande
# already have
# Treat You Better by Shawn Mendes
# already have
# Thinking out Loud by Ed Sheeran
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# My Way by Calvin Harris
# already have
# Photograph by Ed Sheeran
# already have
# Andas En Mi Cabeza by Chino & Nacho
# already have
# Fever by Vybz Kartel
# already have
# I Took A Pill In Ibiza - Seeb Remix by Mike Posner
# already have
# Shaky Shaky by Daddy Yankee
# already have
# I Feel It Coming by The Weeknd
# already have
# Heathens by Twenty One Pilots
# already have
# Pa Que Me Invitan - Spanglish Version by JEN
# already have
# Ride by Twenty One Pilots
# already have
# Borro Cassette by Maluma
# already have
# Gyal You A Party Animal by Charly Black
# already have
# Cheap Thrills by Sia
# already have
# We Don't Talk Anymore by Charlie Puth
# already have
# Ya Me Enteré (feat. Nicky Jam) - Urban Version by Reik
# already have
# Stressed Out by Twenty One Pilots
# already have
# Cake By The Ocean by DNCE
# already have
# Black Beatles by Rae Sremmurd
# already have
# Cheap Thrills by Sia
# already have
# Me Llamas (feat. Maluma) - Remix by Piso 21
# already have
# Just Hold On by Steve Aoki
# already have
# Dile Que Tu Me Quieres by Ozuna
# already have
# Scared to Be Lonely by Martin Garrix
# already have
# Mercy by Shawn Mendes
# already have
# Bailame Despacio by Xantos
# already have
# Say You Won't Let Go by James Arthur
# already have
# La Ocasion (feat. Arcangel, Ozuna & Anuel Aa) by De La Ghetto
# already have
# Te Quiero Pa´Mi by Don Omar
# already have
# Hasta el Amanecer by Nicky Jam
# already have
# Bobo by J Balvin
# already have
# El chisme by Reykon
# already have
# This Is What You Came For by Calvin Harris
# already have
# La Gozadera by Gente De Zona
# already have
# Call On Me - Ryan Riback Extended Remix by Starley
# already have
# How Far I'll Go - From "Moana" by Alessia Cara
# already have
# Work by Rihanna
# already have
# Faded by Alan Walker
# already have
# DUELE EL CORAZON by Enrique Iglesias
# already have
# Fuego by Juanes
# already have
# Fake Love by Drake
# already have
# Bruk It Dung by Eshconinco
# already have
# CAN'T STOP THE FEELING! (Original Song from DreamWorks Animation's "TROLLS") by Justin Timberlake
# already have
# Love Yourself by Justin Bieber
# already have
# Desde Esa Noche by Thalía
# already have
# Sorry by Justin Bieber
# already have
# Trumpets by Sak Noel & Salvi
# already have
# Deja Que Te Bese by Alejandro Sanz
# already have
# Bruk Off Yuh Back by Konshens
# already have
# Panda by Desiigner
# already have
# All We Know by The Chainsmokers
# already have
# Gyal You A Party Animal - Remix by Charly Black
# already have
# Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox] by Anuel AA
# already have
# Por Fin Te Encontré by Cali Y El Dandee
# already have
# Qué Gano Olvidándote (feat. Zion & Lennox) - Versión Urbana by Reik
# already have
# Work from Home (feat. Ty Dolla $ign) by Fifth Harmony
# already have
# My Dream by Nesbeth
# already have
# Lean On (feat. MØ & DJ Snake) by Major Lazer
# already have
# Starving by Hailee Steinfeld
# already have
# Ya Me Enteré by Reik
# already have
# Bad and Boujee (feat. Lil Uzi Vert) by Migos
# already have
# Diles (feat. Arcangel, Nengo Flow, Dj Luian & Mambo Kings) by Ozuna
# already have
# Bad Things (with Camila Cabello) by Machine Gun Kelly
# already have
# Bajito by JEN
# already have
# The Greatest by Sia
# already have
# Middle by DJ Snake
# already have
# Dueles by Jesse & Joy
# already have
# Que Raro by Feid
# already have
# Sugar by Maroon 5
# already have
# Alone by Alan Walker
# already have
# No Lie by Sean Paul
# already have
# Quiero Que Vuelvas by Alejandro Fernandez
# already have
# LUV by Tory Lanez
# already have
# Hear Me Now by Alok
# already have
# 7 Years by Lukas Graham
# already have
# All of Me by John Legend
# already have
# Ando buscando (feat. Piso 21) by Carlos Baute
# already have
# Run Up (feat. PARTYNEXTDOOR & Nicki Minaj) by Major Lazer
# already have
# De Pies A Cabeza by Maná
# already have
# Too Good by Drake
# already have
# Solo Dance by Martin Jensen
# already have
# Stitches by Shawn Mendes
# already have
# Hello by Adele
# already have
# Bicycle Ride by Vybz Kartel
# already have
# The Greatest by Sia
# already have
# This Girl (Kungs Vs. Cookin' On 3 Burners) - Kungs Vs. Cookin' On 3 Burners by Kungs
# already have
# All Night by The Vamps
# already have
# Perfect Strangers by Jonas Blue
# already have
# Love Yuh Everything by Alkaline
# already have
# Encantadora - Remix by Yandel
# already have
# Shed a Light by Robin Schulz
# already have
# Send My Love (To Your New Lover) by Adele
# already have
# Let Her Go by Passenger
# already have
# Chandelier by Sia
# already have
# Hymn for the Weekend - Seeb Remix by Coldplay
# already have
# The Scientist by Coldplay
# already have
# By Your Side by Jonas Blue
# already have
# Counting Stars by OneRepublic
# already have
# Obsesionado by Farruko
# already have
# Million Reasons by Lady Gaga
# already have
# Baila Conmigo by Juan Magán
# already have
# Sucker For Pain (with Wiz Khalifa, Imagine Dragons, Logic & Ty Dolla $ign feat. X Ambassadors) by Lil Wayne
# already have
# Tan Fácil by CNCO
# already have
# Love Me Now by John Legend
# already have
# Controlla by Drake
# already have
# El Perdón by Nicky Jam
# already have
# Adventure of a Lifetime by Coldplay
# already have
# No Money by Galantis
# already have
# Sweet Child O' Mine by Guns N' Roses
# already have
# Pumped Up Kicks by Foster The People
# already have
# Hotline Bling by Drake
# already have
# Into You by Ariana Grande
# already have
# Caminar de Tu Mano by Río Roma
# already have
# Quisiera by CNCO
# already have
# El Perdedor by Maluma
# already have
# Flor Pálida by Marc Anthony
# already have
# Unapologetic by Tanya Stephens
# already have
# Fast Car by Jonas Blue
# already have
# Ilegal by Cultura Profética
# already have
# What Do You Mean? by Justin Bieber
# already have
# Hasta Que Se Seque el Malecón - Remix by Jacob Forever
# already have
# Lumbra by Cali Y El Dandee
# already have
# Si me dices que sí (feat. Nicky Jam) by Cosculluela
# already have
# Manicomio by Cosculluela
# already have
# Mi tesoro (feat. Nicky Jam) by Zion & Lennox
# already have
# All Time Low by Jon Bellion
# already have
# Ginza by J Balvin
# already have
# I See Fire - From "The Hobbit - The Desolation Of Smaug" by Ed Sheeran
# already have
# Stay With Me by Sam Smith
# already have
# Hymn for the Weekend by Coldplay
# already have
# Bailando - Spanish Version by Enrique Iglesias
# already have
# Bohemian Rhapsody - Remastered 2011 by Queen
# already have
# A Thousand Years by Christina Perri
# already have
# I Would Like by Zara Larsson
# already have
# Ya No Me Duele Más - Remix by Silvestre Dangond
# already have
# Sin Contrato by Maluma
# already have
# Traicionera - Remix by Sebastian Yatra
# already have
# Cheerleader - Felix Jaehn Remix Radio Edit by OMI
# already have
# Scars To Your Beautiful by Alessia Cara
# already have
# El Perdedor - The Remix by Maluma
# already have
# Caraluna by Bacilos
# already have
# Rude by MAGIC!
# already have
# PILLOWTALK by ZAYN
# already have
# I Got You by Bebe Rexha
# already have
# Llegaste tú (feat. Reykon) by Sofia Reyes
# already have
# Tenerife Sea by Ed Sheeran
# {'track_id': 73109259, 'track_name': 'Tenerife Sea', 'track_name_translation_list': [], 'track_rating': 52, 'commontrack_id': 39539740, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 10365, 'album_id': 19624170, 'album_name': 'x', 'artist_id': 38620990, 'artist_name': 'Ed Sheeran', 'track_share_url': 'https://www.musixmatch.com/lyrics/Ed-Sheeran/Tenerife-Sea?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Ed-Sheeran/Tenerife-Sea/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2019-05-29T08:30:02Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 14, 'music_genre_parent_id': 34, 'music_genre_name': 'Pop', 'music_genre_name_extended': 'Pop', 'music_genre_vanity': 'Pop'}}]}}
# 73109259
# Can't Feel My Face by The Weeknd
# already have
# Vivir Mi Vida by Marc Anthony
# already have
# Water Under the Bridge by Adele
# already have
# Weak by AJR
# already have
# Encantadora by Yandel
# already have
# 6 AM (Remix) by Enzo Ortiz
# already have
# Guapa by MAYKEL
# already have
# Radioactive by Imagine Dragons
# already have
# I'm Yours by Jason Mraz
# already have
# Take Me To Church by Hozier
# already have
# Propuesta Indecente by Romeo Santos
# already have
# La Carretera by Prince Royce
# already have
# When I Was Your Man by Bruno Mars
# already have
# Sex by Cheat Codes
# already have
# Te busco (feat. Nicky Jam) by Cosculluela
# already have
# Sofia by Alvaro Soler
# already have
# Someone Like You by Adele
# already have
# When We Were Young by Adele
# already have
# I'm Not The Only One by Sam Smith
# already have
# Rolling in the Deep by Adele
# already have
# Now and Later by Sage The Gemini
# already have
# Lush Life by Zara Larsson
# {'track_id': 125673926, 'track_name': 'Lush Life', 'track_name_translation_list': [], 'track_rating': 62, 'commontrack_id': 46709762, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 43638, 'album_id': 25530347, 'album_name': 'So Good', 'artist_id': 33491591, 'artist_name': 'Zara Larsson', 'track_share_url': 'https://www.musixmatch.com/lyrics/Zara-Larsson/Lush-Life?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Zara-Larsson/Lush-Life/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-04-28T13:55:13Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 14, 'music_genre_parent_id': 34, 'music_genre_name': 'Pop', 'music_genre_name_extended': 'Pop', 'music_genre_vanity': 'Pop'}}, {'music_genre': {'music_genre_id': 17, 'music_genre_parent_id': 34, 'music_genre_name': 'Dance', 'music_genre_name_extended': 'Dance', 'music_genre_vanity': 'Dance'}}]}}
# 125673926
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-66-24b2b6a779a1> in <module>
# ----> 1 cr = get_data('cr')
#       2 cr.sort_values(by=['week'], ascending=False)
#
# <ipython-input-62-521a549c7db5> in get_data(country)
#     204
#     205     #add language information to files
# --> 206     add_language(files)
#     207
#     208     #analyze language for every week
#
# <ipython-input-62-521a549c7db5> in add_language(files)
#     192         #use api and add language/lyrics only if you do not already have them
#     193         if ('language' not in list(df)):
# --> 194             get_songs(df, file)
#     195             songs = load_songs()
#     196             print(len(songs))
#
# <ipython-input-62-521a549c7db5> in get_songs(df, fileName)
#     113         #if we do not alreay have the songs language and info archived, then query for it
#     114         if id not in songs:
# --> 115             get_track(songTitle, artist)
#     116         else:
#     117             print("already have")
#
# <ipython-input-62-521a549c7db5> in get_track(song, artist)
#      66         resp = requests.get(search_url, params=params)
#      67
# ---> 68         body = json.loads(resp.text)['message']['body']
#      69         if ('lyrics' in body):
#      70             lyrics = body['lyrics']
#
# /usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)

# %%
ar = get_data('ar')
ar.sort_values(by=['week'], ascending=False)

# %%
gt = get_data('gt')
gt.sort_values(by=['week'], ascending=False)

# %%
co = get_data('co')
co.sort_values(by=['week'], ascending=False)

# %%
es = get_data('es')
es.sort_values(by=['week'], ascending=False)

# %%
de = get_data('de')
de.sort_values(by=['week'], ascending=False)

# %%
glbl = get_data('global')
glbl.sort_values(by=['week'], ascending=False)

# %%
import pandas as pd

def get_all_data(countries):
    #find last fridays date
    last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    if (datetime.now().strftime('%Y-%m-%d') == last_friday.strftime('%Y-%m-%d')):
        last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    all_pds = []
    files = []
    urls = []
    country = []
    week = []
    newer_date = last_friday - timedelta(days=7)
    oldest_date = datetime(2017, 1, 1) 
    
    #create uls by counting back a friday at a time
    while (newer_date > oldest_date):
        dfs = []
        first = True
        older_date = newer_date - timedelta(days=7)
        newer_str = newer_date.strftime('%Y-%m-%d')
        older_str = older_date.strftime('%Y-%m-%d')
        newer_date = older_date
        for c in countries:
            file_name = "data/" + c + "/" + c + "_" + older_str + '--' + newer_str + '.csv'
            df = pd.read_csv(file_name,skiprows=[0])
            if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
                df = pd.read_csv(file_name,skiprows=[])
                if 'Unnamed: 0' in list(df):
                    df = df.drop('Unnamed: 0', axis=1)


            df.Artist = df.Artist.astype(str)
            dfs.append(df)
            if first:
                first = False
                country.append("all")
                week.append(file[-26:][0:10])
        whole=pd.concat(dfs)   
        all_pds.append(whole)  

    #analyze language for every week
    english_percent = []
    spanish_percent = []

    for df in all_pds:
        if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
            if 'Unnamed: 0' in list(df):
                df = df.drop('Unnamed: 0', axis=1)

        lang = {}
        total = 0
        for l in df['language']:
            if l is not "X":
                total = total + 1
            if l in lang:
                lang[l] = lang[l] + 1
            else:
                lang[l] = 1

        eng = 0
        if "en" in lang:
            eng = lang['en']

        esp = 0
        if "es" in lang:
            esp = lang['es']

        english_percent.append(round((eng/total),2))
        spanish_percent.append(round((esp/total),2))

    data = pd.DataFrame(
            {'country': country,
             'week': week,
             "english_percent": english_percent,
             "spanish_percent": spanish_percent
            })
    
    return data

# %%
all_countries = get_all_data(["mx","gt","ar","do", "co", "es"],104)
all_countries.head(104)
all_countries.to_csv("data/all_countries.csv")

# %%
# Create a trace
trace = go.Scatter(
    x = us['week'],
    y = us['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,us['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Spanish Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2
                  )
                )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spotifys US weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = de['week'],
    y = de['spanish_percent'],
    name='Spanish Percent',
)

# Create a trace
trace2 = go.Scatter(
    x = de['week'],
    y = de['german_percent'],
    name='German Percent',
    line = dict(
        color = ('green'),
        width = 2
      )
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,de['german_percent'])
line = slope*xi+intercept

trace3 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='German Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2
                  )
                )

data = [trace, trace2, trace3]

layout = dict(title = 'Percent of Songs in Spotifys Germanys weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = do['week'],
    y = do['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,do['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Spanish Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2
                  )
                )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spotifys Dominican Republic weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = co['week'],
    y = co['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,co['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Spanish Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2
                  )
                )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spotifys Colombia weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = mx['week'],
    y = mx['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,mx['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Spanish Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2
                  )
                )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spotifys Mexico weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = ar['week'],
    y = ar['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,ar['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Spanish Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2
                  )
                )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spotifys Argentina weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = gt['week'],
    y = gt['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,gt['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Spanish Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2
                  )
                )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spotifys Guatemala weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = es['week'],
    y = es['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,es['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Spanish Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2
                  )
                )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spains weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = glbl['week'],
    y = glbl['spanish_percent'],
    name='Spanish Percent',
)

# Create a trace
trace2 = go.Scatter(
    x = glbl['week'],
    y = glbl['german_percent'],
    name='German Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,glbl['spanish_percent'])
line = slope*xi+intercept

trace3 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Spanish Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2
                  )
                )

data = [trace, trace2, trace3]

layout = dict(title = 'Percent of Spanish songs in Spotifys Global weekly top 200 Chart',
              xaxis = dict(title = 'Week'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = all_countries['week'],
    y = all_countries['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,all_countries['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2)
                  )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spotifys Combined Spanish Speaking Countries weekly top 200 Chart',
              xaxis = dict(title = ''),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
