# %%
import requests
import pandas as pd
import csv
import datetime
import dateutil
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta, FR
import json
from pathlib import Path
from difflib import SequenceMatcher
import operator
import re
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
import spacy
from spacy_langdetect import LanguageDetector
nlp = spacy.load('en')
nlp.add_pipe(LanguageDetector(), name='language_detector', last=True)
with open('keys.json', 'r') as fp:
    our_keys = json.load(fp)
key = our_keys["musixmatch_key"]
plotly_key = our_keys["plotly_key"]
plotly.tools.set_credentials_file(username='jagluck', api_key=plotly_key)

# %%
#save songs
def save_songs(songs):
    if songs != {}:
        with open('data/songs.json', 'w') as fp:
            json.dump(songs, fp)
        
def load_songs():
    #load songs
    with open('data/songs.json', 'r') as fp:
        songs = json.load(fp)
        
    return songs
       
#compare similarity of two strings
def similar(a, b):
    sep = "feat"
    arest = a.split(sep, 1)[0]
    brest = b.split(sep, 1)[0]
    return SequenceMatcher(None, arest, brest).ratio()

#not currently using this
def get_lang(text):
    doc = nlp(text)
    # document level language detection. Think of it like average language of the document!
    if (doc._.language['language'] == 'es'):
        print("es")
        print(doc._.language)
        return 'es'
    elif (doc._.language['language'] == 'en'):
        print("en")
        print(doc._.language)
        return 'en'
  
    return 'X'

#get language/lyric information for a single track
def get_track(song, artist):
    songs = load_songs()
    search_url = 'http://api.musixmatch.com/ws/1.1/track.search'
    params = {'q_track' : song, 'page_size' : '30', 'page' : '1', 's_track_rating' : 'desc', 'apikey': key}
    resp = requests.get(search_url, params=params)
    tracks = json.loads(resp.text)['message']['body']['track_list']

    artist_results = {}

    index = 0
    for track in tracks:
        track_id = track['track']['track_id']
        artist_results[index] = similar(track['track']['artist_name'], artist)
        index = index + 1

    sorted_index = sorted(artist_results.items(), key=operator.itemgetter(1), reverse=True)
    
    if ((len(sorted_index) > 0) and (sorted_index[0][1] > .6)):
        winningIndex = sorted_index[0][0]
        print(tracks[winningIndex]['track'])
        track_id = tracks[winningIndex]['track']['track_id']
        commontrack_id = tracks[winningIndex]['track']['commontrack_id']
        print(track_id)

        search_url = 'http://api.musixmatch.com/ws/1.1/track.lyrics.get'
        params = {'track_id' : track_id, "commontrack_id" : commontrack_id, 'apikey': key}
        resp = requests.get(search_url, params=params)

        body = json.loads(resp.text)['message']['body']
        if ('lyrics' in body):
            lyrics = body['lyrics']
            lyrics_body  = lyrics['lyrics_body']
#             lyrics_language = lyrics['lyrics_language']

            id = (song + " by " + artist)
            song_info = {}
            song_info['song'] = song
            song_info['artist'] = artist
            song_info['lyrics_body'] = lyrics['lyrics_body'].replace('\n', ' ')[:-59]
#             song_info['lyrics_language'] = lyrics['lyrics_language']
            song_info['lyrics_language'] = get_lang(song_info['lyrics_body'])
            songs[id] = song_info
        else:
            print("empty resp")
            id = (song + " by " + artist)
            song_info = {}
            song_info['song'] = song
            song_info['artist'] = artist
            song_info['lyrics_body'] = "no lyrics"
            lg = "X"
            song_info['lyrics_language'] = lg
            songs[id] = song_info
    else:
        id = (song + " by " + artist)
        song_info = {}
        song_info['song'] = song
        song_info['artist'] = artist
        song_info['lyrics_body'] = "no lyrics"
        lg = "X"
        song_info['lyrics_language'] = lg
        songs[id] = song_info
        
    save_songs(songs)
       
#go through every song in a file
def get_songs(df, fileName):
    songs = load_songs()
    languages = []
    lyrics = []
    for songTitle, artist in zip(df['Track Name'], df['Artist']):
        songTitle = str(songTitle)
        id = (songTitle + ' by ' + artist) 
        print(id)
        #if we do not alreay have the songs language and info archived, then query for it
        if id not in songs:
            get_track(songTitle, artist)
        else:
            print("already have")
        songs = load_songs()
        songInfo = songs[id]
        lyrics.append(songInfo['lyrics_body'])
        languages.append(songInfo['lyrics_language'])
        
    #add new info to dataframe
    df['language'] = languages
    df['lyrics'] = lyrics
    
    df.to_csv(fileName)
    
#create urls and download files for a country and the last x weeks
def download_charts(country, weeks):
    
    #find last fridays date
    last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    if (datetime.now().strftime('%Y-%m-%d') == last_friday.strftime('%Y-%m-%d')):
        last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    files = []
    urls = []
    newer_date = last_friday - timedelta(days=7)
    
    #create uls by counting back a friday at a time
    for i in range(weeks):
        older_date = newer_date - timedelta(days=7)
        newer_str = newer_date.strftime('%Y-%m-%d')
        older_str = older_date.strftime('%Y-%m-%d')
        newer_date = older_date
        url = 'https://spotifycharts.com/regional/' + country + '/weekly/' + older_str + '--' + newer_str + '/download'
        file_name = "data/" + country + "/" + country + "_" + older_str + '--' + newer_str + '.csv'
#         print(url)
#         print(file_name)
        urls.append(url)
        files.append(file_name)
        
    #if we do not already have the file download it
    for file, url in zip(files,urls):
        my_file = Path(file)
        if not my_file.is_file():
            resp = requests.get(url)
            with open(file, 'w') as f:
                writer = csv.writer(f)
                reader = csv.reader(resp.text.splitlines())

                for row in reader:
                    writer.writerow(row)
                
    return files

#take file and add language/lyric info if needed
def add_language(files):

    for file in files:
        
        #load and reformat this file
        df = pd.read_csv(file,skiprows=[0])
        if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
            df = pd.read_csv(file,skiprows=[])
            if 'Unnamed: 0' in list(df):
                df = df.drop('Unnamed: 0', axis=1)


        df.Artist = df.Artist.astype(str)
        
        #use api and add language/lyrics only if you do not already have them
        if ('language' not in list(df)):
            get_songs(df, file) 
            songs = load_songs()
            print(len(songs))
        
def get_data(country, weeks):
       
    #download chart files
    files = download_charts(country, weeks)   
    
    #add language information to files
    add_language(files)

    #analyze language for every week
    country = []
    week = []
    english_percent = []
    spanish_percent = []

    for file in files:
        df = pd.read_csv(file,skiprows=[0])
        if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
            df = pd.read_csv(file,skiprows=[])
            if 'Unnamed: 0' in list(df):
                df = df.drop('Unnamed: 0', axis=1)


        df.Artist = df.Artist.astype(str)
        lang = {}
        for l in df['language']:
            if l in lang:
                lang[l] = lang[l] + 1
            else:
                lang[l] = 1

        eng = 0
        if "en" in lang:
            eng = lang['en']

        esp = 0
        if "es" in lang:
            esp = lang['es']

        total = eng + esp
        english_percent.append(round((eng/total),2))
        spanish_percent.append(round((esp/total),2))
        country.append(file[0:2])
        week.append(file[3:25])

    data = pd.DataFrame(
            {'country': country,
             'week': week,
             "english_percent": english_percent,
             "spanish_percent": spanish_percent
            })
    
    return data

# %%
us = get_data('us', 104)
us.sort_values(by=['week'], ascending=False)
us.head(52)
# Out:
# Despacito - Remix by Luis Fonsi
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# Wild Thoughts (feat. Rihanna & Bryson Tiller) by DJ Khaled
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Unforgettable by French Montana
# already have
# Congratulations by Post Malone
# already have
# Slide by Calvin Harris
# already have
# Redbone by Childish Gambino
# already have
# Location by Khalid
# already have
# Feels by Calvin Harris
# already have
# DNA. by Kendrick Lamar
# already have
# Bank Account by 21 Savage
# already have
# Signs by Drake
# already have
# Body Like A Back Road by Sam Hunt
# already have
# Believer by Imagine Dragons
# already have
# Magnolia by Playboi Carti
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# BUTTERFLY EFFECT by Travis Scott
# already have
# Mask Off by Future
# already have
# 1-800-273-8255 by Logic
# already have
# Strip That Down by Liam Payne
# already have
# Attention by Charlie Puth
# already have
# Rollin by Calvin Harris
# already have
# Slippery (feat. Gucci Mane) by Migos
# already have
# Praying by Kesha
# already have
# goosebumps by Travis Scott
# already have
# That's What I Like by Bruno Mars
# already have
# Bad Liar by Selena Gomez
# already have
# Thunder by Imagine Dragons
# already have
# Now Or Never by Halsey
# already have
# Shape of You by Ed Sheeran
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# Slow Hands by Niall Horan
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# Drowning (feat. Kodak Black) by A Boogie Wit da Hoodie
# already have
# LOVE. FEAT. ZACARI. by Kendrick Lamar
# already have
# Mi Gente by J Balvin
# already have
# Passionfruit by Drake
# already have
# 4 AM by 2 Chainz
# already have
# iSpy (feat. Lil Yachty) by KYLE
# already have
# Numb by 21 Savage
# already have
# I Like Me Better by Lauv
# already have
# No Complaints by Metro Boomin
# already have
# It's A Vibe by 2 Chainz
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# There for You by Martin Garrix
# already have
# LOYALTY. FEAT. RIHANNA. by Kendrick Lamar
# already have
# Young Dumb & Broke by Khalid
# already have
# Something Just Like This by The Chainsmokers
# already have
# Get Low (with Liam Payne) by Zedd
# already have
# Crying in the Club by Camila Cabello
# already have
# Love Galore (feat. Travis Scott) by SZA
# already have
# Tunnel Vision by Kodak Black
# already have
# Portland by Drake
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Bounce Back by Big Sean
# already have
# Famous by 21 Savage
# already have
# Issues by Julia Michaels
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Say You Won't Let Go by James Arthur
# already have
# Closer by The Chainsmokers
# already have
# Malibu by Miley Cyrus
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# wokeuplikethis* by Playboi Carti
# already have
# Craving You by Thomas Rhett
# already have
# Most Girls by Hailee Steinfeld
# already have
# Mama by Jonas Blue
# already have
# T-Shirt by Migos
# already have
# Swang by Rae Sremmurd
# already have
# Bad and Boujee (feat. Lil Uzi Vert) by Migos
# already have
# do re mi by blackbear
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# Bad Business by 21 Savage
# already have
# ELEMENT. by Kendrick Lamar
# already have
# Look At Me! by XXXTENTACION
# already have
# Down by Fifth Harmony
# already have
# Pretty Girl - Cheat Codes X CADE Remix by Maggie Lindemann
# already have
# Fake Love by Drake
# already have
# Close My Eyes by 21 Savage
# already have
# Met Gala (feat. Offset) by Gucci Mane
# already have
# Rolex by Ayo & Teo
# already have
# Your Song by Rita Ora
# already have
# First Day Out by Tee Grizzley
# already have
# FaceTime by 21 Savage
# already have
# Felices los 4 by Maluma
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Broccoli (feat. Lil Yachty) by DRAM
# already have
# Starboy by The Weeknd
# already have
# Gyalchester by Drake
# already have
# Whatever It Takes by Imagine Dragons
# already have
# Neighbors by J. Cole
# already have
# One Dance by Drake
# already have
# No Problem (feat. Lil Wayne & 2 Chainz) by Chance the Rapper
# already have
# Baby Girl by 21 Savage
# already have
# White Iverson by Post Malone
# already have
# Thug Life by 21 Savage
# already have
# X (feat. Future) by 21 Savage
# already have
# Homemade Dynamite by Lorde
# already have
# pick up the phone by Young Thug
# already have
# Feel It Still by Portugal. The Man
# already have
# Money Longer by Lil Uzi Vert
# already have
# Losin Control by Russ
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Who Dat Boy by Tyler, The Creator
# already have
# Hurricane by Luke Combs
# already have
# Go Flex by Post Malone
# already have
# beibs in the trap by Travis Scott
# already have
# Bring Dem Things by French Montana
# already have
# Sign of the Times by Harry Styles
# already have
# Nights With You by MØ
# already have
# No Vacancy by OneRepublic
# already have
# PRBLMS by 6LACK
# already have
# Caroline by Aminé
# already have
# Sorry Not Sorry by Demi Lovato
# already have
# Everyday We Lit (feat. PnB Rock) by YFN Lucci
# already have
# Relationship (feat. Future) by Young Thug
# already have
# No Role Modelz by J. Cole
# already have
# Escápate Conmigo by Wisin
# already have
# Paris by The Chainsmokers
# already have
# 911 / Mr. Lonely by Tyler, The Creator
# already have
# Two High by Moon Taxi
# already have
# In Case You Didn't Know by Brett Young
# already have
# Small Town Boy by Dustin Lynch
# already have
# I Feel It Coming by The Weeknd
# already have
# 24K Magic by Bruno Mars
# already have
# You Was Right by Lil Uzi Vert
# already have
# Horses (with PnB Rock, Kodak Black & A Boogie Wit da Hoodie) by PnB Rock
# already have
# Don't Let Me Down by The Chainsmokers
# already have
# What Ifs by Kane Brown
# already have
# Jump Out The Window by Big Sean
# already have
# Castle on the Hill by Ed Sheeran
# already have
# Selfish (feat. Rihanna) by Future
# already have
# First Time by Kygo
# already have
# Nothin New by 21 Savage
# already have
# Perfect Pint (feat. Kendrick Lamar, Gucci Mane & Rae Sremmurd) by Mike WiLL Made-It
# already have
# Symphony (feat. Zara Larsson) by Clean Bandit
# already have
# Candy Paint by Post Malone
# already have
# What They Want by Russ
# already have
# Starving by Hailee Steinfeld
# already have
# Low Life by Future
# already have
# Flex Like Ouu by Lil Pump
# already have
# No Heart by 21 Savage
# already have
# Dead People by 21 Savage
# already have
# Extra Luv by Future
# already have
# Can I Be Him by James Arthur
# already have
# Black Beatles by Rae Sremmurd
# already have
# The Cure by Lady Gaga
# already have
# Whole Lot by 21 Savage
# already have
# RAF by A$AP Mob
# already have
# Moves by Big Sean
# already have
# Everybody by Logic
# already have
# Reminder by The Weeknd
# already have
# Reminding Me by Shawn Hook
# already have
# The Night We Met by Lord Huron
# already have
# Skateboard P (feat. Big Sean) by MadeinTYO
# already have
# Money Convo by 21 Savage
# already have
# Run Me Dry by Bryson Tiller
# already have
# 7 Min Freestyle by 21 Savage
# already have
# Weak by AJR
# already have
# Both (feat. Drake) by Gucci Mane
# already have
# Rake It Up by Yo Gotti
# already have
# Good Drank by 2 Chainz
# already have
# Galway Girl by Ed Sheeran
# already have
# From The D To The A (feat. Lil Yachty) by Tee Grizzley
# already have
# Audi. by Smokepurpp
# already have
# Don't by Bryson Tiller
# already have
# How Far I'll Go - From "Moana" by Alessia Cara
# already have
# The Way I Are (Dance with Somebody) (feat. Lil Wayne) - Spotify Version by Bebe Rexha
# Myself by NAV
# already have
# Saved by Khalid
# already have
# Ex Calling by 6LACK
# already have
# Exchange by Bryson Tiller
# already have
# Selfish by PnB Rock
# already have
# High Without Your Love by Loote
# already have
# Love On The Brain by Rihanna
# already have
# Congratulations - Remix by Post Malone
# already have
# Ahora Dice by Chris Jeday
# already have
# Chill Bill by Rob $tone
# already have
# How Far I'll Go by Auli'i Cravalho
# already have
# Super Far by LANY
# already have
# 'Till I Collapse by Eminem
# already have
# Trap Paris (feat. Quavo & Ty Dolla $ign) by Machine Gun Kelly
# already have
# Up by NAV
# already have
# XXX. FEAT. U2. by Kendrick Lamar
# already have
# Special by 21 Savage
# already have
# CAN'T STOP THE FEELING! (Original Song from DreamWorks Animation's "TROLLS") by Justin Timberlake
# already have
# H.O.L.Y. by Florida Georgia Line
# already have
# Ride by Twenty One Pilots
# already have
# Nobody Else But You by Trey Songz
# already have
# Heartache On The Dance Floor by Jon Pardi
# already have
# Some Way by NAV
# already have
# Uh Huh by Julia Michaels
# already have
# Die A Happy Man by Thomas Rhett
# already have
# My Girl by Dylan Scott
# already have
# Mask Off - Remix by Future
# already have
# Heathens by Twenty One Pilots
# already have
# V. 3005 by Childish Gambino
# already have
# Get Right Witcha by Migos
# already have
# Side To Side by Ariana Grande
# already have
# 4524
# Despacito - Remix by Luis Fonsi
# already have
# XO TOUR Llif3 by Lil Uzi Vert
# already have
# Wild Thoughts (feat. Rihanna & Bryson Tiller) by DJ Khaled
# already have
# I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne) by DJ Khaled
# already have
# HUMBLE. by Kendrick Lamar
# already have
# Unforgettable by French Montana
# already have
# Congratulations by Post Malone
# already have
# Slide by Calvin Harris
# already have
# Redbone by Childish Gambino
# already have
# Location by Khalid
# already have
# Feels by Calvin Harris
# already have
# Signs by Drake
# already have
# Mask Off by Future
# already have
# DNA. by Kendrick Lamar
# already have
# Body Like A Back Road by Sam Hunt
# already have
# Rollin by Calvin Harris
# already have
# Believer by Imagine Dragons
# already have
# Magnolia by Playboi Carti
# already have
# That's What I Like by Bruno Mars
# already have
# 2U (feat. Justin Bieber) by David Guetta
# already have
# 1-800-273-8255 by Logic
# already have
# Stay (with Alessia Cara) by Zedd
# already have
# Strip That Down by Liam Payne
# already have
# BUTTERFLY EFFECT by Travis Scott
# already have
# goosebumps by Travis Scott
# already have
# Attention by Charlie Puth
# already have
# Thunder by Imagine Dragons
# already have
# Shape of You by Ed Sheeran
# already have
# Slippery (feat. Gucci Mane) by Migos
# already have
# Now Or Never by Halsey
# already have
# LOVE. FEAT. ZACARI. by Kendrick Lamar
# already have
# Passionfruit by Drake
# already have
# Drowning (feat. Kodak Black) by A Boogie Wit da Hoodie
# already have
# Bad Liar by Selena Gomez
# already have
# iSpy (feat. Lil Yachty) by KYLE
# already have
# Slow Hands by Niall Horan
# already have
# 4 AM by 2 Chainz
# already have
# There's Nothing Holdin' Me Back by Shawn Mendes
# already have
# No Complaints by Metro Boomin
# already have
# Something Just Like This by The Chainsmokers
# already have
# There for You by Martin Garrix
# already have
# Despacito (Featuring Daddy Yankee) by Luis Fonsi
# already have
# LOYALTY. FEAT. RIHANNA. by Kendrick Lamar
# already have
# It's A Vibe by 2 Chainz
# already have
# Portland by Drake
# already have
# Tunnel Vision by Kodak Black
# already have
# I Like Me Better by Lauv
# already have
# Issues by Julia Michaels
# already have
# Malibu by Miley Cyrus
# already have
# Bounce Back by Big Sean
# already have
# Know No Better (feat. Travis Scott, Camila Cabello & Quavo) by Major Lazer
# already have
# Crying in the Club by Camila Cabello
# already have
# Closer by The Chainsmokers
# already have
# It Ain't Me (with Selena Gomez) by Kygo
# already have
# Young Dumb & Broke by Khalid
# already have
# T-Shirt by Migos
# already have
# Bad and Boujee (feat. Lil Uzi Vert) by Migos
# already have
# wokeuplikethis* by Playboi Carti
# already have
# Mama by Jonas Blue
# already have
# Swang by Rae Sremmurd
# already have
# Love Galore (feat. Travis Scott) by SZA
# already have
# Prayers Up by Calvin Harris
# {'track_id': 131477095, 'track_name': 'Prayers Up', 'track_name_translation_list': [], 'track_rating': 34, 'commontrack_id': 73336160, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 134, 'album_id': 26383108, 'album_name': 'Funk Wav Bounces Vol.1', 'artist_id': 33821240, 'artist_name': 'Calvin Harris feat. Travis Scott & A-Trak', 'track_share_url': 'https://www.musixmatch.com/lyrics/Calvin-Harris-feat-Travis-Scott-A-Trak/Prayers-Up?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Calvin-Harris-feat-Travis-Scott-A-Trak/Prayers-Up/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-06-30T07:58:35Z', 'primary_genres': {'music_genre_list': []}}
# 131477095
# en
# {'language': 'en', 'score': 0.9999987184345027}
# Say You Won't Let Go by James Arthur
# already have
# 911 / Mr. Lonely by Tyler, The Creator
# already have
# Swalla (feat. Nicki Minaj & Ty Dolla $ign) by Jason Derulo
# already have
# ELEMENT. by Kendrick Lamar
# already have
# Who Dat Boy by Tyler, The Creator
# already have
# Look At Me! by XXXTENTACION
# already have
# More Than You Know by Axwell /\ Ingrosso
# already have
# Mi Gente by J Balvin
# already have
# Craving You by Thomas Rhett
# already have
# Fake Love by Drake
# already have
# do re mi by blackbear
# already have
# Rolex by Ayo & Teo
# already have
# Most Girls by Hailee Steinfeld
# already have
# Whatever It Takes by Imagine Dragons
# already have
# Gyalchester by Drake
# already have
# First Time by Kygo
# already have
# One Dance by Drake
# already have
# Broccoli (feat. Lil Yachty) by DRAM
# already have
# Met Gala (feat. Offset) by Gucci Mane
# already have
# First Day Out by Tee Grizzley
# already have
# Down by Fifth Harmony
# already have
# No Promises (feat. Demi Lovato) by Cheat Codes
# already have
# Pretty Girl - Cheat Codes X CADE Remix by Maggie Lindemann
# already have
# Starboy by The Weeknd
# already have
# Don't Quit (feat. Travis Scott & Jeremih) by DJ Khaled
# Extra Luv by Future
# already have
# No Problem (feat. Lil Wayne & 2 Chainz) by Chance the Rapper
# already have
# Faking It by Calvin Harris
# {'track_id': 131477102, 'track_name': 'Faking It', 'track_name_translation_list': [], 'track_rating': 35, 'commontrack_id': 73336158, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 752, 'album_id': 26383108, 'album_name': 'Funk Wav Bounces Vol.1', 'artist_id': 33821243, 'artist_name': 'Calvin Harris feat. Kehlani & Lil Yachty', 'track_share_url': 'https://www.musixmatch.com/lyrics/Calvin-Harris-feat-Kehlani-Lil-Yachty/Faking-It?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Calvin-Harris-feat-Kehlani-Lil-Yachty/Faking-It/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-06-30T08:17:35Z', 'primary_genres': {'music_genre_list': []}}
# 131477102
# en
# {'language': 'en', 'score': 0.9999969679894654}
# Hurricane by Luke Combs
# already have
# Your Song by Rita Ora
# already have
# Swish Swish by Katy Perry
# already have
# Cash Out by Calvin Harris
# {'track_id': 131477088, 'track_name': 'Cash Out', 'track_name_translation_list': [], 'track_rating': 30, 'commontrack_id': 73357186, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 90, 'album_id': 26383108, 'album_name': 'Funk Wav Bounces Vol.1', 'artist_id': 33827675, 'artist_name': 'Calvin Harris feat. ScHoolboy Q, PARTYNEXTDOOR & DRAM', 'track_share_url': 'https://www.musixmatch.com/lyrics/Calvin-Harris-feat-ScHoolboy-Q-PARTYNEXTDOOR-DRAM/Cash-Out?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Calvin-Harris-feat-ScHoolboy-Q-PARTYNEXTDOOR-DRAM/Cash-Out/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-06-30T07:49:22Z', 'primary_genres': {'music_genre_list': []}}
# 131477088
# en
# {'language': 'en', 'score': 0.9999947981802809}
# Homemade Dynamite by Lorde
# already have
# White Iverson by Post Malone
# already have
# Sign of the Times by Harry Styles
# already have
# Felices los 4 by Maluma
# already have
# Money Longer by Lil Uzi Vert
# already have
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)" by ZAYN
# already have
# Losin Control by Russ
# already have
# pick up the phone by Young Thug
# already have
# Nights With You by MØ
# already have
# Neighbors by J. Cole
# already have
# In Case You Didn't Know by Brett Young
# already have
# Caroline by Aminé
# already have
# Go Flex by Post Malone
# already have
# 24K Magic by Bruno Mars
# already have
# Everyday We Lit (feat. PnB Rock) by YFN Lucci
# already have
# Heatstroke by Calvin Harris
# {'track_id': 131477090, 'track_name': 'Heatstroke', 'track_name_translation_list': [], 'track_rating': 40, 'commontrack_id': 71023840, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 1, 'num_favourite': 576, 'album_id': 26383108, 'album_name': 'Funk Wav Bounces Vol.1', 'artist_id': 33371622, 'artist_name': 'Calvin Harris feat. Young Thug, Pharrell Williams & Ariana Grande', 'track_share_url': 'https://www.musixmatch.com/lyrics/Calvin-Harris-feat-Young-Thug-Pharrell-Williams-Ariana-Grande/Heatstroke?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Calvin-Harris-feat-Young-Thug-Pharrell-Williams-Ariana-Grande/Heatstroke/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-03-31T10:08:54Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 1048, 'music_genre_parent_id': 17, 'music_genre_name': 'House', 'music_genre_name_extended': 'Dance / House', 'music_genre_vanity': 'Dance-House'}}, {'music_genre': {'music_genre_id': 18, 'music_genre_parent_id': 34, 'music_genre_name': 'Hip Hop/Rap', 'music_genre_name_extended': 'Hip Hop/Rap', 'music_genre_vanity': 'Hip-Hop-Rap'}}]}}
# 131477090
# en
# {'language': 'en', 'score': 0.9999955059128365}
# Don't Let Me Down by The Chainsmokers
# already have
# X (feat. Future) by 21 Savage
# already have
# I Feel It Coming by The Weeknd
# already have
# beibs in the trap by Travis Scott
# already have
# Paris by The Chainsmokers
# already have
# PIE by Future
# {'track_id': 146691336, 'track_name': 'Pie', 'track_name_translation_list': [], 'track_rating': 30, 'commontrack_id': 77302296, 'instrumental': 0, 'explicit': 1, 'has_lyrics': 1, 'has_subtitles': 1, 'has_richsync': 0, 'num_favourite': 19, 'album_id': 28316111, 'album_name': 'Hip Hop Lit Vol. 8 (DJ Mix)', 'artist_id': 33491115, 'artist_name': 'Future', 'track_share_url': 'https://www.musixmatch.com/lyrics/Future/Pie?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Future/Pie/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2017-12-20T13:15:00Z', 'primary_genres': {'music_genre_list': []}}
# 146691336
# en
# {'language': 'en', 'score': 0.9999954708485826}
# Relationship (feat. Future) by Young Thug
# already have
# You Was Right by Lil Uzi Vert
# already have
# PRBLMS by 6LACK
# already have
# God, Your Mama, And Me by Florida Georgia Line
# {'track_id': 161619937, 'track_name': 'God, Your Mama, and Me (Commentary)', 'track_name_translation_list': [], 'track_rating': 26, 'commontrack_id': 90108278, 'instrumental': 0, 'explicit': 0, 'has_lyrics': 0, 'has_subtitles': 0, 'has_richsync': 0, 'num_favourite': 3, 'album_id': 30733224, 'album_name': 'Dig Your Roots (Big Machine Radio Release Special)', 'artist_id': 14014541, 'artist_name': 'Florida Georgia Line', 'track_share_url': 'https://www.musixmatch.com/lyrics/Florida-Georgia-Line/God-Your-Mama-and-Me-Commentary?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'track_edit_url': 'https://www.musixmatch.com/lyrics/Florida-Georgia-Line/God-Your-Mama-and-Me-Commentary/edit?utm_source=application&utm_campaign=api&utm_medium=National+Public+Radio%3A1409617822099', 'restricted': 0, 'updated_time': '2018-12-01T01:30:45Z', 'primary_genres': {'music_genre_list': [{'music_genre': {'music_genre_id': 6, 'music_genre_parent_id': 34, 'music_genre_name': 'Country', 'music_genre_name_extended': 'Country', 'music_genre_vanity': 'Country'}}]}}
# 161619937
# empty resp
# No Role Modelz by J. Cole
# already have
# No Vacancy by OneRepublic
# already have
# Horses (with PnB Rock, Kodak Black & A Boogie Wit da Hoodie) by PnB Rock
# already have
# To the Max by DJ Khaled

# %%
do = get_data('do', 104)
do.sort_values(by=['week'], ascending=False)
do.head(52)

# %%
mx = get_data('mx', 104)
mx.sort_values(by=['week'], ascending=False)
mx.head(52)

# %%
mx = get_data('cr', 104)
mx.sort_values(by=['week'], ascending=False)
mx.head(52)

# %%
ar = get_data('ar', 104)
ar.sort_values(by=['week'], ascending=False)
ar.head(52)

# %%
gt = get_data('gt', 104)
gt.sort_values(by=['week'], ascending=False)
gt.head(52)

# %%
co = get_data('co', 104)
co.sort_values(by=['week'], ascending=False)
co.head(52)

# %%
glbl = get_data('global', 104)
glbl.sort_values(by=['week'], ascending=False)
glbl.head(52)

# %%
import pandas as pd

def get_all_data(countries):
    #find last fridays date
    last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    if (datetime.now().strftime('%Y-%m-%d') == last_friday.strftime('%Y-%m-%d')):
        last_friday = datetime.now() + relativedelta(weekday=FR(-1))

    all_pds = []
    files = []
    urls = []
    country = []
    week = []
    newer_date = last_friday - timedelta(days=7)

    #create uls by counting back a friday at a time
    for i in range(52):
        dfs = []
        first = True
        older_date = newer_date - timedelta(days=7)
        newer_str = newer_date.strftime('%Y-%m-%d')
        older_str = older_date.strftime('%Y-%m-%d')
        newer_date = older_date
        for c in countries:
            file_name = c + "_" + older_str + '--' + newer_str + '.csv'
            df = pd.read_csv(file_name,skiprows=[0])
            if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
                df = pd.read_csv(file_name,skiprows=[])
                if 'Unnamed: 0' in list(df):
                    df = df.drop('Unnamed: 0', axis=1)


            df.Artist = df.Artist.astype(str)
            dfs.append(df)
            if first:
                first = False
                country.append("all")
                week.append(file_name[3:25])
        whole=pd.concat(dfs)   
        all_pds.append(whole)  

    #analyze language for every week
    english_percent = []
    spanish_percent = []

    for df in all_pds:
        if (list(df) != ['Position', 'Track Name', 'Artist', 'Streams', 'URL']):
            if 'Unnamed: 0' in list(df):
                df = df.drop('Unnamed: 0', axis=1)

        lang = {}
        for l in df['language']:
            if l in lang:
                lang[l] = lang[l] + 1
            else:
                lang[l] = 1

        eng = 0
        if "en" in lang:
            eng = lang['en']

        esp = 0
        if "es" in lang:
            esp = lang['es']

        total = eng + esp
        english_percent.append(round((eng/total),2))
        spanish_percent.append(round((esp/total),2))

    data = pd.DataFrame(
            {'country': country,
             'week': week,
             "english_percent": english_percent,
             "spanish_percent": spanish_percent
            })
    
    return data

# %%
all_countries = get_all_data(["mx","gt","ar","do", "co"])
all_countries.head(52)
all_countries.to_csv("all_countries.csv")

# %%
# Create a trace
trace = go.Scatter(
    x = us['week'],
    y = us['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys US weekly top 200 Chart',
              xaxis = dict(title = 'Week', autorange='reversed'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = do['week'],
    y = do['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Dominican Republic weekly top 200 Chart',
              xaxis = dict(title = 'Week', autorange='reversed'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = co['week'],
    y = co['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Colombia weekly top 200 Chart',
              xaxis = dict(title = 'Week', autorange='reversed'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = mx['week'],
    y = mx['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Mexico weekly top 200 Chart',
              xaxis = dict(title = 'Week', autorange='reversed'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = ar['week'],
    y = ar['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Argentina weekly top 200 Chart',
              xaxis = dict(title = 'Week', autorange='reversed'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = gt['week'],
    y = gt['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Guatemala weekly top 200 Chart',
              xaxis = dict(title = 'Week', autorange='reversed'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = glbl['week'],
    y = glbl['spanish_percent']
)

data = [trace]

layout = dict(title = 'Percent of Spanish songs in Spotifys Global weekly top 200 Chart',
              xaxis = dict(title = 'Week', autorange='reversed'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')

# %%
# Create a trace
trace = go.Scatter(
    x = all_countries['week'],
    y = all_countries['spanish_percent'],
    name='Spanish Percent',
)

xi = arange(0,len(all_countries))

# Generated linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,all_countries['spanish_percent'])
line = slope*xi+intercept

trace2 = go.Scatter(
                  x=all_countries['week'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Fit',
                  line = dict(
                    color = ('rgb(205, 12, 24)'),
                    width = 2)
                  )

data = [trace, trace2]

layout = dict(title = 'Percent of Spanish songs in Spotifys Combined Spanish Speaking Countries weekly top 200 Chart',
              xaxis = dict(title = '', autorange='reversed'),
              yaxis = dict(title = 'Percent of Spanish songs', tickformat = '.0%'),
              )

fig = dict(data=data, layout=layout)
py.iplot(figure_or_data=fig, filename='basic-line')
